# %%
from google.colab import drive
import os

drive.mount('/content/drive')                          # auth popup, once per session
RESULTS_DIR = '/content/drive/MyDrive/thesis_results'  # change name if you like
os.makedirs(RESULTS_DIR, exist_ok=True)
os.chdir(RESULTS_DIR)                                   # all relative saves now land here
print('Saving to:', os.getcwd())
# Out:
# Mounted at /content/drive
# Saving to: /content/drive/MyDrive/thesis_results

# %%
# Imports

## Core libraries
import numpy as np
import matplotlib.pyplot as plt

## TensorFlow / Keras
import tensorflow as tf
import keras
from keras import ops, layers
from keras.callbacks import Callback
from keras.models import Sequential, Model
from keras.layers import Input, Conv2D, Dense

# %%
# Setting seeds

np.random.seed(1999)
tf.random.set_seed(1999)

# %%
# Loading the dataset

(x_train_full, y_train_full), (x_test, y_test) = keras.datasets.cifar10.load_data()

## Feature scaling (mapping pixel values to [0,1])
'''
This is used as neural network training via gradient descent is sensitive to the
scale of inputs (through activations a = Wx + b). This causes gradients to vanish
and makes the loss landscape poorly conditioned.
'''
x_train_full = x_train_full / 255.0
x_test = x_test / 255.0

''' Recalling our y values are our categories '''
y_train_full = keras.utils.to_categorical(y_train_full, 10)
y_test = keras.utils.to_categorical(y_test, 10)

## Setting up our validation dataset
n_val = int(0.2 * len(x_train_full))
perm = np.random.permutation(len(x_train_full))
val_idx, train_idx = perm[:n_val], perm[n_val:]
x_val, y_val = x_train_full[val_idx], y_train_full[val_idx]
x_train, y_train = x_train_full[train_idx], y_train_full[train_idx]

## Check
print(f"train: {x_train.shape} val: {x_val.shape} test: {x_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 7647s 45us/step
# train: (40000, 32, 32, 3) val: (10000, 32, 32, 3) test: (10000, 32, 32, 3)

# %%
# Augmenting the dataset
'''
This involves creating new training examples by applying label preserving
transformations to existing examples e.g. flips, crops, scaling, colour jitter,
adding noise, ...
'''

'''
Applying three transformations in sequence, we pad the image with black 0s,
then randomly crop the newly padded image (so the model learns that a shifted
horse picture is still a horse), and then randomly mirroring the image from left
to right.
'''
augment = keras.Sequential([layers.ZeroPadding2D(padding=4),
                            layers.RandomCrop(32, 32),
                            layers.RandomFlip("horizontal")])

batch_size = 128

'''
This builds the full training data pipeline, where:
- The from_tensor_slices((x_train, y_train)) wraps the numpy arrays into a
  tf.data.Dataset that has image label pairs one at a time.
- For .shuffle(len(x_train)) - this shifts the entire dataset after each epoch.
- For .map(lambda x, y: (augment(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
  this applies the augmentation pipeline to each batch of images whilst leaving
  labels untouched. The training=True is important because RandomCrop and
  RandomFlip only apply their transformations during training. The
  num_parallel_calls=tf.data.AUTOTUNE lets TensorFlow decide how many batches to
  augment in parallel across CPU threads.
'''
train_ds = (tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size).map(lambda x, y: (augment(x, training=True), y),
            num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE))

### Recalling that there is no augmentation for validation and test datasets
val_ds  = (tf.data.Dataset.from_tensor_slices((x_val,  y_val ))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))
test_ds = (tf.data.Dataset.from_tensor_slices((x_test, y_test))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))


### Un-augmented training data used ONLY to recalibrate BatchNorm statistics
### after loading SWAG-sampled weights (see recalibrate_batchnorm). No shuffle/
### augmentation needed; we just need representative activations.
recal_ds = (tf.data.Dataset.from_tensor_slices((x_train, y_train))
            .batch(batch_size).prefetch(tf.data.AUTOTUNE))

# %%
# Residual block (no dropout)
'''
Here is the specification requirements for a single residual block (the repeating
unit in ResNet-20). Instead of learning the mapping between the input and the
output, we instead learn the difference between the input and the desired output
(the residual).

In this, the shortcut path passes the input unchanged (albeit with a channel
count change to match shapes at times). These two paths are added together for
a final ReLU.
'''

### We recall that a convolution slides a small window (a kernel/filter) across our grid.
### A single kernel produces one output grid (one channel). One kernel might learn to detect vertical edges, another colour gradients, and so on.
### We thus use 16 kernels simultaneously to produce an output with 16 channels.

class ResidualBlock(keras.layers.Layer):

    '''
    The init method constructs everything which doesn't fit into the other categories.
    In this, we construct the two convolutional layers and the ReLU activation.
    Everything here is created once and reused when the block processes an input.
    Projection is handled separately, as the input's channel count changes.
    '''
    def __init__(self, filters, stride=1, **kwargs):
        super().__init__(**kwargs)
        self.filters = filters
        self.stride = stride

        ### The same padding here adds just enough padding at each convolution step so the output spatial dimensions match the input.
        ### The kernel initialiser establishes starting weights for the kernels such that they are not all zero (each kernel learns the same thing), too large (where activations explode), or too small (vanishing to zero).
        self.conv1 = layers.Conv2D(filters, 3, strides=stride, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")

        ### Batch normalisation ensures each channel has a mean of 0 and a variance of 1.
        ### This is necessary for faster and more stable training as the weights update during training, causing our outputs to shift considerably (and calibrated to the old weights).
        ### The purpose of batch normalisation is to ensure a stable range of outputs.
        self.bn1 = layers.BatchNormalization()
        self.conv2 = layers.Conv2D(filters, 3, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")
        self.bn2 = layers.BatchNormalization()
        self.relu = layers.Activation("relu")

    ### Going deeper into the network, we want to detect increasingly abstract features.
    ### We therefore downsample (have a bigger stride) as we detect combinations.
    ### We compensate for that by increasing the number of channels.

    '''
    The build method handles the projection shortcut (and handles shape-matching if needed).
    '''
    def build(self, input_shape):
        in_channels = input_shape[-1]

        if self.stride != 1 or in_channels != self.filters:
            self.proj = layers.Conv2D(self.filters, 1, strides=self.stride, padding="valid",
                                      kernel_regularizer=keras.regularizers.L2(1e-4),
                                      kernel_initializer="he_normal")
            self.bn_proj = layers.BatchNormalization()
        else:
            self.proj = None

        super().build(input_shape)

    '''
    The call method runs the actual forward pass of the model organising the
    split into the main convolutional path and the shortcut path, then summing
    them and applying ReLU.
    '''
    def call(self, x):
        if self.proj is not None:
            shortcut = self.bn_proj(self.proj(x))
        else:
            shortcut = x

        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))

        return self.relu(out + shortcut)

    '''
    The get_config method enables serialisation so Keras can save/load the model.
    '''
    def get_config(self):
        config = super().get_config()
        config.update({"filters": self.filters,
                       "stride": self.stride})
        return config

# %%
# build_resnet20_vib — VIB + SWAG variant

'''
The feature extractor follows the deterministic ResNet-20 specification above.
The VIB change is after global average pooling: instead of sending the feature
vector directly to the classifier, we map it to the parameters of a diagonal
Gaussian bottleneck, sample z, and classify from z.

SWAG is added later during training by collecting weight snapshots and sampling
from the fitted Gaussian approximation. The architecture itself is therefore
just the VIB-ResNet-20 architecture.
'''

class VIBSampling(keras.layers.Layer):

    """
    Reparameterisation layer for VIB.

    Given mu and log_var, sample z = mu + sigma * epsilon and add the VIB KL
    penalty beta * KL(q(z|x) || N(0, I)) to the model loss.
    """
    def __init__(self, beta=1e-3, **kwargs):
        super().__init__(**kwargs)
        self.beta = beta

    def call(self, inputs):
        mu, log_var = inputs
        eps = tf.random.normal(shape=tf.shape(mu), dtype=mu.dtype)
        z = mu + tf.exp(0.5 * log_var) * eps

        kl_per_example = -0.5 * tf.reduce_sum(
            1.0 + log_var - tf.square(mu) - tf.exp(log_var), axis=-1
        )
        self.add_loss(self.beta * tf.reduce_mean(kl_per_example))

        return z

    def get_config(self):
        config = super().get_config()
        config.update({"beta": self.beta})
        return config


def build_vib_resnet20(beta=1e-3, latent_dim=64):
    inputs = keras.Input(shape=(32, 32, 3))

    x = layers.Conv2D(16, 3, padding="same",
                      kernel_regularizer=keras.regularizers.L2(1e-4),
                      kernel_initializer="he_normal")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    for _ in range(3):
        x = ResidualBlock(16)(x)

    x = ResidualBlock(32, stride=2)(x)
    for _ in range(2):
        x = ResidualBlock(32)(x)

    x = ResidualBlock(64, stride=2)(x)
    for _ in range(2):
        x = ResidualBlock(64)(x)

    ### Global average pooling takes the block's output and turns it into a flat
    ### feature vector. In the deterministic version this went straight into the
    ### final dense layer; here it becomes the input to the VIB bottleneck.
    x = layers.GlobalAveragePooling2D()(x)

    z_mu = layers.Dense(latent_dim,
                        kernel_initializer="he_normal",
                        name="z_mu")(x)
    z_log_var = layers.Dense(latent_dim,
                             kernel_initializer="zeros",
                             bias_initializer="zeros",
                             name="z_log_var")(x)
    z = VIBSampling(beta=beta, name="vib_bottleneck")([z_mu, z_log_var])

    outputs = layers.Dense(10, kernel_initializer="he_normal")(z)

    return keras.Model(inputs, outputs)

# %%
# Building VIB-SWAG model

beta = 1e-3      # compression strength; useful alternatives: 1e-4, 1e-2
latent_dim = 64  # keep equal to the deterministic ResNet-20 pooled feature width

model = build_vib_resnet20(beta=beta, latent_dim=latent_dim)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        448 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block      │ (None, 32, 32,    │      4,768 │ activation[0][0]  │
# │ (ResidualBlock)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_1    │ (None, 32, 32,    │      4,768 │ residual_block[0… │
# │ (ResidualBlock)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_2    │ (None, 32, 32,    │      4,768 │ residual_block_1… │
# │ (ResidualBlock)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_3    │ (None, 16, 16,    │     14,816 │ residual_block_2… │
# │ (ResidualBlock)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_4    │ (None, 16, 16,    │     18,752 │ residual_block_3… │
# │ (ResidualBlock)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_5    │ (None, 16, 16,    │     18,752 │ residual_block_4… │
# │ (ResidualBlock)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_6    │ (None, 8, 8, 64)  │     58,304 │ residual_block_5… │
# │ (ResidualBlock)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_7    │ (None, 8, 8, 64)  │     74,368 │ residual_block_6… │
# │ (ResidualBlock)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_8    │ (None, 8, 8, 64)  │     74,368 │ residual_block_7… │
# │ (ResidualBlock)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ residual_block_8… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mu (Dense)        │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vib_bottleneck      │ (None, 64)        │          0 │ z_mu[0][0],       │
# │ (VIBSampling)       │                   │            │ z_log_var[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10)        │        650 │ vib_bottleneck[0… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 283,146 (1.08 MB)
#  Trainable params: 281,578 (1.07 MB)
#  Non-trainable params: 1,568 (6.12 KB)

# %%
# Initial VIB training

'''
Step-wise learning-rate schedule: drop by 10x at epochs 100 and 150.
This is unchanged from the deterministic notebook so the combined VIB-SWAG
model starts from the same optimisation recipe as the VIB-alone model.
'''
def lr_schedule(epoch, lr):
    if epoch in (100, 150):
        return lr * 0.1
    return lr

# %%
# Compiling initial VIB model

### This doesn't run any training or touch any data, but it configures the optimiser (how weights are updated), the loss function, and optionally any metrics we want to track.
### The VIB KL term is added inside the VIBSampling layer via self.add_loss(...), so the compile loss remains categorical cross-entropy.
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1, momentum=0.9),
              loss=keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=["categorical_accuracy"])

# %%
# Callbacks for initial VIB checkpoint

callbacks = [keras.callbacks.ModelCheckpoint("vib_swag_initial_best.weights.h5",
                                             monitor="val_loss",
                                             save_best_only=True,
                                             save_weights_only=True),
             keras.callbacks.LearningRateScheduler(lr_schedule, verbose=1)] # calls lr_schedule function each epoch to reduce learning rate

# %%
# Initial VIB training run

history = model.fit(train_ds,
                    epochs=200,
                    validation_data=val_ds,
                    callbacks=callbacks)


model.load_weights("vib_swag_initial_best.weights.h5") # Loading best initial VIB checkpoint

# Final evaluation on test set before SWAG collection.
# This is a single stochastic pass, so the double-MC evaluation cell below is
# the better number to report for the final VIB-SWAG predictive distribution.
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"\nInitial VIB single-sample test loss: {test_loss:.4f}  Initial VIB single-sample test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 1/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 68ms/step - categorical_accuracy: 0.1870 - loss: 2.4549 - val_categorical_accuracy: 0.1803 - val_loss: 2.8448 - learning_rate: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 2/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.3619 - loss: 1.8639 - val_categorical_accuracy: 0.2784 - val_loss: 2.3558 - learning_rate: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 3/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.4916 - loss: 1.5737 - val_categorical_accuracy: 0.3844 - val_loss: 2.1423 - learning_rate: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 4/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.5761 - loss: 1.3675 - val_categorical_accuracy: 0.4981 - val_loss: 1.9194 - learning_rate: 0.1000
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 5/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.6357 - loss: 1.2094 - val_categorical_accuracy: 0.5128 - val_loss: 1.8319 - learning_rate: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 6/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.6799 - loss: 1.0969 - val_categorical_accuracy: 0.5837 - val_loss: 1.4525 - learning_rate: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 7/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7173 - loss: 1.0021 - val_categorical_accuracy: 0.5759 - val_loss: 1.5375 - learning_rate: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 8/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.7377 - loss: 0.9505 - val_categorical_accuracy: 0.6337 - val_loss: 1.3534 - learning_rate: 0.1000
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 9/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.7598 - loss: 0.8909 - val_categorical_accuracy: 0.6981 - val_loss: 1.0814 - learning_rate: 0.1000
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 10/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7742 - loss: 0.8529 - val_categorical_accuracy: 0.5708 - val_loss: 1.5176 - learning_rate: 0.1000
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 11/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7816 - loss: 0.8256 - val_categorical_accuracy: 0.7196 - val_loss: 1.1444 - learning_rate: 0.1000
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 12/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7927 - loss: 0.8049 - val_categorical_accuracy: 0.7021 - val_loss: 1.1366 - learning_rate: 0.1000
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 13/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.7976 - loss: 0.7882 - val_categorical_accuracy: 0.7449 - val_loss: 0.9753 - learning_rate: 0.1000
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 14/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8119 - loss: 0.7527 - val_categorical_accuracy: 0.7759 - val_loss: 0.8894 - learning_rate: 0.1000
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 15/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8146 - loss: 0.7485 - val_categorical_accuracy: 0.6448 - val_loss: 1.4841 - learning_rate: 0.1000
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 16/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8216 - loss: 0.7266 - val_categorical_accuracy: 0.6654 - val_loss: 1.4971 - learning_rate: 0.1000
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 17/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8282 - loss: 0.7145 - val_categorical_accuracy: 0.7929 - val_loss: 0.8399 - learning_rate: 0.1000
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 18/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8336 - loss: 0.6961 - val_categorical_accuracy: 0.6561 - val_loss: 1.3239 - learning_rate: 0.1000
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 19/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8367 - loss: 0.6923 - val_categorical_accuracy: 0.7296 - val_loss: 1.0818 - learning_rate: 0.1000
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 20/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8414 - loss: 0.6777 - val_categorical_accuracy: 0.7116 - val_loss: 1.1156 - learning_rate: 0.1000
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 21/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8411 - loss: 0.6746 - val_categorical_accuracy: 0.7640 - val_loss: 0.9715 - learning_rate: 0.1000
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 22/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8476 - loss: 0.6666 - val_categorical_accuracy: 0.7653 - val_loss: 0.9483 - learning_rate: 0.1000
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 23/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8496 - loss: 0.6584 - val_categorical_accuracy: 0.7310 - val_loss: 1.1188 - learning_rate: 0.1000
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 24/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8533 - loss: 0.6551 - val_categorical_accuracy: 0.7615 - val_loss: 1.0169 - learning_rate: 0.1000
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 25/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8527 - loss: 0.6522 - val_categorical_accuracy: 0.7703 - val_loss: 0.9794 - learning_rate: 0.1000
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 26/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8580 - loss: 0.6457 - val_categorical_accuracy: 0.7093 - val_loss: 1.3648 - learning_rate: 0.1000
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 27/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8641 - loss: 0.6323 - val_categorical_accuracy: 0.7966 - val_loss: 0.8440 - learning_rate: 0.1000
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 28/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8606 - loss: 0.6363 - val_categorical_accuracy: 0.6759 - val_loss: 1.4247 - learning_rate: 0.1000
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 29/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8647 - loss: 0.6296 - val_categorical_accuracy: 0.6999 - val_loss: 1.2587 - learning_rate: 0.1000
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 30/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8684 - loss: 0.6262 - val_categorical_accuracy: 0.7867 - val_loss: 0.9459 - learning_rate: 0.1000
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 31/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8651 - loss: 0.6232 - val_categorical_accuracy: 0.8042 - val_loss: 0.8468 - learning_rate: 0.1000
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 32/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8681 - loss: 0.6224 - val_categorical_accuracy: 0.5878 - val_loss: 1.8791 - learning_rate: 0.1000
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 33/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8685 - loss: 0.6201 - val_categorical_accuracy: 0.8219 - val_loss: 0.7936 - learning_rate: 0.1000
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 34/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8721 - loss: 0.6140 - val_categorical_accuracy: 0.7543 - val_loss: 1.0587 - learning_rate: 0.1000
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 35/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8722 - loss: 0.6163 - val_categorical_accuracy: 0.7228 - val_loss: 1.2365 - learning_rate: 0.1000
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 36/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8729 - loss: 0.6103 - val_categorical_accuracy: 0.7775 - val_loss: 0.9797 - learning_rate: 0.1000
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 37/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8773 - loss: 0.6051 - val_categorical_accuracy: 0.7984 - val_loss: 0.8602 - learning_rate: 0.1000
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 38/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8783 - loss: 0.6003 - val_categorical_accuracy: 0.7853 - val_loss: 0.9271 - learning_rate: 0.1000
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 39/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8779 - loss: 0.6011 - val_categorical_accuracy: 0.7771 - val_loss: 0.9730 - learning_rate: 0.1000
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 40/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8778 - loss: 0.6033 - val_categorical_accuracy: 0.7822 - val_loss: 1.0041 - learning_rate: 0.1000
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 41/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8776 - loss: 0.6053 - val_categorical_accuracy: 0.8310 - val_loss: 0.7705 - learning_rate: 0.1000
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 42/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8813 - loss: 0.5936 - val_categorical_accuracy: 0.6795 - val_loss: 1.3176 - learning_rate: 0.1000
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 43/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8806 - loss: 0.5965 - val_categorical_accuracy: 0.7818 - val_loss: 0.9556 - learning_rate: 0.1000
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 44/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8798 - loss: 0.6041 - val_categorical_accuracy: 0.7370 - val_loss: 1.2388 - learning_rate: 0.1000
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 45/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8825 - loss: 0.5952 - val_categorical_accuracy: 0.8222 - val_loss: 0.8264 - learning_rate: 0.1000
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 46/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8822 - loss: 0.6004 - val_categorical_accuracy: 0.7247 - val_loss: 1.2001 - learning_rate: 0.1000
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 47/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8845 - loss: 0.5896 - val_categorical_accuracy: 0.7414 - val_loss: 1.2970 - learning_rate: 0.1000
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 48/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8859 - loss: 0.5868 - val_categorical_accuracy: 0.6853 - val_loss: 1.5393 - learning_rate: 0.1000
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 49/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8880 - loss: 0.5836 - val_categorical_accuracy: 0.7852 - val_loss: 0.9673 - learning_rate: 0.1000
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 50/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8873 - loss: 0.5859 - val_categorical_accuracy: 0.7198 - val_loss: 1.1695 - learning_rate: 0.1000
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 51/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8866 - loss: 0.5864 - val_categorical_accuracy: 0.7388 - val_loss: 1.2272 - learning_rate: 0.1000
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 52/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8870 - loss: 0.5870 - val_categorical_accuracy: 0.8026 - val_loss: 0.9093 - learning_rate: 0.1000
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 53/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8906 - loss: 0.5788 - val_categorical_accuracy: 0.8281 - val_loss: 0.8305 - learning_rate: 0.1000
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 54/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8903 - loss: 0.5793 - val_categorical_accuracy: 0.7782 - val_loss: 1.0894 - learning_rate: 0.1000
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 55/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8897 - loss: 0.5801 - val_categorical_accuracy: 0.7833 - val_loss: 1.0300 - learning_rate: 0.1000
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 56/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8907 - loss: 0.5783 - val_categorical_accuracy: 0.7928 - val_loss: 0.8984 - learning_rate: 0.1000
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 57/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8913 - loss: 0.5775 - val_categorical_accuracy: 0.7156 - val_loss: 1.3203 - learning_rate: 0.1000
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 58/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8944 - loss: 0.5705 - val_categorical_accuracy: 0.7482 - val_loss: 1.0991 - learning_rate: 0.1000
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 59/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8938 - loss: 0.5693 - val_categorical_accuracy: 0.7959 - val_loss: 0.9164 - learning_rate: 0.1000
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 60/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8905 - loss: 0.5766 - val_categorical_accuracy: 0.7811 - val_loss: 1.0460 - learning_rate: 0.1000
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 61/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8954 - loss: 0.5697 - val_categorical_accuracy: 0.7631 - val_loss: 1.0301 - learning_rate: 0.1000
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 62/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8928 - loss: 0.5775 - val_categorical_accuracy: 0.8142 - val_loss: 0.9267 - learning_rate: 0.1000
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 63/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8954 - loss: 0.5662 - val_categorical_accuracy: 0.8095 - val_loss: 0.8967 - learning_rate: 0.1000
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 64/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8965 - loss: 0.5642 - val_categorical_accuracy: 0.7867 - val_loss: 1.0396 - learning_rate: 0.1000
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 65/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8942 - loss: 0.5747 - val_categorical_accuracy: 0.8074 - val_loss: 0.8763 - learning_rate: 0.1000
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 66/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8980 - loss: 0.5655 - val_categorical_accuracy: 0.7546 - val_loss: 1.1656 - learning_rate: 0.1000
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 67/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8956 - loss: 0.5703 - val_categorical_accuracy: 0.8010 - val_loss: 0.9440 - learning_rate: 0.1000
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 68/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8959 - loss: 0.5680 - val_categorical_accuracy: 0.7892 - val_loss: 1.0070 - learning_rate: 0.1000
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 69/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8976 - loss: 0.5610 - val_categorical_accuracy: 0.7879 - val_loss: 0.9668 - learning_rate: 0.1000
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 70/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8983 - loss: 0.5651 - val_categorical_accuracy: 0.7897 - val_loss: 0.9609 - learning_rate: 0.1000
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 71/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8995 - loss: 0.5623 - val_categorical_accuracy: 0.7746 - val_loss: 1.0197 - learning_rate: 0.1000
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 72/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8960 - loss: 0.5669 - val_categorical_accuracy: 0.6615 - val_loss: 1.7749 - learning_rate: 0.1000
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 73/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8964 - loss: 0.5651 - val_categorical_accuracy: 0.7934 - val_loss: 1.0218 - learning_rate: 0.1000
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 74/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8993 - loss: 0.5618 - val_categorical_accuracy: 0.8093 - val_loss: 0.9000 - learning_rate: 0.1000
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 75/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9014 - loss: 0.5538 - val_categorical_accuracy: 0.7997 - val_loss: 1.0257 - learning_rate: 0.1000
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 76/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9008 - loss: 0.5572 - val_categorical_accuracy: 0.7893 - val_loss: 0.9807 - learning_rate: 0.1000
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 77/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9005 - loss: 0.5568 - val_categorical_accuracy: 0.8153 - val_loss: 0.8694 - learning_rate: 0.1000
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 78/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9009 - loss: 0.5548 - val_categorical_accuracy: 0.8049 - val_loss: 0.9531 - learning_rate: 0.1000
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 79/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8959 - loss: 0.5667 - val_categorical_accuracy: 0.7471 - val_loss: 1.2684 - learning_rate: 0.1000
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 80/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9016 - loss: 0.5580 - val_categorical_accuracy: 0.8398 - val_loss: 0.7852 - learning_rate: 0.1000
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 81/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9046 - loss: 0.5504 - val_categorical_accuracy: 0.8293 - val_loss: 0.8757 - learning_rate: 0.1000
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 82/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9013 - loss: 0.5626 - val_categorical_accuracy: 0.8459 - val_loss: 0.7930 - learning_rate: 0.1000
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 83/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9032 - loss: 0.5546 - val_categorical_accuracy: 0.7991 - val_loss: 0.9745 - learning_rate: 0.1000
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 84/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8999 - loss: 0.5608 - val_categorical_accuracy: 0.7993 - val_loss: 0.9802 - learning_rate: 0.1000
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 85/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9018 - loss: 0.5551 - val_categorical_accuracy: 0.8087 - val_loss: 0.9068 - learning_rate: 0.1000
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 86/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9008 - loss: 0.5639 - val_categorical_accuracy: 0.8183 - val_loss: 0.8911 - learning_rate: 0.1000
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 87/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9029 - loss: 0.5575 - val_categorical_accuracy: 0.7637 - val_loss: 1.1211 - learning_rate: 0.1000
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 88/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9044 - loss: 0.5530 - val_categorical_accuracy: 0.8007 - val_loss: 0.9041 - learning_rate: 0.1000
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 89/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9041 - loss: 0.5550 - val_categorical_accuracy: 0.8405 - val_loss: 0.7955 - learning_rate: 0.1000
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 90/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9031 - loss: 0.5554 - val_categorical_accuracy: 0.7842 - val_loss: 0.9564 - learning_rate: 0.1000
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 91/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9057 - loss: 0.5496 - val_categorical_accuracy: 0.7722 - val_loss: 1.0798 - learning_rate: 0.1000
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 92/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9054 - loss: 0.5498 - val_categorical_accuracy: 0.8030 - val_loss: 0.9385 - learning_rate: 0.1000
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 93/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9033 - loss: 0.5541 - val_categorical_accuracy: 0.7740 - val_loss: 1.0653 - learning_rate: 0.1000
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 94/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9042 - loss: 0.5488 - val_categorical_accuracy: 0.8060 - val_loss: 0.9308 - learning_rate: 0.1000
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 95/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9061 - loss: 0.5486 - val_categorical_accuracy: 0.8276 - val_loss: 0.8514 - learning_rate: 0.1000
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 96/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9057 - loss: 0.5478 - val_categorical_accuracy: 0.8135 - val_loss: 0.8997 - learning_rate: 0.1000
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 97/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9052 - loss: 0.5494 - val_categorical_accuracy: 0.8079 - val_loss: 0.9343 - learning_rate: 0.1000
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 98/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9055 - loss: 0.5483 - val_categorical_accuracy: 0.8166 - val_loss: 0.9182 - learning_rate: 0.1000
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 99/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9052 - loss: 0.5516 - val_categorical_accuracy: 0.8031 - val_loss: 0.9525 - learning_rate: 0.1000
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 100/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9068 - loss: 0.5474 - val_categorical_accuracy: 0.7787 - val_loss: 1.0138 - learning_rate: 0.1000
#
# Epoch 101: LearningRateScheduler setting learning rate to 0.010000000149011612.
# Epoch 101/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - categorical_accuracy: 0.9326 - loss: 0.4732 - val_categorical_accuracy: 0.8945 - val_loss: 0.6209 - learning_rate: 0.0100
#
# Epoch 102: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 102/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9526 - loss: 0.4120 - val_categorical_accuracy: 0.9002 - val_loss: 0.6116 - learning_rate: 0.0100
#
# Epoch 103: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 103/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9593 - loss: 0.3936 - val_categorical_accuracy: 0.9029 - val_loss: 0.5917 - learning_rate: 0.0100
#
# Epoch 104: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 104/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9630 - loss: 0.3784 - val_categorical_accuracy: 0.9047 - val_loss: 0.5979 - learning_rate: 0.0100
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 105/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9644 - loss: 0.3710 - val_categorical_accuracy: 0.9030 - val_loss: 0.5994 - learning_rate: 0.0100
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 106/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - categorical_accuracy: 0.9668 - loss: 0.3611 - val_categorical_accuracy: 0.9067 - val_loss: 0.5832 - learning_rate: 0.0100
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 107/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9683 - loss: 0.3534 - val_categorical_accuracy: 0.9062 - val_loss: 0.5887 - learning_rate: 0.0100
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 108/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9707 - loss: 0.3431 - val_categorical_accuracy: 0.9068 - val_loss: 0.5830 - learning_rate: 0.0100
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 109/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9716 - loss: 0.3364 - val_categorical_accuracy: 0.9074 - val_loss: 0.5844 - learning_rate: 0.0100
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 110/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9735 - loss: 0.3306 - val_categorical_accuracy: 0.9037 - val_loss: 0.6071 - learning_rate: 0.0100
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 111/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9741 - loss: 0.3250 - val_categorical_accuracy: 0.9049 - val_loss: 0.5934 - learning_rate: 0.0100
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 112/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9764 - loss: 0.3170 - val_categorical_accuracy: 0.9072 - val_loss: 0.5936 - learning_rate: 0.0100
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 113/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9765 - loss: 0.3132 - val_categorical_accuracy: 0.9056 - val_loss: 0.5876 - learning_rate: 0.0100
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 114/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9771 - loss: 0.3077 - val_categorical_accuracy: 0.9055 - val_loss: 0.5960 - learning_rate: 0.0100
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 115/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9786 - loss: 0.3032 - val_categorical_accuracy: 0.9058 - val_loss: 0.5990 - learning_rate: 0.0100
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 116/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9794 - loss: 0.2980 - val_categorical_accuracy: 0.9042 - val_loss: 0.5920 - learning_rate: 0.0100
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 117/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9786 - loss: 0.2954 - val_categorical_accuracy: 0.9047 - val_loss: 0.5937 - learning_rate: 0.0100
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 118/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9802 - loss: 0.2908 - val_categorical_accuracy: 0.9027 - val_loss: 0.6053 - learning_rate: 0.0100
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 119/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9821 - loss: 0.2823 - val_categorical_accuracy: 0.9055 - val_loss: 0.5885 - learning_rate: 0.0100
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 120/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9813 - loss: 0.2820 - val_categorical_accuracy: 0.9062 - val_loss: 0.5909 - learning_rate: 0.0100
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 121/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9832 - loss: 0.2751 - val_categorical_accuracy: 0.9042 - val_loss: 0.6008 - learning_rate: 0.0100
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 122/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9818 - loss: 0.2757 - val_categorical_accuracy: 0.9049 - val_loss: 0.6034 - learning_rate: 0.0100
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 123/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9836 - loss: 0.2683 - val_categorical_accuracy: 0.9088 - val_loss: 0.5900 - learning_rate: 0.0100
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 124/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9844 - loss: 0.2646 - val_categorical_accuracy: 0.9067 - val_loss: 0.5891 - learning_rate: 0.0100
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 125/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9843 - loss: 0.2618 - val_categorical_accuracy: 0.9036 - val_loss: 0.6088 - learning_rate: 0.0100
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 126/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9849 - loss: 0.2576 - val_categorical_accuracy: 0.9037 - val_loss: 0.6130 - learning_rate: 0.0100
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 127/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9843 - loss: 0.2564 - val_categorical_accuracy: 0.9034 - val_loss: 0.6017 - learning_rate: 0.0100
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 128/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9854 - loss: 0.2512 - val_categorical_accuracy: 0.9026 - val_loss: 0.6043 - learning_rate: 0.0100
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 129/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9854 - loss: 0.2500 - val_categorical_accuracy: 0.9039 - val_loss: 0.6019 - learning_rate: 0.0100
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 130/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9863 - loss: 0.2468 - val_categorical_accuracy: 0.9019 - val_loss: 0.6122 - learning_rate: 0.0100
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 131/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9858 - loss: 0.2442 - val_categorical_accuracy: 0.9066 - val_loss: 0.5897 - learning_rate: 0.0100
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 132/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9865 - loss: 0.2413 - val_categorical_accuracy: 0.9031 - val_loss: 0.6040 - learning_rate: 0.0100
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 133/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9867 - loss: 0.2375 - val_categorical_accuracy: 0.9030 - val_loss: 0.6082 - learning_rate: 0.0100
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 134/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9876 - loss: 0.2336 - val_categorical_accuracy: 0.9037 - val_loss: 0.6032 - learning_rate: 0.0100
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 135/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9887 - loss: 0.2288 - val_categorical_accuracy: 0.9022 - val_loss: 0.6119 - learning_rate: 0.0100
#
# Epoch 136: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 136/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9872 - loss: 0.2306 - val_categorical_accuracy: 0.9050 - val_loss: 0.6105 - learning_rate: 0.0100
#
# Epoch 137: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 137/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9885 - loss: 0.2258 - val_categorical_accuracy: 0.9016 - val_loss: 0.6054 - learning_rate: 0.0100
#
# Epoch 138: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 138/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9880 - loss: 0.2239 - val_categorical_accuracy: 0.8991 - val_loss: 0.6203 - learning_rate: 0.0100
#
# Epoch 139: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 139/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9891 - loss: 0.2192 - val_categorical_accuracy: 0.9047 - val_loss: 0.6046 - learning_rate: 0.0100
#
# Epoch 140: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 140/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9893 - loss: 0.2184 - val_categorical_accuracy: 0.8997 - val_loss: 0.6107 - learning_rate: 0.0100
#
# Epoch 141: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 141/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9881 - loss: 0.2176 - val_categorical_accuracy: 0.9008 - val_loss: 0.6163 - learning_rate: 0.0100
#
# Epoch 142: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 142/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9888 - loss: 0.2142 - val_categorical_accuracy: 0.9044 - val_loss: 0.6092 - learning_rate: 0.0100
#
# Epoch 143: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 143/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9890 - loss: 0.2121 - val_categorical_accuracy: 0.9004 - val_loss: 0.6135 - learning_rate: 0.0100
#
# Epoch 144: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 144/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9888 - loss: 0.2114 - val_categorical_accuracy: 0.9014 - val_loss: 0.6149 - learning_rate: 0.0100
#
# Epoch 145: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 145/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9884 - loss: 0.2094 - val_categorical_accuracy: 0.9000 - val_loss: 0.6250 - learning_rate: 0.0100
#
# Epoch 146: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 146/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9898 - loss: 0.2058 - val_categorical_accuracy: 0.9014 - val_loss: 0.6214 - learning_rate: 0.0100
#
# Epoch 147: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 147/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9892 - loss: 0.2044 - val_categorical_accuracy: 0.9006 - val_loss: 0.6204 - learning_rate: 0.0100
#
# Epoch 148: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 148/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9895 - loss: 0.2026 - val_categorical_accuracy: 0.9015 - val_loss: 0.6019 - learning_rate: 0.0100
#
# Epoch 149: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 149/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9902 - loss: 0.2002 - val_categorical_accuracy: 0.8996 - val_loss: 0.6122 - learning_rate: 0.0100
#
# Epoch 150: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 150/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9901 - loss: 0.1980 - val_categorical_accuracy: 0.9032 - val_loss: 0.6233 - learning_rate: 0.0100
#
# Epoch 151: LearningRateScheduler setting learning rate to 0.0009999999776482583.
# Epoch 151/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9915 - loss: 0.1937 - val_categorical_accuracy: 0.9061 - val_loss: 0.5905 - learning_rate: 1.0000e-03
#
# Epoch 152: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 152/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9931 - loss: 0.1888 - val_categorical_accuracy: 0.9071 - val_loss: 0.5899 - learning_rate: 1.0000e-03
#
# Epoch 153: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 153/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.9931 - loss: 0.1890 - val_categorical_accuracy: 0.9075 - val_loss: 0.5825 - learning_rate: 1.0000e-03
#
# Epoch 154: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 154/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9936 - loss: 0.1868 - val_categorical_accuracy: 0.9092 - val_loss: 0.5783 - learning_rate: 1.0000e-03
#
# Epoch 155: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 155/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9945 - loss: 0.1856 - val_categorical_accuracy: 0.9095 - val_loss: 0.5809 - learning_rate: 1.0000e-03
#
# Epoch 156: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 156/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.9945 - loss: 0.1846 - val_categorical_accuracy: 0.9097 - val_loss: 0.5767 - learning_rate: 1.0000e-03
#
# Epoch 157: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 157/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9943 - loss: 0.1844 - val_categorical_accuracy: 0.9101 - val_loss: 0.5771 - learning_rate: 1.0000e-03
#
# Epoch 158: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 158/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9947 - loss: 0.1836 - val_categorical_accuracy: 0.9106 - val_loss: 0.5729 - learning_rate: 1.0000e-03
#
# Epoch 159: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 159/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9947 - loss: 0.1834 - val_categorical_accuracy: 0.9075 - val_loss: 0.5771 - learning_rate: 1.0000e-03
#
# Epoch 160: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 160/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9946 - loss: 0.1831 - val_categorical_accuracy: 0.9079 - val_loss: 0.5769 - learning_rate: 1.0000e-03
#
# Epoch 161: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 161/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9950 - loss: 0.1826 - val_categorical_accuracy: 0.9079 - val_loss: 0.5786 - learning_rate: 1.0000e-03
#
# Epoch 162: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 162/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9950 - loss: 0.1825 - val_categorical_accuracy: 0.9072 - val_loss: 0.5824 - learning_rate: 1.0000e-03
#
# Epoch 163: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 163/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9953 - loss: 0.1815 - val_categorical_accuracy: 0.9091 - val_loss: 0.5750 - learning_rate: 1.0000e-03
#
# Epoch 164: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 164/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9956 - loss: 0.1802 - val_categorical_accuracy: 0.9091 - val_loss: 0.5766 - learning_rate: 1.0000e-03
#
# Epoch 165: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 165/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9952 - loss: 0.1806 - val_categorical_accuracy: 0.9077 - val_loss: 0.5793 - learning_rate: 1.0000e-03
#
# Epoch 166: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 166/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1803 - val_categorical_accuracy: 0.9080 - val_loss: 0.5800 - learning_rate: 1.0000e-03
#
# Epoch 167: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 167/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9943 - loss: 0.1817 - val_categorical_accuracy: 0.9082 - val_loss: 0.5771 - learning_rate: 1.0000e-03
#
# Epoch 168: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 168/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1796 - val_categorical_accuracy: 0.9079 - val_loss: 0.5786 - learning_rate: 1.0000e-03
#
# Epoch 169: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 169/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9952 - loss: 0.1798 - val_categorical_accuracy: 0.9064 - val_loss: 0.5759 - learning_rate: 1.0000e-03
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 170/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9950 - loss: 0.1795 - val_categorical_accuracy: 0.9077 - val_loss: 0.5793 - learning_rate: 1.0000e-03
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 171/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9950 - loss: 0.1803 - val_categorical_accuracy: 0.9099 - val_loss: 0.5765 - learning_rate: 1.0000e-03
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 172/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1778 - val_categorical_accuracy: 0.9067 - val_loss: 0.5792 - learning_rate: 1.0000e-03
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 173/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9957 - loss: 0.1784 - val_categorical_accuracy: 0.9065 - val_loss: 0.5776 - learning_rate: 1.0000e-03
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 174/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1768 - val_categorical_accuracy: 0.9089 - val_loss: 0.5819 - learning_rate: 1.0000e-03
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 175/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9954 - loss: 0.1781 - val_categorical_accuracy: 0.9093 - val_loss: 0.5836 - learning_rate: 1.0000e-03
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 176/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9952 - loss: 0.1778 - val_categorical_accuracy: 0.9082 - val_loss: 0.5796 - learning_rate: 1.0000e-03
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 177/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1772 - val_categorical_accuracy: 0.9096 - val_loss: 0.5754 - learning_rate: 1.0000e-03
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 178/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1771 - val_categorical_accuracy: 0.9066 - val_loss: 0.5796 - learning_rate: 1.0000e-03
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 179/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1767 - val_categorical_accuracy: 0.9067 - val_loss: 0.5821 - learning_rate: 1.0000e-03
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 180/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1754 - val_categorical_accuracy: 0.9094 - val_loss: 0.5817 - learning_rate: 1.0000e-03
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 181/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9957 - loss: 0.1760 - val_categorical_accuracy: 0.9076 - val_loss: 0.5806 - learning_rate: 1.0000e-03
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 182/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9957 - loss: 0.1760 - val_categorical_accuracy: 0.9065 - val_loss: 0.5833 - learning_rate: 1.0000e-03
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 183/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1752 - val_categorical_accuracy: 0.9083 - val_loss: 0.5778 - learning_rate: 1.0000e-03
#
# Epoch 184: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 184/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9957 - loss: 0.1758 - val_categorical_accuracy: 0.9088 - val_loss: 0.5867 - learning_rate: 1.0000e-03
#
# Epoch 185: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 185/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9960 - loss: 0.1738 - val_categorical_accuracy: 0.9097 - val_loss: 0.5794 - learning_rate: 1.0000e-03
#
# Epoch 186: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 186/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1736 - val_categorical_accuracy: 0.9093 - val_loss: 0.5839 - learning_rate: 1.0000e-03
#
# Epoch 187: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 187/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1745 - val_categorical_accuracy: 0.9101 - val_loss: 0.5757 - learning_rate: 1.0000e-03
#
# Epoch 188: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 188/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1738 - val_categorical_accuracy: 0.9095 - val_loss: 0.5781 - learning_rate: 1.0000e-03
#
# Epoch 189: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 189/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1729 - val_categorical_accuracy: 0.9094 - val_loss: 0.5793 - learning_rate: 1.0000e-03
#
# Epoch 190: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 190/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1733 - val_categorical_accuracy: 0.9082 - val_loss: 0.5790 - learning_rate: 1.0000e-03
#
# Epoch 191: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 191/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1730 - val_categorical_accuracy: 0.9070 - val_loss: 0.5831 - learning_rate: 1.0000e-03
#
# Epoch 192: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 192/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1732 - val_categorical_accuracy: 0.9083 - val_loss: 0.5809 - learning_rate: 1.0000e-03
#
# Epoch 193: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 193/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1742 - val_categorical_accuracy: 0.9078 - val_loss: 0.5841 - learning_rate: 1.0000e-03
#
# Epoch 194: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 194/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1720 - val_categorical_accuracy: 0.9085 - val_loss: 0.5739 - learning_rate: 1.0000e-03
#
# Epoch 195: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 195/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1722 - val_categorical_accuracy: 0.9086 - val_loss: 0.5815 - learning_rate: 1.0000e-03
#
# Epoch 196: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 196/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1716 - val_categorical_accuracy: 0.9088 - val_loss: 0.5769 - learning_rate: 1.0000e-03
#
# Epoch 197: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 197/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1714 - val_categorical_accuracy: 0.9086 - val_loss: 0.5777 - learning_rate: 1.0000e-03
#
# Epoch 198: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 198/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1706 - val_categorical_accuracy: 0.9115 - val_loss: 0.5737 - learning_rate: 1.0000e-03
#
# Epoch 199: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 199/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1703 - val_categorical_accuracy: 0.9067 - val_loss: 0.5802 - learning_rate: 1.0000e-03
#
# Epoch 200: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 200/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1708 - val_categorical_accuracy: 0.9087 - val_loss: 0.5757 - learning_rate: 1.0000e-03
#
# Initial VIB single-sample test loss: 0.5650  Initial VIB single-sample test accuracy: 0.9065

# %%
# Plotting initial VIB training curves

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

## Plot 1
ax1.plot(history.history["loss"], label="train loss")
ax1.plot(history.history["val_loss"], label="val loss")
ax1.set_xlabel("epoch"); ax1.set_ylabel("loss")
ax1.set_title("Initial VIB ResNet-20 — Loss"); ax1.legend()

## Plot 2
ax2.plot(history.history["categorical_accuracy"], label="train acc")
ax2.plot(history.history["val_categorical_accuracy"], label="val acc")
ax2.set_xlabel("epoch"); ax2.set_ylabel("accuracy")
ax2.set_title("Initial VIB ResNet-20 — Accuracy"); ax2.legend()
plt.tight_layout(); plt.show()

# %%
# SWAG helper functions
'''
SWAG is fit after the initial VIB training run. We keep the architecture fixed,
continue training with a constant learning rate, and collect parameter snapshots.

For stability, only trainable variables are sampled. BatchNorm moving means and
moving variances are left at the values learned during SWAG collection. This is
a small practical deviation from sampling every array in model.get_weights(),
because directly sampling BatchNorm moving variances can create negative values.
'''

def flatten_trainable_variables(model):
    return np.concatenate([v.numpy().ravel() for v in model.trainable_variables]).astype("float32")


def set_trainable_variables_from_vector(model, vector):
    pointer = 0
    for variable in model.trainable_variables:
        shape = variable.shape
        size = int(np.prod(shape))
        new_value = vector[pointer:pointer + size].reshape(shape)
        variable.assign(new_value)
        pointer += size

    if pointer != len(vector):
        raise ValueError("Vector length did not match the model's trainable variables.")


def fit_swag_distribution(snapshots):
    snapshots = np.asarray(snapshots, dtype="float32")
    if snapshots.ndim != 2 or snapshots.shape[0] < 2:
        raise ValueError("Need at least two SWAG snapshots to estimate covariance.")

    mean = snapshots.mean(axis=0)
    diag_var = snapshots.var(axis=0, ddof=1)

    ### Low-rank deviations are centred on the *running* mean up to each snapshot
    ### (the Maddox et al. 2019 construction), matching the SWAG-alone notebook.
    ### Centring on the final mean instead systematically overstates the spread.
    deviations = np.empty_like(snapshots)
    for i in range(snapshots.shape[0]):
        deviations[i] = snapshots[i] - snapshots[:i + 1].mean(axis=0)

    return {"mean": mean,
            "diag_var": diag_var,
            "deviations": deviations,
            "n_snapshots": snapshots.shape[0]}


def sample_swag_weights(swag, rng=None, diag_scale=1.0, low_rank_scale=1.0):
    if rng is None:
        rng = np.random.default_rng()

    mean = swag["mean"]
    diag_var = swag["diag_var"]
    deviations = swag["deviations"]
    k = swag["n_snapshots"]

    ### SWAG commonly uses a 1/sqrt(2) split between diagonal and low-rank parts.
    diag_sample = np.sqrt(0.5) * diag_scale * np.sqrt(diag_var + 1e-30) * rng.normal(size=mean.shape)
    low_rank_sample = np.sqrt(0.5) * low_rank_scale * deviations.T @ rng.normal(size=k) / np.sqrt(k - 1)

    return (mean + diag_sample + low_rank_sample).astype("float32")


class SWAGSnapshotCallback(keras.callbacks.Callback):

    def __init__(self, collect_every=2):
        super().__init__()
        self.collect_every = collect_every
        self.snapshots = []

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.collect_every == 0:
            self.snapshots.append(flatten_trainable_variables(self.model))
            print(f"SWAG snapshot {len(self.snapshots)} collected at SWAG epoch {epoch + 1}")


def _all_batchnorm_layers(model):
    """Recursively collect every BatchNormalization layer, including those nested
    inside custom layers (e.g. ResidualBlock). Avoids model.submodules, which is
    not exposed on Functional models in current Keras versions."""
    seen, stack, found = set(), [model], []
    while stack:
        obj = stack.pop()
        if id(obj) in seen:
            continue
        seen.add(id(obj))
        if isinstance(obj, keras.layers.BatchNormalization):
            found.append(obj)
        subs = []
        for attr in ("layers", "_layers"):
            v = getattr(obj, attr, None)
            if v:
                try:
                    subs.extend(list(v))
                except TypeError:
                    pass
        for a in getattr(obj, "__dict__", {}).values():
            if isinstance(a, keras.layers.Layer):
                subs.append(a)
            elif isinstance(a, (list, tuple)):
                subs.extend(x for x in a if isinstance(x, keras.layers.Layer))
        stack.extend(subs)
    out, s2 = [], set()
    for b in found:
        if id(b) not in s2:
            s2.add(id(b)); out.append(b)
    return out


def recalibrate_batchnorm(model, recal_dataset, num_batches=200):
    """Re-estimate BatchNorm moving statistics for the model's CURRENT weights.

    SWAG-sampled weights do not match the BatchNorm running statistics learned
    during training (those belong to the SWA-mean weights). Evaluating with
    mismatched normalisation degrades accuracy and inflates apparent weight
    disagreement. We therefore reset the moving statistics and recompute them
    with a *cumulative* average over training data, taking no gradient steps.

    Setting each BN layer's momentum to i/(i+1) on the i-th batch turns Keras'
    exponential moving average into an exact running mean:
        i=0 -> momentum 0  -> moving = batch_0
        i=1 -> momentum 1/2 -> moving = (batch_0 + batch_1) / 2  ...
    so the reset values never leak into the final estimate. Original momenta are
    restored afterwards. This is the standard SWAG-with-BatchNorm procedure
    (Maddox et al. 2019).
    """
    bn_layers = _all_batchnorm_layers(model)
    original_momenta = [bn.momentum for bn in bn_layers]

    for bn in bn_layers:
        bn.moving_mean.assign(tf.zeros_like(bn.moving_mean))
        bn.moving_variance.assign(tf.ones_like(bn.moving_variance))

    for i, batch in enumerate(recal_dataset):
        if num_batches is not None and i >= num_batches:
            break
        x_batch = batch[0] if isinstance(batch, (tuple, list)) else batch
        for bn in bn_layers:
            bn.momentum = i / (i + 1.0)
        model(x_batch, training=True)   # updates BN running stats only; no optimiser step

    for bn, mom in zip(bn_layers, original_momenta):
        bn.momentum = mom

# %%
# SWAG collection training
'''
After initial VIB convergence, we switch to a constant learning rate and keep
training with the same VIB loss. Every c epochs, we take a trainable-weight
snapshot. These snapshots define the SWAG mean, diagonal variance and low-rank
covariance directions.
'''

swag_learning_rate = 0.001  # was 0.01; matches the validated SWAG-alone collection LR (higher rates over-inflate the posterior)
swag_epochs = 40
swag_collect_every = 2

swag_callback = SWAGSnapshotCallback(collect_every=swag_collect_every)

model.compile(optimizer=keras.optimizers.SGD(learning_rate=swag_learning_rate, momentum=0.9),
              loss=keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=["categorical_accuracy"])

swag_history = model.fit(train_ds,
                         epochs=swag_epochs,
                         validation_data=val_ds,
                         callbacks=[swag_callback])

swag = fit_swag_distribution(swag_callback.snapshots)
set_trainable_variables_from_vector(model, swag["mean"])
model.save_weights("vib_swag_mean.weights.h5")

print(f"Collected {swag['n_snapshots']} SWAG snapshots")
print(f"SWAG parameter dimension: {swag['mean'].shape[0]}")
# Out:
# Epoch 1/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - categorical_accuracy: 0.9948 - loss: 0.1834 - val_categorical_accuracy: 0.9084 - val_loss: 0.5757
# Epoch 2/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9941 - loss: 0.1847SWAG snapshot 1 collected at SWAG epoch 2
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9941 - loss: 0.1839 - val_categorical_accuracy: 0.9080 - val_loss: 0.5829
# Epoch 3/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9944 - loss: 0.1836 - val_categorical_accuracy: 0.9083 - val_loss: 0.5741
# Epoch 4/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9952 - loss: 0.1822SWAG snapshot 2 collected at SWAG epoch 4
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9952 - loss: 0.1825 - val_categorical_accuracy: 0.9074 - val_loss: 0.5840
# Epoch 5/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9956 - loss: 0.1810 - val_categorical_accuracy: 0.9075 - val_loss: 0.5809
# Epoch 6/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9953 - loss: 0.1815SWAG snapshot 3 collected at SWAG epoch 6
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9952 - loss: 0.1816 - val_categorical_accuracy: 0.9071 - val_loss: 0.5799
# Epoch 7/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9953 - loss: 0.1801 - val_categorical_accuracy: 0.9086 - val_loss: 0.5768
# Epoch 8/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9950 - loss: 0.1816SWAG snapshot 4 collected at SWAG epoch 8
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9950 - loss: 0.1812 - val_categorical_accuracy: 0.9086 - val_loss: 0.5816
# Epoch 9/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9951 - loss: 0.1806 - val_categorical_accuracy: 0.9080 - val_loss: 0.5796
# Epoch 10/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9959 - loss: 0.1800SWAG snapshot 5 collected at SWAG epoch 10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1803 - val_categorical_accuracy: 0.9083 - val_loss: 0.5836
# Epoch 11/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9955 - loss: 0.1800 - val_categorical_accuracy: 0.9088 - val_loss: 0.5806
# Epoch 12/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9953 - loss: 0.1791SWAG snapshot 6 collected at SWAG epoch 12
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9952 - loss: 0.1793 - val_categorical_accuracy: 0.9087 - val_loss: 0.5807
# Epoch 13/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9958 - loss: 0.1786 - val_categorical_accuracy: 0.9090 - val_loss: 0.5808
# Epoch 14/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9950 - loss: 0.1785SWAG snapshot 7 collected at SWAG epoch 14
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9952 - loss: 0.1788 - val_categorical_accuracy: 0.9087 - val_loss: 0.5809
# Epoch 15/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1773 - val_categorical_accuracy: 0.9092 - val_loss: 0.5798
# Epoch 16/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9952 - loss: 0.1798SWAG snapshot 8 collected at SWAG epoch 16
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9953 - loss: 0.1791 - val_categorical_accuracy: 0.9086 - val_loss: 0.5830
# Epoch 17/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1776 - val_categorical_accuracy: 0.9078 - val_loss: 0.5822
# Epoch 18/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9952 - loss: 0.1776SWAG snapshot 9 collected at SWAG epoch 18
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9957 - loss: 0.1770 - val_categorical_accuracy: 0.9069 - val_loss: 0.5803
# Epoch 19/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9957 - loss: 0.1772 - val_categorical_accuracy: 0.9083 - val_loss: 0.5763
# Epoch 20/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9962 - loss: 0.1760SWAG snapshot 10 collected at SWAG epoch 20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1757 - val_categorical_accuracy: 0.9096 - val_loss: 0.5798
# Epoch 21/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9964 - loss: 0.1759 - val_categorical_accuracy: 0.9089 - val_loss: 0.5776
# Epoch 22/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9959 - loss: 0.1757SWAG snapshot 11 collected at SWAG epoch 22
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1754 - val_categorical_accuracy: 0.9089 - val_loss: 0.5827
# Epoch 23/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1759 - val_categorical_accuracy: 0.9082 - val_loss: 0.5785
# Epoch 24/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9965 - loss: 0.1751SWAG snapshot 12 collected at SWAG epoch 24
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9958 - loss: 0.1755 - val_categorical_accuracy: 0.9067 - val_loss: 0.5833
# Epoch 25/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9963 - loss: 0.1746 - val_categorical_accuracy: 0.9079 - val_loss: 0.5776
# Epoch 26/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9955 - loss: 0.1755SWAG snapshot 13 collected at SWAG epoch 26
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1760 - val_categorical_accuracy: 0.9086 - val_loss: 0.5819
# Epoch 27/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1738 - val_categorical_accuracy: 0.9081 - val_loss: 0.5768
# Epoch 28/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9950 - loss: 0.1769SWAG snapshot 14 collected at SWAG epoch 28
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9952 - loss: 0.1767 - val_categorical_accuracy: 0.9090 - val_loss: 0.5825
# Epoch 29/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9958 - loss: 0.1745 - val_categorical_accuracy: 0.9084 - val_loss: 0.5783
# Epoch 30/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9953 - loss: 0.1759SWAG snapshot 15 collected at SWAG epoch 30
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9956 - loss: 0.1752 - val_categorical_accuracy: 0.9084 - val_loss: 0.5807
# Epoch 31/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1736 - val_categorical_accuracy: 0.9081 - val_loss: 0.5821
# Epoch 32/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9959 - loss: 0.1742SWAG snapshot 16 collected at SWAG epoch 32
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9964 - loss: 0.1732 - val_categorical_accuracy: 0.9063 - val_loss: 0.5843
# Epoch 33/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1727 - val_categorical_accuracy: 0.9094 - val_loss: 0.5794
# Epoch 34/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9964 - loss: 0.1727SWAG snapshot 17 collected at SWAG epoch 34
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9968 - loss: 0.1723 - val_categorical_accuracy: 0.9092 - val_loss: 0.5769
# Epoch 35/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1718 - val_categorical_accuracy: 0.9089 - val_loss: 0.5842
# Epoch 36/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9963 - loss: 0.1719SWAG snapshot 18 collected at SWAG epoch 36
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9967 - loss: 0.1715 - val_categorical_accuracy: 0.9068 - val_loss: 0.5786
# Epoch 37/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9963 - loss: 0.1723 - val_categorical_accuracy: 0.9095 - val_loss: 0.5776
# Epoch 38/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9966 - loss: 0.1721SWAG snapshot 19 collected at SWAG epoch 38
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1721 - val_categorical_accuracy: 0.9079 - val_loss: 0.5794
# Epoch 39/40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9964 - loss: 0.1709 - val_categorical_accuracy: 0.9097 - val_loss: 0.5759
# Epoch 40/40
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9959 - loss: 0.1723SWAG snapshot 20 collected at SWAG epoch 40
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9958 - loss: 0.1722 - val_categorical_accuracy: 0.9087 - val_loss: 0.5823
# Collected 20 SWAG snapshots
# SWAG parameter dimension: 281578

# %%
# Loading SVHN as the out-of-distribution reference set
'''
Per the proposal §3.5, SVHN (street view of house numbers) is used as the
OOD test set. SVHN images are 32x32 colour photos like CIFAR-10, but of
digits, so a CIFAR-10 trained model should ideally report higher predictive
entropy on SVHN inputs than on its in-distribution CIFAR-10 test images.

We download the official SVHN test split (.mat) directly instead of using
tensorflow_datasets, which removes a flaky lazy-import dependency from the
pipeline. The ~26k images rescale to [0, 1] to match CIFAR-10 preprocessing.
The file caches in the working directory (Drive) after the first download.
'''
import os, urllib.request
from scipy.io import loadmat

svhn_path = "svhn_test_32x32.mat"
if not os.path.exists(svhn_path):
    urllib.request.urlretrieve(
        "http://ufldl.stanford.edu/housenumbers/test_32x32.mat", svhn_path)

mat = loadmat(svhn_path)
# mat["X"] has shape (32, 32, 3, N); move the sample axis to the front, rescale.
x_svhn = np.transpose(mat["X"], (3, 0, 1, 2)).astype("float32") / 255.0

print(f"SVHN OOD set: {x_svhn.shape}")   # expect (26032, 32, 32, 3)
# Out:
# SVHN OOD set: (26032, 32, 32, 3)

# %%
# Loading CIFAR-10-C (common corruptions) as the in-distribution shift set
'''
Per the proposal §3.5, CIFAR-10-C (Hendrycks & Dietterich 2019) is the
corruption / covariate-shift evaluation set: the same 10 CIFAR-10 classes but
with algorithmic corruptions at graded severity. Unlike SVHN (far / semantic
OOD), these are in-domain-but-degraded inputs, so they probe a different kind
of uncertainty.

Patched folder handling:
- verifies labels.npy and every expected corruption .npy file;
- repairs partial extractions by re-extracting CIFAR-10-C.tar;
- re-downloads the tar if it is missing, invalid, or incomplete;
- raises a clear error listing missing files if the folder is still incomplete.
'''
import os, urllib.request, tarfile
import numpy as np

SEVERITY = globals().get("SEVERITY", 3)
CORRUPTIONS = globals().get("CORRUPTIONS", [
    "gaussian_noise", "shot_noise", "impulse_noise", "defocus_blur",
    "glass_blur", "motion_blur", "zoom_blur", "snow", "frost", "fog",
    "brightness", "contrast", "elastic_transform", "pixelate", "jpeg_compression",
])

CIFAR10C_ROOT = "CIFAR-10-C"
CIFAR10C_TAR = "CIFAR-10-C.tar"
CIFAR10C_URLS = [
    "https://zenodo.org/records/2535967/files/CIFAR-10-C.tar?download=1",
    "https://zenodo.org/record/2535967/files/CIFAR-10-C.tar",
]


def _required_cifar10c_files(corruptions=CORRUPTIONS):
    return ["labels.npy"] + [f"{corr}.npy" for corr in corruptions]


def _cifar10c_score(root, corruptions=CORRUPTIONS):
    try:
        file_set = set(os.listdir(root))
    except OSError:
        return 0
    required = set(_required_cifar10c_files(corruptions))
    return len(required.intersection(file_set))


def _find_cifar10c_root(start=".", corruptions=CORRUPTIONS):
    """Return the directory that best looks like the extracted CIFAR-10-C root."""
    required = set(_required_cifar10c_files(corruptions))
    candidates = []

    # Fast-path the expected folder first.
    if os.path.isdir(CIFAR10C_ROOT):
        candidates.append((_cifar10c_score(CIFAR10C_ROOT, corruptions), CIFAR10C_ROOT))

    # Then support nested layouts produced by some archive/extraction tools.
    for root, dirs, files in os.walk(start):
        # Avoid descending into hidden/checkpoint folders, which can make Drive scans noisy.
        dirs[:] = [d for d in dirs if not d.startswith(".") and d != "__MACOSX"]
        file_set = set(files)
        if "labels.npy" in file_set or any(f"{corr}.npy" in file_set for corr in corruptions):
            candidates.append((len(required.intersection(file_set)), root))

    if not candidates:
        return CIFAR10C_ROOT

    candidates.sort(key=lambda item: item[0], reverse=True)
    return candidates[0][1]


def _missing_cifar10c_files(root, corruptions=CORRUPTIONS):
    return [
        filename
        for filename in _required_cifar10c_files(corruptions)
        if not os.path.exists(os.path.join(root, filename))
    ]


def _safe_extract_tar(tar, path="."):
    """Protect against path traversal before extracting the downloaded tar."""
    base = os.path.abspath(path)
    for member in tar.getmembers():
        member_path = os.path.abspath(os.path.join(path, member.name))
        if not (member_path == base or member_path.startswith(base + os.sep)):
            raise RuntimeError(f"Unsafe path in tar archive: {member.name}")
    tar.extractall(path)


def _download_cifar10c_tar(tar_path=CIFAR10C_TAR, urls=CIFAR10C_URLS):
    last_error = None
    for url in urls:
        try:
            print(f"Downloading CIFAR-10-C from {url}")
            urllib.request.urlretrieve(url, tar_path)
            return
        except Exception as exc:
            last_error = exc
            print(f"Download failed from {url}: {exc}")

    raise RuntimeError("Could not download CIFAR-10-C from any configured URL.") from last_error


def _extract_cifar10c_tar(tar_path=CIFAR10C_TAR):
    try:
        with tarfile.open(tar_path) as tar:
            _safe_extract_tar(tar, ".")
    except (tarfile.TarError, EOFError) as exc:
        print("Existing CIFAR-10-C tar is invalid or incomplete; re-downloading.")
        if os.path.exists(tar_path):
            os.remove(tar_path)
        _download_cifar10c_tar(tar_path)
        with tarfile.open(tar_path) as tar:
            _safe_extract_tar(tar, ".")


def load_cifar10c(severity=SEVERITY, corruptions=CORRUPTIONS, root=CIFAR10C_ROOT):
    """Download/extract CIFAR-10-C if needed, verify all files, then load one severity."""
    if not (1 <= int(severity) <= 5):
        raise ValueError("CIFAR-10-C severity must be an integer from 1 to 5.")
    severity = int(severity)

    root = _find_cifar10c_root(root, corruptions)
    missing = _missing_cifar10c_files(root, corruptions)

    if missing:
        print(f"CIFAR-10-C is incomplete at '{root}'. Missing {len(missing)} file(s): {missing[:5]}")
        if not os.path.exists(CIFAR10C_TAR):
            print("CIFAR-10-C tar is not present; downloading it now (~2.9 GB).")
            _download_cifar10c_tar(CIFAR10C_TAR)
        else:
            print("CIFAR-10-C tar already exists; re-extracting it to repair the dataset.")

        _extract_cifar10c_tar(CIFAR10C_TAR)
        root = _find_cifar10c_root(root, corruptions)
        missing = _missing_cifar10c_files(root, corruptions)

    if missing:
        raise FileNotFoundError(
            "CIFAR-10-C is still incomplete after extraction. "
            f"Root checked: '{root}'. Missing files include: {missing[:10]}. "
            "Delete CIFAR-10-C and CIFAR-10-C.tar, then rerun this cell."
        )

    lo, hi = (severity - 1) * 10000, severity * 10000
    labels_full = np.load(os.path.join(root, "labels.npy"))
    labels_block = labels_full[lo:hi] if labels_full.shape[0] > 10000 else labels_full

    x_parts, y_parts = [], []
    for corr in corruptions:
        path = os.path.join(root, f"{corr}.npy")
        arr = np.load(path)[lo:hi]    # (10000, 32, 32, 3) uint8
        x_parts.append(arr)
        y_parts.append(labels_block)

    x_cifar10c = np.concatenate(x_parts, axis=0).astype("float32") / 255.0
    labels_cifar10c = np.concatenate(y_parts, axis=0).astype("int64")

    print(
        f"CIFAR-10-C set (severity {severity}, {len(corruptions)} corruptions): "
        f"{x_cifar10c.shape}, labels {labels_cifar10c.shape}"
    )
    print(f"CIFAR-10-C root: {root}")

    return x_cifar10c, labels_cifar10c


# Execute the load in this cell so Run all prepares CIFAR-10-C before prediction.
x_cifar10c, labels_cifar10c = load_cifar10c(SEVERITY, CORRUPTIONS)
# Out:
# CIFAR-10-C set (severity 3, 15 corruptions): (150000, 32, 32, 3), labels (150000,)
# CIFAR-10-C root: CIFAR-10-C

# %%
# Generating VIB-SWAG predictions and uncertainty decomposition
'''
This is the full proposal design: for each input, we sample S weight
configurations from SWAG. For each sampled weight configuration, we sample M
representations from the VIB bottleneck. This gives an (S, M, N, 10) probability
array.

The decomposition follows the proposal:
- total uncertainty: entropy of the full averaged predictive distribution,
- weight-epistemic: disagreement between SWAG weight samples,
- bottleneck / representation-level: disagreement between z samples for fixed weights,
- residual: remaining expected entropy with both weights and z fixed.
'''


# Guard: load CIFAR-10-C here if the dedicated loading cell was skipped.
# This prevents this notebook from producing results without CIFAR-10-C outputs.
if "x_cifar10c" not in globals() or "labels_cifar10c" not in globals():
    print("CIFAR-10-C was not loaded before prediction; loading it now.")
    if "load_cifar10c" not in globals():
        import os, urllib.request, tarfile
        import numpy as np

        SEVERITY = globals().get("SEVERITY", 3)
        CORRUPTIONS = globals().get("CORRUPTIONS", [
            "gaussian_noise", "shot_noise", "impulse_noise", "defocus_blur",
            "glass_blur", "motion_blur", "zoom_blur", "snow", "frost", "fog",
            "brightness", "contrast", "elastic_transform", "pixelate", "jpeg_compression",
        ])

        CIFAR10C_ROOT = "CIFAR-10-C"
        CIFAR10C_TAR = "CIFAR-10-C.tar"
        CIFAR10C_URLS = [
            "https://zenodo.org/records/2535967/files/CIFAR-10-C.tar?download=1",
            "https://zenodo.org/record/2535967/files/CIFAR-10-C.tar",
        ]


        def _required_cifar10c_files(corruptions=CORRUPTIONS):
            return ["labels.npy"] + [f"{corr}.npy" for corr in corruptions]


        def _cifar10c_score(root, corruptions=CORRUPTIONS):
            try:
                file_set = set(os.listdir(root))
            except OSError:
                return 0
            required = set(_required_cifar10c_files(corruptions))
            return len(required.intersection(file_set))


        def _find_cifar10c_root(start=".", corruptions=CORRUPTIONS):
            """Return the directory that best looks like the extracted CIFAR-10-C root."""
            required = set(_required_cifar10c_files(corruptions))
            candidates = []

            # Fast-path the expected folder first.
            if os.path.isdir(CIFAR10C_ROOT):
                candidates.append((_cifar10c_score(CIFAR10C_ROOT, corruptions), CIFAR10C_ROOT))

            # Then support nested layouts produced by some archive/extraction tools.
            for root, dirs, files in os.walk(start):
                # Avoid descending into hidden/checkpoint folders, which can make Drive scans noisy.
                dirs[:] = [d for d in dirs if not d.startswith(".") and d != "__MACOSX"]
                file_set = set(files)
                if "labels.npy" in file_set or any(f"{corr}.npy" in file_set for corr in corruptions):
                    candidates.append((len(required.intersection(file_set)), root))

            if not candidates:
                return CIFAR10C_ROOT

            candidates.sort(key=lambda item: item[0], reverse=True)
            return candidates[0][1]


        def _missing_cifar10c_files(root, corruptions=CORRUPTIONS):
            return [
                filename
                for filename in _required_cifar10c_files(corruptions)
                if not os.path.exists(os.path.join(root, filename))
            ]


        def _safe_extract_tar(tar, path="."):
            """Protect against path traversal before extracting the downloaded tar."""
            base = os.path.abspath(path)
            for member in tar.getmembers():
                member_path = os.path.abspath(os.path.join(path, member.name))
                if not (member_path == base or member_path.startswith(base + os.sep)):
                    raise RuntimeError(f"Unsafe path in tar archive: {member.name}")
            tar.extractall(path)


        def _download_cifar10c_tar(tar_path=CIFAR10C_TAR, urls=CIFAR10C_URLS):
            last_error = None
            for url in urls:
                try:
                    print(f"Downloading CIFAR-10-C from {url}")
                    urllib.request.urlretrieve(url, tar_path)
                    return
                except Exception as exc:
                    last_error = exc
                    print(f"Download failed from {url}: {exc}")

            raise RuntimeError("Could not download CIFAR-10-C from any configured URL.") from last_error


        def _extract_cifar10c_tar(tar_path=CIFAR10C_TAR):
            try:
                with tarfile.open(tar_path) as tar:
                    _safe_extract_tar(tar, ".")
            except (tarfile.TarError, EOFError) as exc:
                print("Existing CIFAR-10-C tar is invalid or incomplete; re-downloading.")
                if os.path.exists(tar_path):
                    os.remove(tar_path)
                _download_cifar10c_tar(tar_path)
                with tarfile.open(tar_path) as tar:
                    _safe_extract_tar(tar, ".")


        def load_cifar10c(severity=SEVERITY, corruptions=CORRUPTIONS, root=CIFAR10C_ROOT):
            """Download/extract CIFAR-10-C if needed, verify all files, then load one severity."""
            if not (1 <= int(severity) <= 5):
                raise ValueError("CIFAR-10-C severity must be an integer from 1 to 5.")
            severity = int(severity)

            root = _find_cifar10c_root(root, corruptions)
            missing = _missing_cifar10c_files(root, corruptions)

            if missing:
                print(f"CIFAR-10-C is incomplete at '{root}'. Missing {len(missing)} file(s): {missing[:5]}")
                if not os.path.exists(CIFAR10C_TAR):
                    print("CIFAR-10-C tar is not present; downloading it now (~2.9 GB).")
                    _download_cifar10c_tar(CIFAR10C_TAR)
                else:
                    print("CIFAR-10-C tar already exists; re-extracting it to repair the dataset.")

                _extract_cifar10c_tar(CIFAR10C_TAR)
                root = _find_cifar10c_root(root, corruptions)
                missing = _missing_cifar10c_files(root, corruptions)

            if missing:
                raise FileNotFoundError(
                    "CIFAR-10-C is still incomplete after extraction. "
                    f"Root checked: '{root}'. Missing files include: {missing[:10]}. "
                    "Delete CIFAR-10-C and CIFAR-10-C.tar, then rerun this cell."
                )

            lo, hi = (severity - 1) * 10000, severity * 10000
            labels_full = np.load(os.path.join(root, "labels.npy"))
            labels_block = labels_full[lo:hi] if labels_full.shape[0] > 10000 else labels_full

            x_parts, y_parts = [], []
            for corr in corruptions:
                path = os.path.join(root, f"{corr}.npy")
                arr = np.load(path)[lo:hi]    # (10000, 32, 32, 3) uint8
                x_parts.append(arr)
                y_parts.append(labels_block)

            x_cifar10c = np.concatenate(x_parts, axis=0).astype("float32") / 255.0
            labels_cifar10c = np.concatenate(y_parts, axis=0).astype("int64")

            print(
                f"CIFAR-10-C set (severity {severity}, {len(corruptions)} corruptions): "
                f"{x_cifar10c.shape}, labels {labels_cifar10c.shape}"
            )
            print(f"CIFAR-10-C root: {root}")

            return x_cifar10c, labels_cifar10c
    x_cifar10c, labels_cifar10c = load_cifar10c(SEVERITY, CORRUPTIONS)

def entropy_from_probs(probs, eps=1e-12):
    probs = np.clip(probs, eps, 1.0)
    return -np.sum(probs * np.log(probs), axis=-1)


def decompose_uncertainty(all_probs):
    ### all_probs has shape (S, M, N, C)
    mean_probs = all_probs.mean(axis=(0, 1))        # (N, C)
    weight_mean_probs = all_probs.mean(axis=1)      # (S, N, C)

    total = entropy_from_probs(mean_probs)                          # (N,)
    mean_entropy_fixed_weight = entropy_from_probs(weight_mean_probs).mean(axis=0)
    residual = entropy_from_probs(all_probs).mean(axis=(0, 1))

    weight_epistemic = total - mean_entropy_fixed_weight
    bottleneck = mean_entropy_fixed_weight - residual

    ### Small negative values can occur from floating-point error.
    weight_epistemic = np.maximum(weight_epistemic, 0.0)
    bottleneck = np.maximum(bottleneck, 0.0)
    residual = np.maximum(residual, 0.0)

    return {"total": total,
            "weight_epistemic": weight_epistemic,
            "bottleneck": bottleneck,
            "residual": residual}


def predict_vib_swag_double_mc(model, swag, data, n_weight_samples=30, n_rep_samples=10, batch_size=128, recal_dataset=None, seed=1999):
    rng = np.random.default_rng(seed)
    original_weights = flatten_trainable_variables(model)
    all_weight_probs = []

    for s in range(n_weight_samples):
        sampled_weights = sample_swag_weights(swag, rng=rng)
        set_trainable_variables_from_vector(model, sampled_weights)

        ### Refresh BatchNorm statistics for THIS weight sample before predicting.
        if recal_dataset is not None:
            recalibrate_batchnorm(model, recal_dataset, num_batches=200)

        rep_probs = []
        for m in range(n_rep_samples):
            if isinstance(data, tf.data.Dataset):
                logits = model.predict(data, verbose=0)
            else:
                logits = model.predict(data, batch_size=batch_size, verbose=0)

            probs = tf.nn.softmax(logits, axis=-1).numpy()
            rep_probs.append(probs)

        rep_probs = np.stack(rep_probs, axis=0)     # (M, N, 10)
        all_weight_probs.append(rep_probs)
        print(f"SWAG sample {s + 1:02d}/{n_weight_samples} complete")

    set_trainable_variables_from_vector(model, original_weights)

    all_probs = np.stack(all_weight_probs, axis=0)  # (S, M, N, 10)
    mean_probs = all_probs.mean(axis=(0, 1))        # (N, 10)
    uncertainty = decompose_uncertainty(all_probs)

    return mean_probs, all_probs, uncertainty


n_weight_samples = 30
n_rep_samples = 10

## In-distribution: CIFAR-10 test set
probs_test, all_probs_test, uncertainty_test = predict_vib_swag_double_mc(
    model, swag, test_ds,
    recal_dataset=recal_ds,
    n_weight_samples=n_weight_samples,
    n_rep_samples=n_rep_samples,
    batch_size=128,
    seed=1999
)
preds_test = np.argmax(probs_test, axis=1)
labels_test = np.argmax(y_test, axis=1)

print(f"VIB-SWAG double-MC test accuracy: {(preds_test == labels_test).mean():.4f}")

## Out-of-distribution: SVHN test set
probs_svhn, all_probs_svhn, uncertainty_svhn = predict_vib_swag_double_mc(
    model, swag, x_svhn,
    recal_dataset=recal_ds,
    n_weight_samples=n_weight_samples,
    n_rep_samples=n_rep_samples,
    batch_size=128,
    seed=2000
)

## In-distribution shift: CIFAR-10-C (severity 3, 15 corruptions).
## We keep the per-image decomposition components but intentionally discard the
## full (S, M, N, 10) sample array (~1.8 GB): the evaluation file reads the
## components directly and never needs the raw samples for this split.
probs_cifar10c, _, uncertainty_cifar10c = predict_vib_swag_double_mc(
    model, swag, x_cifar10c,
    recal_dataset=recal_ds,
    n_weight_samples=n_weight_samples,
    n_rep_samples=n_rep_samples,
    batch_size=128,
    seed=2001
)

print(f"probs_test:          {probs_test.shape}")
print(f"all_probs_test:      {all_probs_test.shape}")
print(f"probs_svhn:          {probs_svhn.shape}")
print(f"all_probs_svhn:      {all_probs_svhn.shape}")
print(f"test total mean:      {uncertainty_test['total'].mean():.4f}")
print(f"test weight mean:     {uncertainty_test['weight_epistemic'].mean():.4f}")
print(f"test bottleneck mean: {uncertainty_test['bottleneck'].mean():.4f}")
print(f"test residual mean:   {uncertainty_test['residual'].mean():.4f}")
print(f"probs_cifar10c:           {probs_cifar10c.shape}")
print(f"cifar10c total mean:      {uncertainty_cifar10c['total'].mean():.4f}")
print(f"cifar10c weight mean:     {uncertainty_cifar10c['weight_epistemic'].mean():.4f}")
print(f"cifar10c bottleneck mean: {uncertainty_cifar10c['bottleneck'].mean():.4f}")
print(f"cifar10c residual mean:   {uncertainty_cifar10c['residual'].mean():.4f}")
# Out:
# SWAG sample 01/30 complete
# SWAG sample 02/30 complete
# SWAG sample 03/30 complete
# SWAG sample 04/30 complete
# SWAG sample 05/30 complete
# SWAG sample 06/30 complete
# SWAG sample 07/30 complete
# SWAG sample 08/30 complete
# SWAG sample 09/30 complete
# SWAG sample 10/30 complete
# SWAG sample 11/30 complete
# SWAG sample 12/30 complete
# SWAG sample 13/30 complete
# SWAG sample 14/30 complete
# SWAG sample 15/30 complete
# SWAG sample 16/30 complete
# SWAG sample 17/30 complete
# SWAG sample 18/30 complete
# SWAG sample 19/30 complete
# SWAG sample 20/30 complete
# SWAG sample 21/30 complete
# SWAG sample 22/30 complete
# SWAG sample 23/30 complete
# SWAG sample 24/30 complete
# SWAG sample 25/30 complete
# SWAG sample 26/30 complete
# SWAG sample 27/30 complete
# SWAG sample 28/30 complete
# SWAG sample 29/30 complete
# SWAG sample 30/30 complete
# VIB-SWAG double-MC test accuracy: 0.9071
# SWAG sample 01/30 complete
# SWAG sample 02/30 complete
# SWAG sample 03/30 complete
# SWAG sample 04/30 complete
# SWAG sample 05/30 complete
# SWAG sample 06/30 complete
# SWAG sample 07/30 complete
# SWAG sample 08/30 complete
# SWAG sample 09/30 complete
# SWAG sample 10/30 complete
# SWAG sample 11/30 complete
# SWAG sample 12/30 complete
# SWAG sample 13/30 complete
# SWAG sample 14/30 complete
# SWAG sample 15/30 complete
# SWAG sample 16/30 complete
# SWAG sample 17/30 complete
# SWAG sample 18/30 complete
# SWAG sample 19/30 complete
# SWAG sample 20/30 complete
# SWAG sample 21/30 complete
# SWAG sample 22/30 complete
# SWAG sample 23/30 complete
# SWAG sample 24/30 complete
# SWAG sample 25/30 complete
# SWAG sample 26/30 complete
# SWAG sample 27/30 complete
# SWAG sample 28/30 complete
# SWAG sample 29/30 complete
# SWAG sample 30/30 complete
# SWAG sample 01/30 complete
# SWAG sample 02/30 complete
# SWAG sample 03/30 complete
# SWAG sample 04/30 complete
# SWAG sample 05/30 complete
# SWAG sample 06/30 complete
# SWAG sample 07/30 complete
# SWAG sample 08/30 complete
# SWAG sample 09/30 complete
# SWAG sample 10/30 complete
# SWAG sample 11/30 complete
# SWAG sample 12/30 complete
# SWAG sample 13/30 complete
# SWAG sample 14/30 complete
# SWAG sample 15/30 complete
# SWAG sample 16/30 complete
# SWAG sample 17/30 complete
# SWAG sample 18/30 complete
# SWAG sample 19/30 complete
# SWAG sample 20/30 complete
# SWAG sample 21/30 complete
# SWAG sample 22/30 complete
# SWAG sample 23/30 complete
# SWAG sample 24/30 complete
# SWAG sample 25/30 complete
# SWAG sample 26/30 complete
# SWAG sample 27/30 complete
# SWAG sample 28/30 complete
# SWAG sample 29/30 complete
# SWAG sample 30/30 complete
# probs_test:          (10000, 10)
# all_probs_test:      (30, 10, 10000, 10)
# probs_svhn:          (26032, 10)
# all_probs_svhn:      (30, 10, 26032, 10)
# test total mean:      0.1180
# test weight mean:     0.0021
# test bottleneck mean: 0.0083
# test residual mean:   0.1076
# probs_cifar10c:           (150000, 10)
# cifar10c total mean:      0.3070
# cifar10c weight mean:     0.0049
# cifar10c bottleneck mean: 0.0190
# cifar10c residual mean:   0.2831

# %%
# Saving raw outputs for the evaluation file
'''
Save format (shared across all benchmarks). The evaluation notebook will
load these by filename and produce ECE, reliability diagrams, OOD AUROC,
risk-coverage and uncertainty summaries.

Keys:
  model_name               - human-readable string identifier
  beta                     - VIB compression strength used for training
  latent_dim               - bottleneck dimensionality
  n_weight_samples         - number of SWAG weight samples used at inference
  n_rep_samples            - number of VIB representation samples per weight sample
  probs_test               - (N_test, 10) mean predictive distribution on CIFAR-10 test
  labels_test              - (N_test,) true labels (integer 0-9)
  preds_test               - (N_test,) argmax of probs_test
  probs_svhn               - (N_svhn, 10) mean predictive distribution on SVHN OOD
  all_probs_test           - (S, M, N_test, 10) per-weight/per-representation probs
  all_probs_svhn           - (S, M, N_svhn, 10) per-weight/per-representation probs
  total_*                  - entropy of the averaged predictive distribution
  weight_epistemic_*       - SWAG / weight-level uncertainty component
  bottleneck_*             - VIB representation-level uncertainty component
  residual_*               - remaining expected entropy after fixing weights and z

The large all_probs arrays are included so the decomposition can be recomputed
or audited later. Delete those keys if storage becomes an issue.
'''
np.savez("vib_swag_results.npz",
         model_name="vib_swag",
         beta=beta,
         latent_dim=latent_dim,
         swag_learning_rate=swag_learning_rate,
         swag_epochs=swag_epochs,
         swag_collect_every=swag_collect_every,
         n_swag_snapshots=swag["n_snapshots"],
         n_weight_samples=n_weight_samples,
         n_rep_samples=n_rep_samples,
         probs_test=probs_test,
         labels_test=labels_test,
         preds_test=preds_test,
         probs_svhn=probs_svhn,
         all_probs_test=all_probs_test,
         all_probs_svhn=all_probs_svhn,
         total_test=uncertainty_test["total"],
         weight_epistemic_test=uncertainty_test["weight_epistemic"],
         bottleneck_test=uncertainty_test["bottleneck"],
         residual_test=uncertainty_test["residual"],
         total_svhn=uncertainty_svhn["total"],
         weight_epistemic_svhn=uncertainty_svhn["weight_epistemic"],
         bottleneck_svhn=uncertainty_svhn["bottleneck"],
         residual_svhn=uncertainty_svhn["residual"],
         probs_cifar10c=probs_cifar10c,
         labels_cifar10c=labels_cifar10c,
         cifar10c_severity=SEVERITY,
         total_cifar10c=uncertainty_cifar10c["total"],
         weight_epistemic_cifar10c=uncertainty_cifar10c["weight_epistemic"],
         bottleneck_cifar10c=uncertainty_cifar10c["bottleneck"],
         residual_cifar10c=uncertainty_cifar10c["residual"])

np.savez("vib_swag_distribution.npz",
         mean=swag["mean"],
         diag_var=swag["diag_var"],
         deviations=swag["deviations"],
         n_snapshots=swag["n_snapshots"])

print("Saved vib_swag_results.npz")
print("Saved vib_swag_distribution.npz")
# Out:
# Saved vib_swag_results.npz
# Saved vib_swag_distribution.npz
