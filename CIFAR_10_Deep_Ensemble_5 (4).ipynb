# %%
from google.colab import drive
import os

drive.mount('/content/drive')                          # auth popup, once per session
RESULTS_DIR = '/content/drive/MyDrive/thesis_results'  # change name if you like
os.makedirs(RESULTS_DIR, exist_ok=True)
os.chdir(RESULTS_DIR)                                   # all relative saves now land here
print('Saving to:', os.getcwd())
# Out:
# Mounted at /content/drive
# Saving to: /content/drive/MyDrive/thesis_results

# %%
# Imports

## Core libraries
import numpy as np
import matplotlib.pyplot as plt

## TensorFlow / Keras
import tensorflow as tf
import keras
from keras import ops, layers
from keras.callbacks import Callback
from keras.models import Sequential, Model
from keras.layers import Input, Conv2D, Dense

# %%
# Setting seeds

np.random.seed(1999)
tf.random.set_seed(1999)

# %%
# Loading the dataset

(x_train_full, y_train_full), (x_test, y_test) = keras.datasets.cifar10.load_data()

## Feature scaling (mapping pixel values to [0,1])
'''
This is used as neural network training via gradient descent is sensitive to the
scale of inputs (through activations a = Wx + b). This causes gradients to vanish
and makes the loss landscape poorly conditioned.
'''
x_train_full = x_train_full / 255.0
x_test = x_test / 255.0

''' Recalling our y values are our categories '''
y_train_full = keras.utils.to_categorical(y_train_full, 10)
y_test = keras.utils.to_categorical(y_test, 10)

## Setting up our validation dataset
n_val = int(0.2 * len(x_train_full))
perm = np.random.permutation(len(x_train_full))
val_idx, train_idx = perm[:n_val], perm[n_val:]
x_val, y_val = x_train_full[val_idx], y_train_full[val_idx]
x_train, y_train = x_train_full[train_idx], y_train_full[train_idx]

## Check
print(f"train: {x_train.shape} val: {x_val.shape} test: {x_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6458s 38us/step
# train: (40000, 32, 32, 3) val: (10000, 32, 32, 3) test: (10000, 32, 32, 3)

# %%
# Augmenting the dataset
'''
This involves creating new training examples by applying label preserving
transformations to existing examples e.g. flips, crops, scaling, colour jitter,
adding noise, ...
'''

'''
Applying three transformations in sequence, we pad the image with black 0s,
then randomly crop the newly padded image (so the model learns that a shifted
horse picture is still a horse), and then randomly mirroring the image from left
to right.
'''
augment = keras.Sequential([layers.ZeroPadding2D(padding=4),
                            layers.RandomCrop(32, 32),
                            layers.RandomFlip("horizontal")])

batch_size = 128

'''
This builds the full training data pipeline, where:
- The from_tensor_slices((x_train, y_train)) wraps the numpy arrays into a
  tf.data.Dataset that has image label pairs one at a time.
- For .shuffle(len(x_train)) - this shifts the entire dataset after each epoch.
- For .map(lambda x, y: (augment(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
  this applies the augmentation pipeline to each batch of images whilst leaving
  labels untouched. The training=True is important because RandomCrop and
  RandomFlip only apply their transformations during training. The
  num_parallel_calls=tf.data.AUTOTUNE lets TensorFlow decide how many batches to
  augment in parallel across CPU threads.
'''
train_ds = (tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size).map(lambda x, y: (augment(x, training=True), y),
            num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE))

### Recalling that there is no augmentation for validation and test datasets
val_ds  = (tf.data.Dataset.from_tensor_slices((x_val,  y_val ))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))
test_ds = (tf.data.Dataset.from_tensor_slices((x_test, y_test))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))

# %%
# Residual block (no dropout)
'''
Here is the specification requirements for a single residual block (the repeating
unit in ResNet-20). Instead of learning the mapping between the input and the
output, we instead learn the difference between the input and the desired output
(the residual).

In this, the shortcut path passes the input unchanged (albeit with a channel
count change to match shapes at times). These two paths are added together for
a final ReLU.
'''

### We recall that a convolution slides a small window (a kernel/filter) across our grid.
### A single kernel produces one output grid (one channel). One kernel might learn to detect vertical edges, another colour gradients, and so on.
### We thus use 16 kernels simultaneously to produce an output with 16 channels.

class ResidualBlock(keras.layers.Layer):

    '''
    The init method constructs everything which doesn't fit into the other categories.
    In this, we construct the two convolutional layers and the ReLU activation.
    Everything here is created once and reused when the block processes an input.
    Projection is handled separately, as the input's channel count changes.
    '''
    def __init__(self, filters, stride=1, **kwargs):
        super().__init__(**kwargs)
        self.filters = filters
        self.stride = stride

        ### The same padding here adds just enough padding at each convolution step so the output spatial dimensions match the input.
        ### The kernel initialiser establishes starting weights for the kernels such that they are not all zero (each kernel learns the same thing), too large (where activations explode), or too small (vanishing to zero).
        self.conv1 = layers.Conv2D(filters, 3, strides=stride, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")

        ### Batch normalisation ensures each channel has a mean of 0 and a variance of 1.
        ### This is necessary for faster and more stable training as the weights update during training, causing our outputs to shift considerably (and calibrated to the old weights).
        ### The purpose of batch normalisation is to ensure a stable range of outputs.
        self.bn1 = layers.BatchNormalization()
        self.conv2 = layers.Conv2D(filters, 3, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")
        self.bn2 = layers.BatchNormalization()
        self.relu = layers.Activation("relu")

    ### Going deeper into the network, we want to detect increasingly abstract features.
    ### We therefore downsample (have a bigger stride) as we detect combinations.
    ### We compensate for that by increasing the number of channels.

    '''
    The build method handles the projection shortcut (and handles shape-matching if needed).
    '''
    def build(self, input_shape):
        in_channels = input_shape[-1]

        if self.stride != 1 or in_channels != self.filters:
            self.proj = layers.Conv2D(self.filters, 1, strides=self.stride, padding="valid",
                                      kernel_regularizer=keras.regularizers.L2(1e-4),
                                      kernel_initializer="he_normal")
            self.bn_proj = layers.BatchNormalization()
        else:
            self.proj = None

        super().build(input_shape)

    '''
    The call method runs the actual forward pass of the model organising the
    split into the main convolutional path and the shortcut path, then summing
    them and applying ReLU.
    '''
    def call(self, x):
        if self.proj is not None:
            shortcut = self.bn_proj(self.proj(x))
        else:
            shortcut = x

        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))

        return self.relu(out + shortcut)

    '''
    The get_config method enables serialisation so Keras can save/load the model.
    '''
    def get_config(self):
        config = super().get_config()
        config.update({"filters": self.filters,
                       "stride": self.stride})
        return config

# %%
# build_resnet20 — deep ensemble variant (same deterministic member network)
'''
The full architecture follows the ResNet-20 spec of He et al. (2016) for CIFAR:
an initial conv, three stages of three residual blocks at filter widths
{16, 32, 64}, with the first block of stages 2 and 3 using stride 2 to halve
spatial resolution while doubling channels.

For the deep ensemble baseline, each member is this same deterministic ResNet-20.
The uncertainty signal comes from training five networks independently, then
averaging their predictive probabilities at inference time.
'''
def build_resnet20():
    inputs = keras.Input(shape=(32, 32, 3))

    x = layers.Conv2D(16, 3, padding="same",
                      kernel_regularizer=keras.regularizers.L2(1e-4),
                      kernel_initializer="he_normal")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    for _ in range(3):
        x = ResidualBlock(16)(x)

    x = ResidualBlock(32, stride=2)(x)
    for _ in range(2):
        x = ResidualBlock(32)(x)

    x = ResidualBlock(64, stride=2)(x)
    for _ in range(2):
        x = ResidualBlock(64)(x)

    ### Global average pooling takes the block's output and feeds it into a final dense layer for classification.
    ### It takes the 64 feature maps (each of which is an 8x8 grid) and averages each grid into a single number. The output is a flat vector of length 64, that feeds into the final dense layer for classification.
    ### This is therefore translation invariant (if a feature shifts position in the 8x8 grid, the average barely changes), so classification is stable.
    x = layers.GlobalAveragePooling2D()(x)

    outputs = layers.Dense(10, kernel_initializer="he_normal")(x)

    return keras.Model(inputs, outputs)

# %%
# Deep ensemble settings

'''
Deep ensembles train multiple deterministic networks independently. Here we use
five ResNet-20 members, following the baseline described by Lakshminarayanan
et al. (2017). The members have the same architecture and optimiser, but use
different random seeds and separate checkpoints.
'''
ensemble_size = 5
base_seed = 1999

ensemble_models = []
ensemble_histories = []
ensemble_test_metrics = []

# %%
# Training schedule for each ensemble member

'''
Step-wise learning-rate schedule: drop by 10x at epochs 100 and 150.
This is the standard CIFAR ResNet schedule from He et al. (2016) and matches
the deterministic baseline, so the baseline differs only in the ensemble
mechanism, not in the optimisation recipe.
'''
def lr_schedule(epoch, lr):
    if epoch in (100, 150):
        return lr * 0.1
    return lr

# %%
# Compiling helper

### This doesn't run any training or touch any data, but it configures the optimiser (how weights are updated), the loss function, and optionally any metrics we want to track.
def compile_member(model):
    model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1, momentum=0.9),
                  loss=keras.losses.CategoricalCrossentropy(from_logits=True),
                  metrics=["categorical_accuracy"])
    return model

# %%
# Callbacks for member-specific checkpoints

def make_callbacks(member_id):
    checkpoint_path = f"resnet20_ensemble_member_{member_id + 1}_best.weights.h5"
    return [keras.callbacks.ModelCheckpoint(checkpoint_path,
                                            monitor="val_loss",
                                            save_best_only=True,
                                            save_weights_only=True),
            keras.callbacks.LearningRateScheduler(lr_schedule, verbose=1)] # calls lr_schedule function each epoch to reduce learning rate

# %%
# Training the 5-member deep ensemble

for member_id in range(ensemble_size):
    print("\n" + "=" * 70)
    print(f"Training ensemble member {member_id + 1}/{ensemble_size}")
    print("=" * 70)

    ### Reset the Keras graph and random seeds before each member so the models
    ### are independently initialised while preserving reproducibility.
    keras.backend.clear_session()
    np.random.seed(base_seed + member_id)
    tf.random.set_seed(base_seed + member_id)

    model = build_resnet20()
    model = compile_member(model)

    callbacks = make_callbacks(member_id)
    history = model.fit(train_ds,
                        epochs=200,
                        validation_data=val_ds,
                        callbacks=callbacks)

    checkpoint_path = f"resnet20_ensemble_member_{member_id + 1}_best.weights.h5"
    model.load_weights(checkpoint_path) # Loading best checkpoint for this member

    # Final evaluation on test set for this member
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    print(f"Member {member_id + 1} test loss: {test_loss:.4f}  test accuracy: {test_acc:.4f}")

    ensemble_models.append(model)
    ensemble_histories.append(history)
    ensemble_test_metrics.append((test_loss, test_acc))

member_accs = np.array([acc for _, acc in ensemble_test_metrics])
print(f"\nMember test accuracies: {member_accs}")
print(f"Mean member accuracy: {member_accs.mean():.4f} ± {member_accs.std():.4f}")
# Out:
# ======================================================================
# Training ensemble member 1/5
# ======================================================================
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 1/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - categorical_accuracy: 0.3537 - loss: 1.8960 - val_categorical_accuracy: 0.3984 - val_loss: 1.8172 - learning_rate: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 2/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.5299 - loss: 1.4414 - val_categorical_accuracy: 0.3839 - val_loss: 2.2488 - learning_rate: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 3/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.6302 - loss: 1.1940 - val_categorical_accuracy: 0.6081 - val_loss: 1.3471 - learning_rate: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 4/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.6869 - loss: 1.0438 - val_categorical_accuracy: 0.5641 - val_loss: 1.5868 - learning_rate: 0.1000
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 5/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.7222 - loss: 0.9484 - val_categorical_accuracy: 0.6335 - val_loss: 1.3236 - learning_rate: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 6/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.7498 - loss: 0.8728 - val_categorical_accuracy: 0.7177 - val_loss: 1.0196 - learning_rate: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 7/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7727 - loss: 0.8146 - val_categorical_accuracy: 0.6445 - val_loss: 1.3970 - learning_rate: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 8/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7849 - loss: 0.7851 - val_categorical_accuracy: 0.5962 - val_loss: 1.5974 - learning_rate: 0.1000
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 9/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7998 - loss: 0.7462 - val_categorical_accuracy: 0.7259 - val_loss: 1.0259 - learning_rate: 0.1000
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 10/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8075 - loss: 0.7219 - val_categorical_accuracy: 0.7192 - val_loss: 1.0105 - learning_rate: 0.1000
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 11/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8144 - loss: 0.7026 - val_categorical_accuracy: 0.7371 - val_loss: 0.9881 - learning_rate: 0.1000
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 12/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8221 - loss: 0.6840 - val_categorical_accuracy: 0.7586 - val_loss: 0.8910 - learning_rate: 0.1000
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 13/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8298 - loss: 0.6646 - val_categorical_accuracy: 0.6745 - val_loss: 1.2630 - learning_rate: 0.1000
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 14/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8385 - loss: 0.6472 - val_categorical_accuracy: 0.7939 - val_loss: 0.8036 - learning_rate: 0.1000
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 15/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8407 - loss: 0.6347 - val_categorical_accuracy: 0.7692 - val_loss: 0.9491 - learning_rate: 0.1000
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 16/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8444 - loss: 0.6307 - val_categorical_accuracy: 0.7364 - val_loss: 1.0663 - learning_rate: 0.1000
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 17/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8482 - loss: 0.6183 - val_categorical_accuracy: 0.7785 - val_loss: 0.8525 - learning_rate: 0.1000
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 18/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8525 - loss: 0.6116 - val_categorical_accuracy: 0.7707 - val_loss: 0.8491 - learning_rate: 0.1000
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 19/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8558 - loss: 0.6018 - val_categorical_accuracy: 0.6977 - val_loss: 1.2104 - learning_rate: 0.1000
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 20/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8565 - loss: 0.5982 - val_categorical_accuracy: 0.7840 - val_loss: 0.8250 - learning_rate: 0.1000
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 21/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8625 - loss: 0.5848 - val_categorical_accuracy: 0.8027 - val_loss: 0.8077 - learning_rate: 0.1000
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 22/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8630 - loss: 0.5838 - val_categorical_accuracy: 0.7583 - val_loss: 0.9879 - learning_rate: 0.1000
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 23/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8658 - loss: 0.5817 - val_categorical_accuracy: 0.7823 - val_loss: 0.9545 - learning_rate: 0.1000
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 24/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8691 - loss: 0.5749 - val_categorical_accuracy: 0.7868 - val_loss: 0.9796 - learning_rate: 0.1000
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 25/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8703 - loss: 0.5723 - val_categorical_accuracy: 0.8062 - val_loss: 0.8002 - learning_rate: 0.1000
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 26/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8762 - loss: 0.5601 - val_categorical_accuracy: 0.7691 - val_loss: 0.9902 - learning_rate: 0.1000
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 27/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8762 - loss: 0.5623 - val_categorical_accuracy: 0.8119 - val_loss: 0.8035 - learning_rate: 0.1000
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 28/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8760 - loss: 0.5582 - val_categorical_accuracy: 0.7384 - val_loss: 1.0267 - learning_rate: 0.1000
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 29/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8786 - loss: 0.5562 - val_categorical_accuracy: 0.6247 - val_loss: 1.7581 - learning_rate: 0.1000
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 30/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8783 - loss: 0.5548 - val_categorical_accuracy: 0.8125 - val_loss: 0.8094 - learning_rate: 0.1000
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 31/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8794 - loss: 0.5522 - val_categorical_accuracy: 0.7479 - val_loss: 1.1042 - learning_rate: 0.1000
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 32/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8820 - loss: 0.5507 - val_categorical_accuracy: 0.7023 - val_loss: 1.3783 - learning_rate: 0.1000
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 33/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8838 - loss: 0.5460 - val_categorical_accuracy: 0.7632 - val_loss: 1.0796 - learning_rate: 0.1000
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 34/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8846 - loss: 0.5448 - val_categorical_accuracy: 0.7566 - val_loss: 1.0263 - learning_rate: 0.1000
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 35/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8839 - loss: 0.5404 - val_categorical_accuracy: 0.7418 - val_loss: 1.0996 - learning_rate: 0.1000
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 36/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8867 - loss: 0.5420 - val_categorical_accuracy: 0.7524 - val_loss: 1.0636 - learning_rate: 0.1000
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 37/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8896 - loss: 0.5358 - val_categorical_accuracy: 0.8068 - val_loss: 0.8753 - learning_rate: 0.1000
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 38/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8871 - loss: 0.5389 - val_categorical_accuracy: 0.8306 - val_loss: 0.7453 - learning_rate: 0.1000
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 39/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8891 - loss: 0.5378 - val_categorical_accuracy: 0.6987 - val_loss: 1.3713 - learning_rate: 0.1000
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 40/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8906 - loss: 0.5335 - val_categorical_accuracy: 0.8016 - val_loss: 0.9355 - learning_rate: 0.1000
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 41/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8897 - loss: 0.5348 - val_categorical_accuracy: 0.7681 - val_loss: 1.0336 - learning_rate: 0.1000
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 42/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8937 - loss: 0.5267 - val_categorical_accuracy: 0.6954 - val_loss: 1.2691 - learning_rate: 0.1000
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 43/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8927 - loss: 0.5309 - val_categorical_accuracy: 0.8129 - val_loss: 0.8195 - learning_rate: 0.1000
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 44/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8940 - loss: 0.5279 - val_categorical_accuracy: 0.8010 - val_loss: 0.8437 - learning_rate: 0.1000
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 45/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8910 - loss: 0.5319 - val_categorical_accuracy: 0.7942 - val_loss: 0.8777 - learning_rate: 0.1000
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 46/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8954 - loss: 0.5197 - val_categorical_accuracy: 0.8009 - val_loss: 0.8402 - learning_rate: 0.1000
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 47/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8953 - loss: 0.5245 - val_categorical_accuracy: 0.7607 - val_loss: 1.0664 - learning_rate: 0.1000
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 48/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9005 - loss: 0.5107 - val_categorical_accuracy: 0.7640 - val_loss: 1.0913 - learning_rate: 0.1000
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 49/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8975 - loss: 0.5149 - val_categorical_accuracy: 0.8362 - val_loss: 0.7491 - learning_rate: 0.1000
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 50/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8986 - loss: 0.5157 - val_categorical_accuracy: 0.7008 - val_loss: 1.4160 - learning_rate: 0.1000
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 51/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8981 - loss: 0.5194 - val_categorical_accuracy: 0.7895 - val_loss: 0.9259 - learning_rate: 0.1000
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 52/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8965 - loss: 0.5206 - val_categorical_accuracy: 0.8036 - val_loss: 0.8640 - learning_rate: 0.1000
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 53/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8972 - loss: 0.5183 - val_categorical_accuracy: 0.7087 - val_loss: 1.2315 - learning_rate: 0.1000
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 54/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9012 - loss: 0.5099 - val_categorical_accuracy: 0.8143 - val_loss: 0.8895 - learning_rate: 0.1000
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 55/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9025 - loss: 0.5061 - val_categorical_accuracy: 0.8057 - val_loss: 0.9171 - learning_rate: 0.1000
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 56/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9007 - loss: 0.5110 - val_categorical_accuracy: 0.7925 - val_loss: 0.8417 - learning_rate: 0.1000
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 57/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9029 - loss: 0.5078 - val_categorical_accuracy: 0.8077 - val_loss: 0.8067 - learning_rate: 0.1000
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 58/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9018 - loss: 0.5120 - val_categorical_accuracy: 0.7148 - val_loss: 1.3142 - learning_rate: 0.1000
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 59/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9018 - loss: 0.5076 - val_categorical_accuracy: 0.7213 - val_loss: 1.2989 - learning_rate: 0.1000
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 60/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9040 - loss: 0.5078 - val_categorical_accuracy: 0.7083 - val_loss: 1.4156 - learning_rate: 0.1000
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 61/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9036 - loss: 0.5046 - val_categorical_accuracy: 0.8030 - val_loss: 0.9350 - learning_rate: 0.1000
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 62/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9006 - loss: 0.5128 - val_categorical_accuracy: 0.7957 - val_loss: 0.9550 - learning_rate: 0.1000
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 63/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9052 - loss: 0.5042 - val_categorical_accuracy: 0.7972 - val_loss: 0.9165 - learning_rate: 0.1000
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 64/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - categorical_accuracy: 0.9045 - loss: 0.5051 - val_categorical_accuracy: 0.8417 - val_loss: 0.7259 - learning_rate: 0.1000
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 65/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9071 - loss: 0.4993 - val_categorical_accuracy: 0.8090 - val_loss: 0.8886 - learning_rate: 0.1000
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 66/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9050 - loss: 0.5026 - val_categorical_accuracy: 0.8254 - val_loss: 0.8421 - learning_rate: 0.1000
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 67/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9057 - loss: 0.5009 - val_categorical_accuracy: 0.7691 - val_loss: 1.0800 - learning_rate: 0.1000
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 68/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9061 - loss: 0.5012 - val_categorical_accuracy: 0.7648 - val_loss: 1.0344 - learning_rate: 0.1000
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 69/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9064 - loss: 0.5044 - val_categorical_accuracy: 0.6691 - val_loss: 1.6559 - learning_rate: 0.1000
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 70/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9048 - loss: 0.5054 - val_categorical_accuracy: 0.8385 - val_loss: 0.7761 - learning_rate: 0.1000
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 71/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9110 - loss: 0.4950 - val_categorical_accuracy: 0.8285 - val_loss: 0.8079 - learning_rate: 0.1000
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 72/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.9075 - loss: 0.5020 - val_categorical_accuracy: 0.8542 - val_loss: 0.7018 - learning_rate: 0.1000
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 73/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9076 - loss: 0.5014 - val_categorical_accuracy: 0.8024 - val_loss: 0.9312 - learning_rate: 0.1000
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 74/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9094 - loss: 0.4954 - val_categorical_accuracy: 0.7816 - val_loss: 1.0383 - learning_rate: 0.1000
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 75/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9110 - loss: 0.4928 - val_categorical_accuracy: 0.7760 - val_loss: 1.0607 - learning_rate: 0.1000
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 76/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9094 - loss: 0.4942 - val_categorical_accuracy: 0.8404 - val_loss: 0.7201 - learning_rate: 0.1000
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 77/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9067 - loss: 0.5007 - val_categorical_accuracy: 0.8211 - val_loss: 0.8788 - learning_rate: 0.1000
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 78/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9093 - loss: 0.4939 - val_categorical_accuracy: 0.8256 - val_loss: 0.8348 - learning_rate: 0.1000
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 79/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9106 - loss: 0.4922 - val_categorical_accuracy: 0.8070 - val_loss: 0.8858 - learning_rate: 0.1000
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 80/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9099 - loss: 0.4934 - val_categorical_accuracy: 0.7044 - val_loss: 1.4150 - learning_rate: 0.1000
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 81/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9125 - loss: 0.4859 - val_categorical_accuracy: 0.8327 - val_loss: 0.7768 - learning_rate: 0.1000
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 82/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9097 - loss: 0.4933 - val_categorical_accuracy: 0.7723 - val_loss: 1.0516 - learning_rate: 0.1000
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 83/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9137 - loss: 0.4824 - val_categorical_accuracy: 0.7864 - val_loss: 1.0974 - learning_rate: 0.1000
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 84/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9118 - loss: 0.4928 - val_categorical_accuracy: 0.8276 - val_loss: 0.8318 - learning_rate: 0.1000
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 85/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9144 - loss: 0.4866 - val_categorical_accuracy: 0.8111 - val_loss: 0.9176 - learning_rate: 0.1000
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 86/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9130 - loss: 0.4897 - val_categorical_accuracy: 0.6722 - val_loss: 1.6012 - learning_rate: 0.1000
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 87/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9117 - loss: 0.4892 - val_categorical_accuracy: 0.8013 - val_loss: 0.9461 - learning_rate: 0.1000
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 88/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9151 - loss: 0.4831 - val_categorical_accuracy: 0.8273 - val_loss: 0.8334 - learning_rate: 0.1000
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 89/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9129 - loss: 0.4907 - val_categorical_accuracy: 0.8272 - val_loss: 0.8158 - learning_rate: 0.1000
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 90/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9133 - loss: 0.4836 - val_categorical_accuracy: 0.8156 - val_loss: 0.8615 - learning_rate: 0.1000
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 91/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9122 - loss: 0.4920 - val_categorical_accuracy: 0.7641 - val_loss: 1.1256 - learning_rate: 0.1000
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 92/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9153 - loss: 0.4824 - val_categorical_accuracy: 0.7636 - val_loss: 1.0942 - learning_rate: 0.1000
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 93/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9136 - loss: 0.4846 - val_categorical_accuracy: 0.8168 - val_loss: 0.9024 - learning_rate: 0.1000
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 94/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9138 - loss: 0.4881 - val_categorical_accuracy: 0.8175 - val_loss: 0.8679 - learning_rate: 0.1000
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 95/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9131 - loss: 0.4883 - val_categorical_accuracy: 0.7525 - val_loss: 1.1052 - learning_rate: 0.1000
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 96/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9125 - loss: 0.4866 - val_categorical_accuracy: 0.8157 - val_loss: 0.8300 - learning_rate: 0.1000
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 97/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9136 - loss: 0.4865 - val_categorical_accuracy: 0.7556 - val_loss: 1.2150 - learning_rate: 0.1000
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 98/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9142 - loss: 0.4798 - val_categorical_accuracy: 0.8331 - val_loss: 0.7850 - learning_rate: 0.1000
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 99/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9178 - loss: 0.4772 - val_categorical_accuracy: 0.8142 - val_loss: 0.8922 - learning_rate: 0.1000
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 100/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9139 - loss: 0.4837 - val_categorical_accuracy: 0.7890 - val_loss: 0.9810 - learning_rate: 0.1000
#
# Epoch 101: LearningRateScheduler setting learning rate to 0.010000000149011612.
# Epoch 101/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - categorical_accuracy: 0.9402 - loss: 0.4120 - val_categorical_accuracy: 0.9021 - val_loss: 0.5432 - learning_rate: 0.0100
#
# Epoch 102: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 102/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9565 - loss: 0.3626 - val_categorical_accuracy: 0.9054 - val_loss: 0.5405 - learning_rate: 0.0100
#
# Epoch 103: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 103/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9629 - loss: 0.3419 - val_categorical_accuracy: 0.9052 - val_loss: 0.5317 - learning_rate: 0.0100
#
# Epoch 104: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 104/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9652 - loss: 0.3315 - val_categorical_accuracy: 0.9086 - val_loss: 0.5300 - learning_rate: 0.0100
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 105/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9684 - loss: 0.3223 - val_categorical_accuracy: 0.9080 - val_loss: 0.5374 - learning_rate: 0.0100
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 106/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9689 - loss: 0.3156 - val_categorical_accuracy: 0.9108 - val_loss: 0.5320 - learning_rate: 0.0100
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 107/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9712 - loss: 0.3057 - val_categorical_accuracy: 0.9074 - val_loss: 0.5392 - learning_rate: 0.0100
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 108/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9737 - loss: 0.2983 - val_categorical_accuracy: 0.9103 - val_loss: 0.5417 - learning_rate: 0.0100
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 109/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9747 - loss: 0.2919 - val_categorical_accuracy: 0.9066 - val_loss: 0.5422 - learning_rate: 0.0100
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 110/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9756 - loss: 0.2865 - val_categorical_accuracy: 0.9104 - val_loss: 0.5409 - learning_rate: 0.0100
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 111/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9768 - loss: 0.2816 - val_categorical_accuracy: 0.9104 - val_loss: 0.5439 - learning_rate: 0.0100
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 112/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9780 - loss: 0.2753 - val_categorical_accuracy: 0.9105 - val_loss: 0.5320 - learning_rate: 0.0100
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 113/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - categorical_accuracy: 0.9792 - loss: 0.2690 - val_categorical_accuracy: 0.9099 - val_loss: 0.5298 - learning_rate: 0.0100
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 114/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9795 - loss: 0.2651 - val_categorical_accuracy: 0.9094 - val_loss: 0.5336 - learning_rate: 0.0100
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 115/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9807 - loss: 0.2591 - val_categorical_accuracy: 0.9089 - val_loss: 0.5442 - learning_rate: 0.0100
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 116/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9808 - loss: 0.2559 - val_categorical_accuracy: 0.9101 - val_loss: 0.5389 - learning_rate: 0.0100
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 117/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9822 - loss: 0.2511 - val_categorical_accuracy: 0.9085 - val_loss: 0.5341 - learning_rate: 0.0100
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 118/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9815 - loss: 0.2495 - val_categorical_accuracy: 0.9099 - val_loss: 0.5418 - learning_rate: 0.0100
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 119/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9832 - loss: 0.2444 - val_categorical_accuracy: 0.9098 - val_loss: 0.5486 - learning_rate: 0.0100
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 120/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9839 - loss: 0.2412 - val_categorical_accuracy: 0.9074 - val_loss: 0.5505 - learning_rate: 0.0100
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 121/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9849 - loss: 0.2360 - val_categorical_accuracy: 0.9099 - val_loss: 0.5392 - learning_rate: 0.0100
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 122/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9843 - loss: 0.2339 - val_categorical_accuracy: 0.9082 - val_loss: 0.5509 - learning_rate: 0.0100
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 123/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9847 - loss: 0.2308 - val_categorical_accuracy: 0.9093 - val_loss: 0.5531 - learning_rate: 0.0100
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 124/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9850 - loss: 0.2260 - val_categorical_accuracy: 0.9079 - val_loss: 0.5561 - learning_rate: 0.0100
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 125/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9857 - loss: 0.2236 - val_categorical_accuracy: 0.9060 - val_loss: 0.5555 - learning_rate: 0.0100
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 126/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9870 - loss: 0.2175 - val_categorical_accuracy: 0.9076 - val_loss: 0.5537 - learning_rate: 0.0100
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 127/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9858 - loss: 0.2180 - val_categorical_accuracy: 0.9103 - val_loss: 0.5439 - learning_rate: 0.0100
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 128/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9873 - loss: 0.2142 - val_categorical_accuracy: 0.9108 - val_loss: 0.5501 - learning_rate: 0.0100
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 129/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9871 - loss: 0.2115 - val_categorical_accuracy: 0.9098 - val_loss: 0.5446 - learning_rate: 0.0100
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 130/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9882 - loss: 0.2063 - val_categorical_accuracy: 0.9054 - val_loss: 0.5774 - learning_rate: 0.0100
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 131/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9875 - loss: 0.2065 - val_categorical_accuracy: 0.9074 - val_loss: 0.5508 - learning_rate: 0.0100
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 132/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9883 - loss: 0.2028 - val_categorical_accuracy: 0.9074 - val_loss: 0.5505 - learning_rate: 0.0100
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 133/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9877 - loss: 0.2024 - val_categorical_accuracy: 0.9093 - val_loss: 0.5535 - learning_rate: 0.0100
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 134/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9879 - loss: 0.2000 - val_categorical_accuracy: 0.9034 - val_loss: 0.5792 - learning_rate: 0.0100
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 135/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9883 - loss: 0.1975 - val_categorical_accuracy: 0.9018 - val_loss: 0.5824 - learning_rate: 0.0100
#
# Epoch 136: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 136/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9898 - loss: 0.1928 - val_categorical_accuracy: 0.9093 - val_loss: 0.5493 - learning_rate: 0.0100
#
# Epoch 137: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 137/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9891 - loss: 0.1911 - val_categorical_accuracy: 0.9046 - val_loss: 0.5744 - learning_rate: 0.0100
#
# Epoch 138: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 138/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9902 - loss: 0.1871 - val_categorical_accuracy: 0.9067 - val_loss: 0.5689 - learning_rate: 0.0100
#
# Epoch 139: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 139/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9886 - loss: 0.1899 - val_categorical_accuracy: 0.9074 - val_loss: 0.5581 - learning_rate: 0.0100
#
# Epoch 140: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 140/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9892 - loss: 0.1860 - val_categorical_accuracy: 0.9068 - val_loss: 0.5620 - learning_rate: 0.0100
#
# Epoch 141: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 141/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9901 - loss: 0.1820 - val_categorical_accuracy: 0.9039 - val_loss: 0.5735 - learning_rate: 0.0100
#
# Epoch 142: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 142/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9898 - loss: 0.1815 - val_categorical_accuracy: 0.9012 - val_loss: 0.5888 - learning_rate: 0.0100
#
# Epoch 143: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 143/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9895 - loss: 0.1796 - val_categorical_accuracy: 0.9050 - val_loss: 0.5633 - learning_rate: 0.0100
#
# Epoch 144: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 144/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9892 - loss: 0.1793 - val_categorical_accuracy: 0.9053 - val_loss: 0.5778 - learning_rate: 0.0100
#
# Epoch 145: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 145/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9901 - loss: 0.1748 - val_categorical_accuracy: 0.9100 - val_loss: 0.5558 - learning_rate: 0.0100
#
# Epoch 146: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 146/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9908 - loss: 0.1727 - val_categorical_accuracy: 0.9079 - val_loss: 0.5559 - learning_rate: 0.0100
#
# Epoch 147: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 147/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9904 - loss: 0.1704 - val_categorical_accuracy: 0.9059 - val_loss: 0.5796 - learning_rate: 0.0100
#
# Epoch 148: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 148/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9912 - loss: 0.1680 - val_categorical_accuracy: 0.9062 - val_loss: 0.5880 - learning_rate: 0.0100
#
# Epoch 149: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 149/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9894 - loss: 0.1702 - val_categorical_accuracy: 0.9033 - val_loss: 0.5724 - learning_rate: 0.0100
#
# Epoch 150: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 150/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9907 - loss: 0.1678 - val_categorical_accuracy: 0.9095 - val_loss: 0.5606 - learning_rate: 0.0100
#
# Epoch 151: LearningRateScheduler setting learning rate to 0.0009999999776482583.
# Epoch 151/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9915 - loss: 0.1627 - val_categorical_accuracy: 0.9137 - val_loss: 0.5418 - learning_rate: 1.0000e-03
#
# Epoch 152: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 152/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9932 - loss: 0.1587 - val_categorical_accuracy: 0.9148 - val_loss: 0.5386 - learning_rate: 1.0000e-03
#
# Epoch 153: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 153/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9945 - loss: 0.1563 - val_categorical_accuracy: 0.9139 - val_loss: 0.5369 - learning_rate: 1.0000e-03
#
# Epoch 154: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 154/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9945 - loss: 0.1551 - val_categorical_accuracy: 0.9145 - val_loss: 0.5364 - learning_rate: 1.0000e-03
#
# Epoch 155: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 155/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9948 - loss: 0.1547 - val_categorical_accuracy: 0.9143 - val_loss: 0.5369 - learning_rate: 1.0000e-03
#
# Epoch 156: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 156/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9951 - loss: 0.1533 - val_categorical_accuracy: 0.9148 - val_loss: 0.5374 - learning_rate: 1.0000e-03
#
# Epoch 157: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 157/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9954 - loss: 0.1537 - val_categorical_accuracy: 0.9157 - val_loss: 0.5383 - learning_rate: 1.0000e-03
#
# Epoch 158: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 158/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9951 - loss: 0.1535 - val_categorical_accuracy: 0.9160 - val_loss: 0.5378 - learning_rate: 1.0000e-03
#
# Epoch 159: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 159/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9953 - loss: 0.1527 - val_categorical_accuracy: 0.9152 - val_loss: 0.5381 - learning_rate: 1.0000e-03
#
# Epoch 160: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 160/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9951 - loss: 0.1523 - val_categorical_accuracy: 0.9155 - val_loss: 0.5371 - learning_rate: 1.0000e-03
#
# Epoch 161: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 161/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1512 - val_categorical_accuracy: 0.9154 - val_loss: 0.5360 - learning_rate: 1.0000e-03
#
# Epoch 162: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 162/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9954 - loss: 0.1514 - val_categorical_accuracy: 0.9157 - val_loss: 0.5403 - learning_rate: 1.0000e-03
#
# Epoch 163: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 163/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1507 - val_categorical_accuracy: 0.9148 - val_loss: 0.5400 - learning_rate: 1.0000e-03
#
# Epoch 164: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 164/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1500 - val_categorical_accuracy: 0.9142 - val_loss: 0.5386 - learning_rate: 1.0000e-03
#
# Epoch 165: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 165/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1499 - val_categorical_accuracy: 0.9151 - val_loss: 0.5364 - learning_rate: 1.0000e-03
#
# Epoch 166: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 166/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9957 - loss: 0.1496 - val_categorical_accuracy: 0.9139 - val_loss: 0.5356 - learning_rate: 1.0000e-03
#
# Epoch 167: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 167/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1487 - val_categorical_accuracy: 0.9151 - val_loss: 0.5387 - learning_rate: 1.0000e-03
#
# Epoch 168: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 168/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1493 - val_categorical_accuracy: 0.9148 - val_loss: 0.5417 - learning_rate: 1.0000e-03
#
# Epoch 169: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 169/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9960 - loss: 0.1482 - val_categorical_accuracy: 0.9137 - val_loss: 0.5396 - learning_rate: 1.0000e-03
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 170/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9963 - loss: 0.1479 - val_categorical_accuracy: 0.9138 - val_loss: 0.5394 - learning_rate: 1.0000e-03
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 171/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1476 - val_categorical_accuracy: 0.9139 - val_loss: 0.5425 - learning_rate: 1.0000e-03
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 172/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9962 - loss: 0.1475 - val_categorical_accuracy: 0.9137 - val_loss: 0.5410 - learning_rate: 1.0000e-03
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 173/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1483 - val_categorical_accuracy: 0.9138 - val_loss: 0.5447 - learning_rate: 1.0000e-03
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 174/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9958 - loss: 0.1477 - val_categorical_accuracy: 0.9133 - val_loss: 0.5421 - learning_rate: 1.0000e-03
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 175/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9965 - loss: 0.1468 - val_categorical_accuracy: 0.9136 - val_loss: 0.5435 - learning_rate: 1.0000e-03
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 176/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1464 - val_categorical_accuracy: 0.9135 - val_loss: 0.5465 - learning_rate: 1.0000e-03
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 177/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9969 - loss: 0.1454 - val_categorical_accuracy: 0.9145 - val_loss: 0.5383 - learning_rate: 1.0000e-03
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 178/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9963 - loss: 0.1465 - val_categorical_accuracy: 0.9139 - val_loss: 0.5437 - learning_rate: 1.0000e-03
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 179/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1459 - val_categorical_accuracy: 0.9144 - val_loss: 0.5450 - learning_rate: 1.0000e-03
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 180/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9964 - loss: 0.1457 - val_categorical_accuracy: 0.9144 - val_loss: 0.5438 - learning_rate: 1.0000e-03
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 181/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9974 - loss: 0.1439 - val_categorical_accuracy: 0.9150 - val_loss: 0.5417 - learning_rate: 1.0000e-03
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 182/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1462 - val_categorical_accuracy: 0.9139 - val_loss: 0.5442 - learning_rate: 1.0000e-03
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 183/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1447 - val_categorical_accuracy: 0.9148 - val_loss: 0.5436 - learning_rate: 1.0000e-03
#
# Epoch 184: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 184/200
# ...
# Epoch 141/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9889 - loss: 0.1850 - val_categorical_accuracy: 0.9023 - val_loss: 0.5906 - learning_rate: 0.0100
#
# Epoch 142: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 142/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9890 - loss: 0.1816 - val_categorical_accuracy: 0.9014 - val_loss: 0.5845 - learning_rate: 0.0100
#
# Epoch 143: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 143/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9899 - loss: 0.1785 - val_categorical_accuracy: 0.9053 - val_loss: 0.5843 - learning_rate: 0.0100
#
# Epoch 144: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 144/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9905 - loss: 0.1757 - val_categorical_accuracy: 0.9022 - val_loss: 0.5949 - learning_rate: 0.0100
#
# Epoch 145: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 145/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9896 - loss: 0.1768 - val_categorical_accuracy: 0.9061 - val_loss: 0.5803 - learning_rate: 0.0100
#
# Epoch 146: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 146/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9907 - loss: 0.1729 - val_categorical_accuracy: 0.9043 - val_loss: 0.5806 - learning_rate: 0.0100
#
# Epoch 147: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 147/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9901 - loss: 0.1707 - val_categorical_accuracy: 0.9019 - val_loss: 0.6004 - learning_rate: 0.0100
#
# Epoch 148: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 148/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9904 - loss: 0.1712 - val_categorical_accuracy: 0.9047 - val_loss: 0.5834 - learning_rate: 0.0100
#
# Epoch 149: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 149/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9900 - loss: 0.1684 - val_categorical_accuracy: 0.9031 - val_loss: 0.5965 - learning_rate: 0.0100
#
# Epoch 150: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 150/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9908 - loss: 0.1653 - val_categorical_accuracy: 0.9041 - val_loss: 0.5803 - learning_rate: 0.0100
#
# Epoch 151: LearningRateScheduler setting learning rate to 0.0009999999776482583.
# Epoch 151/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9919 - loss: 0.1612 - val_categorical_accuracy: 0.9081 - val_loss: 0.5658 - learning_rate: 1.0000e-03
#
# Epoch 152: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 152/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9936 - loss: 0.1575 - val_categorical_accuracy: 0.9079 - val_loss: 0.5576 - learning_rate: 1.0000e-03
#
# Epoch 153: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 153/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9947 - loss: 0.1553 - val_categorical_accuracy: 0.9094 - val_loss: 0.5617 - learning_rate: 1.0000e-03
#
# Epoch 154: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 154/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9940 - loss: 0.1562 - val_categorical_accuracy: 0.9099 - val_loss: 0.5598 - learning_rate: 1.0000e-03
#
# Epoch 155: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 155/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9955 - loss: 0.1528 - val_categorical_accuracy: 0.9114 - val_loss: 0.5553 - learning_rate: 1.0000e-03
#
# Epoch 156: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 156/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9951 - loss: 0.1534 - val_categorical_accuracy: 0.9118 - val_loss: 0.5568 - learning_rate: 1.0000e-03
#
# Epoch 157: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 157/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9956 - loss: 0.1521 - val_categorical_accuracy: 0.9106 - val_loss: 0.5554 - learning_rate: 1.0000e-03
#
# Epoch 158: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 158/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9957 - loss: 0.1520 - val_categorical_accuracy: 0.9119 - val_loss: 0.5573 - learning_rate: 1.0000e-03
#
# Epoch 159: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 159/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9956 - loss: 0.1519 - val_categorical_accuracy: 0.9123 - val_loss: 0.5532 - learning_rate: 1.0000e-03
#
# Epoch 160: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 160/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9961 - loss: 0.1506 - val_categorical_accuracy: 0.9125 - val_loss: 0.5557 - learning_rate: 1.0000e-03
#
# Epoch 161: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 161/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9958 - loss: 0.1503 - val_categorical_accuracy: 0.9128 - val_loss: 0.5547 - learning_rate: 1.0000e-03
#
# Epoch 162: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 162/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9959 - loss: 0.1503 - val_categorical_accuracy: 0.9125 - val_loss: 0.5582 - learning_rate: 1.0000e-03
#
# Epoch 163: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 163/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9961 - loss: 0.1497 - val_categorical_accuracy: 0.9113 - val_loss: 0.5597 - learning_rate: 1.0000e-03
#
# Epoch 164: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 164/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9965 - loss: 0.1492 - val_categorical_accuracy: 0.9131 - val_loss: 0.5542 - learning_rate: 1.0000e-03
#
# Epoch 165: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 165/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9961 - loss: 0.1494 - val_categorical_accuracy: 0.9130 - val_loss: 0.5573 - learning_rate: 1.0000e-03
#
# Epoch 166: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 166/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9956 - loss: 0.1493 - val_categorical_accuracy: 0.9132 - val_loss: 0.5563 - learning_rate: 1.0000e-03
#
# Epoch 167: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 167/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9962 - loss: 0.1486 - val_categorical_accuracy: 0.9134 - val_loss: 0.5530 - learning_rate: 1.0000e-03
#
# Epoch 168: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 168/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9959 - loss: 0.1486 - val_categorical_accuracy: 0.9125 - val_loss: 0.5583 - learning_rate: 1.0000e-03
#
# Epoch 169: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 169/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9963 - loss: 0.1479 - val_categorical_accuracy: 0.9128 - val_loss: 0.5558 - learning_rate: 1.0000e-03
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 170/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9965 - loss: 0.1475 - val_categorical_accuracy: 0.9126 - val_loss: 0.5580 - learning_rate: 1.0000e-03
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 171/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9959 - loss: 0.1490 - val_categorical_accuracy: 0.9119 - val_loss: 0.5625 - learning_rate: 1.0000e-03
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 172/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9959 - loss: 0.1472 - val_categorical_accuracy: 0.9117 - val_loss: 0.5536 - learning_rate: 1.0000e-03
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 173/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9965 - loss: 0.1470 - val_categorical_accuracy: 0.9121 - val_loss: 0.5613 - learning_rate: 1.0000e-03
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 174/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9969 - loss: 0.1457 - val_categorical_accuracy: 0.9131 - val_loss: 0.5552 - learning_rate: 1.0000e-03
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 175/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9970 - loss: 0.1462 - val_categorical_accuracy: 0.9114 - val_loss: 0.5630 - learning_rate: 1.0000e-03
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 176/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9965 - loss: 0.1461 - val_categorical_accuracy: 0.9119 - val_loss: 0.5626 - learning_rate: 1.0000e-03
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 177/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9967 - loss: 0.1459 - val_categorical_accuracy: 0.9122 - val_loss: 0.5605 - learning_rate: 1.0000e-03
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 178/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9973 - loss: 0.1445 - val_categorical_accuracy: 0.9115 - val_loss: 0.5620 - learning_rate: 1.0000e-03
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 179/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9966 - loss: 0.1456 - val_categorical_accuracy: 0.9116 - val_loss: 0.5668 - learning_rate: 1.0000e-03
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 180/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9962 - loss: 0.1461 - val_categorical_accuracy: 0.9111 - val_loss: 0.5636 - learning_rate: 1.0000e-03
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 181/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9971 - loss: 0.1443 - val_categorical_accuracy: 0.9108 - val_loss: 0.5636 - learning_rate: 1.0000e-03
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 182/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9964 - loss: 0.1450 - val_categorical_accuracy: 0.9118 - val_loss: 0.5628 - learning_rate: 1.0000e-03
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 183/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9958 - loss: 0.1454 - val_categorical_accuracy: 0.9115 - val_loss: 0.5628 - learning_rate: 1.0000e-03
#
# Epoch 184: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 184/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9970 - loss: 0.1435 - val_categorical_accuracy: 0.9115 - val_loss: 0.5666 - learning_rate: 1.0000e-03
#
# Epoch 185: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 185/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9964 - loss: 0.1434 - val_categorical_accuracy: 0.9126 - val_loss: 0.5595 - learning_rate: 1.0000e-03
#
# Epoch 186: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 186/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9973 - loss: 0.1429 - val_categorical_accuracy: 0.9118 - val_loss: 0.5612 - learning_rate: 1.0000e-03
#
# Epoch 187: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 187/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9969 - loss: 0.1431 - val_categorical_accuracy: 0.9118 - val_loss: 0.5608 - learning_rate: 1.0000e-03
#
# Epoch 188: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 188/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9967 - loss: 0.1430 - val_categorical_accuracy: 0.9108 - val_loss: 0.5685 - learning_rate: 1.0000e-03
#
# Epoch 189: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 189/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9969 - loss: 0.1428 - val_categorical_accuracy: 0.9123 - val_loss: 0.5622 - learning_rate: 1.0000e-03
#
# Epoch 190: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 190/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9964 - loss: 0.1429 - val_categorical_accuracy: 0.9104 - val_loss: 0.5652 - learning_rate: 1.0000e-03
#
# Epoch 191: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 191/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9972 - loss: 0.1420 - val_categorical_accuracy: 0.9116 - val_loss: 0.5630 - learning_rate: 1.0000e-03
#
# Epoch 192: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 192/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9972 - loss: 0.1419 - val_categorical_accuracy: 0.9111 - val_loss: 0.5605 - learning_rate: 1.0000e-03
#
# Epoch 193: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 193/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9971 - loss: 0.1418 - val_categorical_accuracy: 0.9113 - val_loss: 0.5627 - learning_rate: 1.0000e-03
#
# Epoch 194: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 194/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9970 - loss: 0.1411 - val_categorical_accuracy: 0.9115 - val_loss: 0.5636 - learning_rate: 1.0000e-03
#
# Epoch 195: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 195/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9971 - loss: 0.1413 - val_categorical_accuracy: 0.9107 - val_loss: 0.5626 - learning_rate: 1.0000e-03
#
# Epoch 196: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 196/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9974 - loss: 0.1412 - val_categorical_accuracy: 0.9109 - val_loss: 0.5671 - learning_rate: 1.0000e-03
#
# Epoch 197: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 197/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9969 - loss: 0.1418 - val_categorical_accuracy: 0.9108 - val_loss: 0.5692 - learning_rate: 1.0000e-03
#
# Epoch 198: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 198/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9970 - loss: 0.1403 - val_categorical_accuracy: 0.9123 - val_loss: 0.5686 - learning_rate: 1.0000e-03
#
# Epoch 199: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 199/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9969 - loss: 0.1401 - val_categorical_accuracy: 0.9120 - val_loss: 0.5692 - learning_rate: 1.0000e-03
#
# Epoch 200: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 200/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9973 - loss: 0.1396 - val_categorical_accuracy: 0.9114 - val_loss: 0.5696 - learning_rate: 1.0000e-03
# Member 5 test loss: 0.5296  test accuracy: 0.9080
#
# Member test accuracies: [0.90679997 0.90990001 0.90450001 0.90979999 0.90799999]
# Mean member accuracy: 0.9078 ± 0.0020

# %%
# Plotting training curves

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

for member_id, history in enumerate(ensemble_histories):
    ## Plot 1
    ax1.plot(history.history["loss"], label=f"member {member_id + 1} train")
    ax1.plot(history.history["val_loss"], linestyle="--", label=f"member {member_id + 1} val")

    ## Plot 2
    ax2.plot(history.history["categorical_accuracy"], label=f"member {member_id + 1} train")
    ax2.plot(history.history["val_categorical_accuracy"], linestyle="--", label=f"member {member_id + 1} val")

ax1.set_xlabel("epoch"); ax1.set_ylabel("loss")
ax1.set_title("Deep Ensemble ResNet-20 — Loss")
ax1.legend(fontsize=8)

ax2.set_xlabel("epoch"); ax2.set_ylabel("accuracy")
ax2.set_title("Deep Ensemble ResNet-20 — Accuracy")
ax2.legend(fontsize=8)

plt.tight_layout(); plt.show()

# %%
# Loading SVHN as the out-of-distribution reference set
'''
Per the proposal §3.5, SVHN (street view of house numbers) is used as the
OOD test set. SVHN images are 32x32 colour photos like CIFAR-10, but of
digits, so a CIFAR-10 trained model should ideally report higher predictive
entropy on SVHN inputs than on its in-distribution CIFAR-10 test images.

We download the official SVHN test split (.mat) directly instead of using
tensorflow_datasets, which removes a flaky lazy-import dependency. The ~26k
images rescale to [0, 1] to match CIFAR-10 preprocessing; cached after the
first download.
'''
import os, urllib.request
from scipy.io import loadmat

svhn_path = "svhn_test_32x32.mat"
if not os.path.exists(svhn_path):
    urllib.request.urlretrieve(
        "http://ufldl.stanford.edu/housenumbers/test_32x32.mat", svhn_path)

mat = loadmat(svhn_path)
# mat["X"] has shape (32, 32, 3, N); move the sample axis to the front, rescale.
x_svhn = np.transpose(mat["X"], (3, 0, 1, 2)).astype("float32") / 255.0

print(f"SVHN OOD set: {x_svhn.shape}")
# Out:
# SVHN OOD set: (26032, 32, 32, 3)

# %%
# Loading CIFAR-10-C (common corruptions) as the in-distribution shift set
'''
Per the proposal §3.5, CIFAR-10-C (Hendrycks & Dietterich 2019) is the
corruption / covariate-shift evaluation set: the same 10 CIFAR-10 classes but
with algorithmic corruptions at graded severity. Unlike SVHN (far / semantic
OOD), these are in-domain-but-degraded inputs, so they probe a different kind
of uncertainty.

Patched folder handling:
- verifies labels.npy and every expected corruption .npy file;
- repairs partial extractions by re-extracting CIFAR-10-C.tar;
- re-downloads the tar if it is missing, invalid, or incomplete;
- raises a clear error listing missing files if the folder is still incomplete.
'''
import os, urllib.request, tarfile
import numpy as np

SEVERITY = globals().get("SEVERITY", 3)
CORRUPTIONS = globals().get("CORRUPTIONS", [
    "gaussian_noise", "shot_noise", "impulse_noise", "defocus_blur",
    "glass_blur", "motion_blur", "zoom_blur", "snow", "frost", "fog",
    "brightness", "contrast", "elastic_transform", "pixelate", "jpeg_compression",
])

CIFAR10C_ROOT = "CIFAR-10-C"
CIFAR10C_TAR = "CIFAR-10-C.tar"
CIFAR10C_URLS = [
    "https://zenodo.org/records/2535967/files/CIFAR-10-C.tar?download=1",
    "https://zenodo.org/record/2535967/files/CIFAR-10-C.tar",
]


def _required_cifar10c_files(corruptions=CORRUPTIONS):
    return ["labels.npy"] + [f"{corr}.npy" for corr in corruptions]


def _cifar10c_score(root, corruptions=CORRUPTIONS):
    try:
        file_set = set(os.listdir(root))
    except OSError:
        return 0
    required = set(_required_cifar10c_files(corruptions))
    return len(required.intersection(file_set))


def _find_cifar10c_root(start=".", corruptions=CORRUPTIONS):
    """Return the directory that best looks like the extracted CIFAR-10-C root."""
    required = set(_required_cifar10c_files(corruptions))
    candidates = []

    # Fast-path the expected folder first.
    if os.path.isdir(CIFAR10C_ROOT):
        candidates.append((_cifar10c_score(CIFAR10C_ROOT, corruptions), CIFAR10C_ROOT))

    # Then support nested layouts produced by some archive/extraction tools.
    for root, dirs, files in os.walk(start):
        # Avoid descending into hidden/checkpoint folders, which can make Drive scans noisy.
        dirs[:] = [d for d in dirs if not d.startswith(".") and d != "__MACOSX"]
        file_set = set(files)
        if "labels.npy" in file_set or any(f"{corr}.npy" in file_set for corr in corruptions):
            candidates.append((len(required.intersection(file_set)), root))

    if not candidates:
        return CIFAR10C_ROOT

    candidates.sort(key=lambda item: item[0], reverse=True)
    return candidates[0][1]


def _missing_cifar10c_files(root, corruptions=CORRUPTIONS):
    return [
        filename
        for filename in _required_cifar10c_files(corruptions)
        if not os.path.exists(os.path.join(root, filename))
    ]


def _safe_extract_tar(tar, path="."):
    """Protect against path traversal before extracting the downloaded tar."""
    base = os.path.abspath(path)
    for member in tar.getmembers():
        member_path = os.path.abspath(os.path.join(path, member.name))
        if not (member_path == base or member_path.startswith(base + os.sep)):
            raise RuntimeError(f"Unsafe path in tar archive: {member.name}")
    tar.extractall(path)


def _download_cifar10c_tar(tar_path=CIFAR10C_TAR, urls=CIFAR10C_URLS):
    last_error = None
    for url in urls:
        try:
            print(f"Downloading CIFAR-10-C from {url}")
            urllib.request.urlretrieve(url, tar_path)
            return
        except Exception as exc:
            last_error = exc
            print(f"Download failed from {url}: {exc}")

    raise RuntimeError("Could not download CIFAR-10-C from any configured URL.") from last_error


def _extract_cifar10c_tar(tar_path=CIFAR10C_TAR):
    try:
        with tarfile.open(tar_path) as tar:
            _safe_extract_tar(tar, ".")
    except (tarfile.TarError, EOFError) as exc:
        print("Existing CIFAR-10-C tar is invalid or incomplete; re-downloading.")
        if os.path.exists(tar_path):
            os.remove(tar_path)
        _download_cifar10c_tar(tar_path)
        with tarfile.open(tar_path) as tar:
            _safe_extract_tar(tar, ".")


def load_cifar10c(severity=SEVERITY, corruptions=CORRUPTIONS, root=CIFAR10C_ROOT):
    """Download/extract CIFAR-10-C if needed, verify all files, then load one severity."""
    if not (1 <= int(severity) <= 5):
        raise ValueError("CIFAR-10-C severity must be an integer from 1 to 5.")
    severity = int(severity)

    root = _find_cifar10c_root(root, corruptions)
    missing = _missing_cifar10c_files(root, corruptions)

    if missing:
        print(f"CIFAR-10-C is incomplete at '{root}'. Missing {len(missing)} file(s): {missing[:5]}")
        if not os.path.exists(CIFAR10C_TAR):
            print("CIFAR-10-C tar is not present; downloading it now (~2.9 GB).")
            _download_cifar10c_tar(CIFAR10C_TAR)
        else:
            print("CIFAR-10-C tar already exists; re-extracting it to repair the dataset.")

        _extract_cifar10c_tar(CIFAR10C_TAR)
        root = _find_cifar10c_root(root, corruptions)
        missing = _missing_cifar10c_files(root, corruptions)

    if missing:
        raise FileNotFoundError(
            "CIFAR-10-C is still incomplete after extraction. "
            f"Root checked: '{root}'. Missing files include: {missing[:10]}. "
            "Delete CIFAR-10-C and CIFAR-10-C.tar, then rerun this cell."
        )

    lo, hi = (severity - 1) * 10000, severity * 10000
    labels_full = np.load(os.path.join(root, "labels.npy"))
    labels_block = labels_full[lo:hi] if labels_full.shape[0] > 10000 else labels_full

    x_parts, y_parts = [], []
    for corr in corruptions:
        path = os.path.join(root, f"{corr}.npy")
        arr = np.load(path)[lo:hi]    # (10000, 32, 32, 3) uint8
        x_parts.append(arr)
        y_parts.append(labels_block)

    x_cifar10c = np.concatenate(x_parts, axis=0).astype("float32") / 255.0
    labels_cifar10c = np.concatenate(y_parts, axis=0).astype("int64")

    print(
        f"CIFAR-10-C set (severity {severity}, {len(corruptions)} corruptions): "
        f"{x_cifar10c.shape}, labels {labels_cifar10c.shape}"
    )
    print(f"CIFAR-10-C root: {root}")

    return x_cifar10c, labels_cifar10c


# Execute the load in this cell so Run all prepares CIFAR-10-C before prediction.
x_cifar10c, labels_cifar10c = load_cifar10c(SEVERITY, CORRUPTIONS)
# Out:
# CIFAR-10-C set (severity 3, 15 corruptions): (150000, 32, 32, 3), labels (150000,)
# CIFAR-10-C root: CIFAR-10-C

# %%
# Generating predictions for the evaluation file
'''
This is the only output the downstream evaluation notebook needs from this
file. We produce softmax probabilities on:
  - the CIFAR-10 test set (in-distribution),
  - the SVHN test set (out-of-distribution),
and stash the true labels and the predicted classes alongside.

For the deep ensemble, each independently trained member gives one predictive
probability vector. The final ensemble probability is the average across the
five members.
'''


# Guard: load CIFAR-10-C here if the dedicated loading cell was skipped.
# This prevents this notebook from producing results without CIFAR-10-C outputs.
if "x_cifar10c" not in globals() or "labels_cifar10c" not in globals():
    print("CIFAR-10-C was not loaded before prediction; loading it now.")
    if "load_cifar10c" not in globals():
        import os, urllib.request, tarfile
        import numpy as np

        SEVERITY = globals().get("SEVERITY", 3)
        CORRUPTIONS = globals().get("CORRUPTIONS", [
            "gaussian_noise", "shot_noise", "impulse_noise", "defocus_blur",
            "glass_blur", "motion_blur", "zoom_blur", "snow", "frost", "fog",
            "brightness", "contrast", "elastic_transform", "pixelate", "jpeg_compression",
        ])

        CIFAR10C_ROOT = "CIFAR-10-C"
        CIFAR10C_TAR = "CIFAR-10-C.tar"
        CIFAR10C_URLS = [
            "https://zenodo.org/records/2535967/files/CIFAR-10-C.tar?download=1",
            "https://zenodo.org/record/2535967/files/CIFAR-10-C.tar",
        ]


        def _required_cifar10c_files(corruptions=CORRUPTIONS):
            return ["labels.npy"] + [f"{corr}.npy" for corr in corruptions]


        def _cifar10c_score(root, corruptions=CORRUPTIONS):
            try:
                file_set = set(os.listdir(root))
            except OSError:
                return 0
            required = set(_required_cifar10c_files(corruptions))
            return len(required.intersection(file_set))


        def _find_cifar10c_root(start=".", corruptions=CORRUPTIONS):
            """Return the directory that best looks like the extracted CIFAR-10-C root."""
            required = set(_required_cifar10c_files(corruptions))
            candidates = []

            # Fast-path the expected folder first.
            if os.path.isdir(CIFAR10C_ROOT):
                candidates.append((_cifar10c_score(CIFAR10C_ROOT, corruptions), CIFAR10C_ROOT))

            # Then support nested layouts produced by some archive/extraction tools.
            for root, dirs, files in os.walk(start):
                # Avoid descending into hidden/checkpoint folders, which can make Drive scans noisy.
                dirs[:] = [d for d in dirs if not d.startswith(".") and d != "__MACOSX"]
                file_set = set(files)
                if "labels.npy" in file_set or any(f"{corr}.npy" in file_set for corr in corruptions):
                    candidates.append((len(required.intersection(file_set)), root))

            if not candidates:
                return CIFAR10C_ROOT

            candidates.sort(key=lambda item: item[0], reverse=True)
            return candidates[0][1]


        def _missing_cifar10c_files(root, corruptions=CORRUPTIONS):
            return [
                filename
                for filename in _required_cifar10c_files(corruptions)
                if not os.path.exists(os.path.join(root, filename))
            ]


        def _safe_extract_tar(tar, path="."):
            """Protect against path traversal before extracting the downloaded tar."""
            base = os.path.abspath(path)
            for member in tar.getmembers():
                member_path = os.path.abspath(os.path.join(path, member.name))
                if not (member_path == base or member_path.startswith(base + os.sep)):
                    raise RuntimeError(f"Unsafe path in tar archive: {member.name}")
            tar.extractall(path)


        def _download_cifar10c_tar(tar_path=CIFAR10C_TAR, urls=CIFAR10C_URLS):
            last_error = None
            for url in urls:
                try:
                    print(f"Downloading CIFAR-10-C from {url}")
                    urllib.request.urlretrieve(url, tar_path)
                    return
                except Exception as exc:
                    last_error = exc
                    print(f"Download failed from {url}: {exc}")

            raise RuntimeError("Could not download CIFAR-10-C from any configured URL.") from last_error


        def _extract_cifar10c_tar(tar_path=CIFAR10C_TAR):
            try:
                with tarfile.open(tar_path) as tar:
                    _safe_extract_tar(tar, ".")
            except (tarfile.TarError, EOFError) as exc:
                print("Existing CIFAR-10-C tar is invalid or incomplete; re-downloading.")
                if os.path.exists(tar_path):
                    os.remove(tar_path)
                _download_cifar10c_tar(tar_path)
                with tarfile.open(tar_path) as tar:
                    _safe_extract_tar(tar, ".")


        def load_cifar10c(severity=SEVERITY, corruptions=CORRUPTIONS, root=CIFAR10C_ROOT):
            """Download/extract CIFAR-10-C if needed, verify all files, then load one severity."""
            if not (1 <= int(severity) <= 5):
                raise ValueError("CIFAR-10-C severity must be an integer from 1 to 5.")
            severity = int(severity)

            root = _find_cifar10c_root(root, corruptions)
            missing = _missing_cifar10c_files(root, corruptions)

            if missing:
                print(f"CIFAR-10-C is incomplete at '{root}'. Missing {len(missing)} file(s): {missing[:5]}")
                if not os.path.exists(CIFAR10C_TAR):
                    print("CIFAR-10-C tar is not present; downloading it now (~2.9 GB).")
                    _download_cifar10c_tar(CIFAR10C_TAR)
                else:
                    print("CIFAR-10-C tar already exists; re-extracting it to repair the dataset.")

                _extract_cifar10c_tar(CIFAR10C_TAR)
                root = _find_cifar10c_root(root, corruptions)
                missing = _missing_cifar10c_files(root, corruptions)

            if missing:
                raise FileNotFoundError(
                    "CIFAR-10-C is still incomplete after extraction. "
                    f"Root checked: '{root}'. Missing files include: {missing[:10]}. "
                    "Delete CIFAR-10-C and CIFAR-10-C.tar, then rerun this cell."
                )

            lo, hi = (severity - 1) * 10000, severity * 10000
            labels_full = np.load(os.path.join(root, "labels.npy"))
            labels_block = labels_full[lo:hi] if labels_full.shape[0] > 10000 else labels_full

            x_parts, y_parts = [], []
            for corr in corruptions:
                path = os.path.join(root, f"{corr}.npy")
                arr = np.load(path)[lo:hi]    # (10000, 32, 32, 3) uint8
                x_parts.append(arr)
                y_parts.append(labels_block)

            x_cifar10c = np.concatenate(x_parts, axis=0).astype("float32") / 255.0
            labels_cifar10c = np.concatenate(y_parts, axis=0).astype("int64")

            print(
                f"CIFAR-10-C set (severity {severity}, {len(corruptions)} corruptions): "
                f"{x_cifar10c.shape}, labels {labels_cifar10c.shape}"
            )
            print(f"CIFAR-10-C root: {root}")

            return x_cifar10c, labels_cifar10c
    x_cifar10c, labels_cifar10c = load_cifar10c(SEVERITY, CORRUPTIONS)

all_probs_test     = []
all_probs_svhn     = []
all_probs_cifar10c = []

for member_id, model in enumerate(ensemble_models):
    print(f"Predicting with ensemble member {member_id + 1}/{ensemble_size}")

    ## In-distribution: CIFAR-10 test set
    logits_test = model.predict(test_ds)                        # (10000, 10)
    probs_test_member = tf.nn.softmax(logits_test, axis=-1).numpy()
    all_probs_test.append(probs_test_member)

    ## Out-of-distribution: SVHN test set
    logits_svhn = model.predict(x_svhn, batch_size=batch_size)
    probs_svhn_member = tf.nn.softmax(logits_svhn, axis=-1).numpy()
    all_probs_svhn.append(probs_svhn_member)

    ## In-distribution shift: CIFAR-10-C (severity 3, 15 corruptions)
    logits_c10c = model.predict(x_cifar10c, batch_size=batch_size)
    probs_c10c_member = tf.nn.softmax(logits_c10c, axis=-1).numpy()
    all_probs_cifar10c.append(probs_c10c_member)

all_probs_test     = np.stack(all_probs_test, axis=0)        # (5, 10000, 10)
all_probs_svhn     = np.stack(all_probs_svhn, axis=0)        # (5, N_svhn, 10)
all_probs_cifar10c = np.stack(all_probs_cifar10c, axis=0)    # (5, 150000, 10)

probs_test     = all_probs_test.mean(axis=0)
probs_svhn     = all_probs_svhn.mean(axis=0)
probs_cifar10c = all_probs_cifar10c.mean(axis=0)

preds_test  = np.argmax(probs_test, axis=1)
labels_test = np.argmax(y_test, axis=1)

print(f"Ensemble test accuracy: {(preds_test == labels_test).mean():.4f}")
print(f"all_probs_test:     {all_probs_test.shape}")
print(f"probs_test:         {probs_test.shape}")
print(f"all_probs_svhn:     {all_probs_svhn.shape}")
print(f"probs_svhn:         {probs_svhn.shape}")
print(f"all_probs_cifar10c: {all_probs_cifar10c.shape}")
print(f"probs_cifar10c:     {probs_cifar10c.shape}")
# Out:
# Predicting with ensemble member 1/5
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step
# Predicting with ensemble member 2/5
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# Predicting with ensemble member 3/5
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# Predicting with ensemble member 4/5
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step
# Predicting with ensemble member 5/5
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# Ensemble test accuracy: 0.9279
# all_probs_test:     (5, 10000, 10)
# probs_test:         (10000, 10)
# all_probs_svhn:     (5, 26032, 10)
# probs_svhn:         (26032, 10)
# all_probs_cifar10c: (5, 150000, 10)
# probs_cifar10c:     (150000, 10)

# %%
# Saving raw outputs for the evaluation file
'''
Save format (shared across all benchmarks). The evaluation notebook will
load these by filename and produce ECE, reliability diagrams, OOD AUROC,
risk-coverage and (for the BNN benchmarks) the epistemic / aleatoric
decomposition.

Keys:
  model_name       - human-readable string identifier
  probs_test       - (N_test, 10)  mean predictive distribution on CIFAR-10 test
  labels_test      - (N_test,)     true labels (integer 0-9)
  preds_test       - (N_test,)     argmax of probs_test
  probs_svhn       - (N_svhn, 10)  mean predictive distribution on SVHN OOD
  all_probs_test   - (S, N_test, 10) per-member probs, where S=5
  all_probs_svhn   - (S, N_svhn, 10) per-member probs, where S=5
  member_test_accs - (S,) per-member CIFAR-10 test accuracies
'''
np.savez("deep_ensemble_5_results.npz",
         model_name="deep_ensemble_5",
         probs_test=probs_test,
         labels_test=labels_test,
         preds_test=preds_test,
         probs_svhn=probs_svhn,
         probs_cifar10c=probs_cifar10c,
         labels_cifar10c=labels_cifar10c,
         cifar10c_severity=SEVERITY,
         all_probs_test=all_probs_test,
         all_probs_svhn=all_probs_svhn,
         all_probs_cifar10c=all_probs_cifar10c,
         member_test_accs=member_accs)

print("Saved deep_ensemble_5_results.npz")
# Out:
# Saved deep_ensemble_5_results.npz
