# %%
from google.colab import drive
import os

drive.mount('/content/drive')                          # auth popup, once per session
RESULTS_DIR = '/content/drive/MyDrive/thesis_results'  # change name if you like
os.makedirs(RESULTS_DIR, exist_ok=True)
os.chdir(RESULTS_DIR)                                   # all relative saves now land here
print('Saving to:', os.getcwd())
# Out:
# Mounted at /content/drive
# Saving to: /content/drive/MyDrive/thesis_results

# %%
# Imports

## Core libraries
import numpy as np
import matplotlib.pyplot as plt

## TensorFlow / Keras
import tensorflow as tf
import keras
from keras import ops, layers
from keras.callbacks import Callback
from keras.models import Sequential, Model
from keras.layers import Input, Conv2D, Dense

# %%
# Setting seeds

np.random.seed(1999)
tf.random.set_seed(1999)

# %%
# Loading the dataset

(x_train_full, y_train_full), (x_test, y_test) = keras.datasets.cifar10.load_data()

## Feature scaling (mapping pixel values to [0,1])
'''
This is used as neural network training via gradient descent is sensitive to the
scale of inputs (through activations a = Wx + b). This causes gradients to vanish
and makes the loss landscape poorly conditioned.
'''
x_train_full = x_train_full / 255.0
x_test = x_test / 255.0

''' Recalling our y values are our categories '''
y_train_full = keras.utils.to_categorical(y_train_full, 10)
y_test = keras.utils.to_categorical(y_test, 10)

## Setting up our validation dataset
n_val = int(0.2 * len(x_train_full))
perm = np.random.permutation(len(x_train_full))
val_idx, train_idx = perm[:n_val], perm[n_val:]
x_val, y_val = x_train_full[val_idx], y_train_full[val_idx]
x_train, y_train = x_train_full[train_idx], y_train_full[train_idx]

## Check
print(f"train: {x_train.shape} val: {x_val.shape} test: {x_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# train: (40000, 32, 32, 3) val: (10000, 32, 32, 3) test: (10000, 32, 32, 3)

# %%
# Augmenting the dataset
'''
This involves creating new training examples by applying label preserving
transformations to existing examples e.g. flips, crops, scaling, colour jitter,
adding noise, ...
'''

'''
Applying three transformations in sequence, we pad the image with black 0s,
then randomly crop the newly padded image (so the model learns that a shifted
horse picture is still a horse), and then randomly mirroring the image from left
to right.
'''
augment = keras.Sequential([layers.ZeroPadding2D(padding=4),
                            layers.RandomCrop(32, 32),
                            layers.RandomFlip("horizontal")])

batch_size = 128

'''
This builds the full training data pipeline, where:
- The from_tensor_slices((x_train, y_train)) wraps the numpy arrays into a
  tf.data.Dataset that has image label pairs one at a time.
- For .shuffle(len(x_train)) - this shifts the entire dataset after each epoch.
- For .map(lambda x, y: (augment(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
  this applies the augmentation pipeline to each batch of images whilst leaving
  labels untouched. The training=True is important because RandomCrop and
  RandomFlip only apply their transformations during training. The
  num_parallel_calls=tf.data.AUTOTUNE lets TensorFlow decide how many batches to
  augment in parallel across CPU threads.
'''
train_ds = (tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size).map(lambda x, y: (augment(x, training=True), y),
            num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE))

### Recalling that there is no augmentation for validation and test datasets
val_ds  = (tf.data.Dataset.from_tensor_slices((x_val,  y_val ))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))
test_ds = (tf.data.Dataset.from_tensor_slices((x_test, y_test))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))

# %%
# MC Dropout layer + Residual block with dropout between convolutions
'''
The MCDropout class subclasses keras.layers.Dropout and overrides its call
method so that training=True is always forced. This means the stochastic
masking remains active at test time, which is exactly what Gal & Ghahramani
(2016) showed is equivalent to drawing samples from an approximate posterior
over the weights of a deep network.
'''
class MCDropout(layers.Dropout):
    def call(self, inputs, training=None):
        return super().call(inputs, training=True)

'''
The residual block here matches the plain ResNet-20 block but inserts an
MCDropout layer between the two convolutions inside each block. We follow the
Summative-2 spec (and the original Gal & Ghahramani placement of dropout
inside the residual unit) so that the BNN approximation lives in the
representation-extraction part of the network rather than at the classifier
head.
'''
class ResidualBlock(keras.layers.Layer):

    def __init__(self, filters, stride=1, dropout_rate=0.0, **kwargs):
        super().__init__(**kwargs)
        self.filters = filters
        self.stride = stride
        self.dropout_rate = dropout_rate

        self.conv1 = layers.Conv2D(filters, 3, strides=stride, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")
        self.bn1 = layers.BatchNormalization()

        ### Dropout layer is constructed only if rate > 0 (so the same class can also build a deterministic block).
        self.drop = MCDropout(dropout_rate) if dropout_rate > 0 else None

        self.conv2 = layers.Conv2D(filters, 3, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")
        self.bn2 = layers.BatchNormalization()
        self.relu = layers.Activation("relu")

    def build(self, input_shape):
        in_channels = input_shape[-1]

        if self.stride != 1 or in_channels != self.filters:
            self.proj = layers.Conv2D(self.filters, 1, strides=self.stride, padding="valid",
                                      kernel_regularizer=keras.regularizers.L2(1e-4),
                                      kernel_initializer="he_normal")
            self.bn_proj = layers.BatchNormalization()
        else:
            self.proj = None

        super().build(input_shape)

    def call(self, x):
        if self.proj is not None:
            shortcut = self.bn_proj(self.proj(x))
        else:
            shortcut = x

        ### Main path: conv -> BN -> ReLU -> (MC Dropout if active) -> conv -> BN
        out = self.relu(self.bn1(self.conv1(x)))
        if self.drop is not None:
            out = self.drop(out)
        out = self.bn2(self.conv2(out))

        return self.relu(out + shortcut)

    def get_config(self):
        config = super().get_config()
        config.update({"filters": self.filters,
                       "stride": self.stride,
                       "dropout_rate": self.dropout_rate})
        return config

# %%
# build_resnet20 — MC Dropout variant
'''
Identical architecture to the deterministic build_resnet20, except a
dropout_rate argument is propagated to every residual block. Each block then
inserts an MCDropout layer between its two convolutions; the layer is always
stochastic (training=True forced) so that test-time forward passes draw
samples from the approximate posterior.
'''
def build_resnet20(dropout_rate=0.0):
    inputs = keras.Input(shape=(32, 32, 3))

    x = layers.Conv2D(16, 3, padding="same",
                      kernel_regularizer=keras.regularizers.L2(1e-4),
                      kernel_initializer="he_normal")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    for _ in range(3):
        x = ResidualBlock(16, dropout_rate=dropout_rate)(x)

    x = ResidualBlock(32, stride=2, dropout_rate=dropout_rate)(x)
    for _ in range(2):
        x = ResidualBlock(32, dropout_rate=dropout_rate)(x)

    x = ResidualBlock(64, stride=2, dropout_rate=dropout_rate)(x)
    for _ in range(2):
        x = ResidualBlock(64, dropout_rate=dropout_rate)(x)

    x = layers.GlobalAveragePooling2D()(x)

    outputs = layers.Dense(10, kernel_initializer="he_normal")(x)

    return keras.Model(inputs, outputs)

# %%
# Building MC Dropout model
'''
We choose dropout_rate=0.1 following the Summative-2 hyperparameter sweep
({0.1, 0.3, 0.5}) which found 0.1 gave the best validation accuracy. Higher
rates over-regularised ResNet-20 for CIFAR-10.

Note: the MC Dropout model uses the same training-time loss and optimiser as
the deterministic baseline; the only architectural change is the dropout
layer inside every residual block (which stays active at test time).
'''
DROPOUT_RATE = 0.1

mc_model = build_resnet20(dropout_rate=DROPOUT_RATE)
mc_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ (None, 32, 32, 16)     │         4,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_1                │ (None, 32, 32, 16)     │         4,768 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_2                │ (None, 32, 32, 16)     │         4,768 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_3                │ (None, 16, 16, 32)     │        14,816 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_4                │ (None, 16, 16, 32)     │        18,752 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_5                │ (None, 16, 16, 32)     │        18,752 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_6                │ (None, 8, 8, 64)       │        58,304 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_7                │ (None, 8, 8, 64)       │        74,368 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_8                │ (None, 8, 8, 64)       │        74,368 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 274,826 (1.05 MB)
#  Trainable params: 273,258 (1.04 MB)
#  Non-trainable params: 1,568 (6.12 KB)

# %%
# Training MC Dropout model

def lr_schedule(epoch, lr):
    if epoch in (100, 150):
        return lr * 0.1
    return lr

# %%
# Compiling

mc_model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1, momentum=0.9),
                 loss=keras.losses.CategoricalCrossentropy(from_logits=True),
                 metrics=["categorical_accuracy"])

# %%
# Callbacks for checkpoints

mc_callbacks = [keras.callbacks.ModelCheckpoint("resnet20_mc_best.weights.h5",
                                                monitor="val_loss",
                                                save_best_only=True,
                                                save_weights_only=True),
                keras.callbacks.LearningRateScheduler(lr_schedule, verbose=1)]

# %%
# Training

history_mc = mc_model.fit(train_ds,
                          epochs=200,
                          validation_data=val_ds,
                          callbacks=mc_callbacks)

mc_model.load_weights("resnet20_mc_best.weights.h5")

# Single-sample test evaluation (deterministic-style readout for sanity)
mc_loss, mc_acc = mc_model.evaluate(test_ds, verbose=0)
print(f"\nMC Dropout single-sample test loss: {mc_loss:.4f}  Test accuracy: {mc_acc:.4f}")
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 1/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 52s 93ms/step - categorical_accuracy: 0.3506 - loss: 1.8951 - val_categorical_accuracy: 0.2399 - val_loss: 2.7531 - learning_rate: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 2/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.5252 - loss: 1.4534 - val_categorical_accuracy: 0.5305 - val_loss: 1.4740 - learning_rate: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 3/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.6156 - loss: 1.2257 - val_categorical_accuracy: 0.3896 - val_loss: 2.4625 - learning_rate: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 4/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.6664 - loss: 1.0994 - val_categorical_accuracy: 0.4765 - val_loss: 2.0055 - learning_rate: 0.1000
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 5/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.7019 - loss: 1.0011 - val_categorical_accuracy: 0.5697 - val_loss: 1.5714 - learning_rate: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 6/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - categorical_accuracy: 0.7383 - loss: 0.9132 - val_categorical_accuracy: 0.6957 - val_loss: 1.0353 - learning_rate: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 7/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - categorical_accuracy: 0.7565 - loss: 0.8586 - val_categorical_accuracy: 0.6966 - val_loss: 1.0290 - learning_rate: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 8/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.7701 - loss: 0.8220 - val_categorical_accuracy: 0.7298 - val_loss: 0.9285 - learning_rate: 0.1000
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 9/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.7862 - loss: 0.7809 - val_categorical_accuracy: 0.7116 - val_loss: 1.0065 - learning_rate: 0.1000
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 10/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.7955 - loss: 0.7521 - val_categorical_accuracy: 0.6911 - val_loss: 1.0494 - learning_rate: 0.1000
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 11/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - categorical_accuracy: 0.8030 - loss: 0.7342 - val_categorical_accuracy: 0.7491 - val_loss: 0.9186 - learning_rate: 0.1000
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 12/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8123 - loss: 0.7167 - val_categorical_accuracy: 0.7124 - val_loss: 1.0243 - learning_rate: 0.1000
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 13/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8181 - loss: 0.6943 - val_categorical_accuracy: 0.7341 - val_loss: 0.9490 - learning_rate: 0.1000
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 14/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8218 - loss: 0.6891 - val_categorical_accuracy: 0.6530 - val_loss: 1.3338 - learning_rate: 0.1000
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 15/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8268 - loss: 0.6736 - val_categorical_accuracy: 0.7333 - val_loss: 0.9913 - learning_rate: 0.1000
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 16/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8330 - loss: 0.6568 - val_categorical_accuracy: 0.7624 - val_loss: 0.9188 - learning_rate: 0.1000
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 17/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - categorical_accuracy: 0.8335 - loss: 0.6614 - val_categorical_accuracy: 0.7557 - val_loss: 0.9027 - learning_rate: 0.1000
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 18/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8421 - loss: 0.6373 - val_categorical_accuracy: 0.7818 - val_loss: 0.8956 - learning_rate: 0.1000
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 19/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 45/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8765 - loss: 0.5647 - val_categorical_accuracy: 0.7158 - val_loss: 1.1531 - learning_rate: 0.1000
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 46/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8809 - loss: 0.5544 - val_categorical_accuracy: 0.7584 - val_loss: 0.9839 - learning_rate: 0.1000
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 47/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8782 - loss: 0.5609 - val_categorical_accuracy: 0.8214 - val_loss: 0.7628 - learning_rate: 0.1000
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 48/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8809 - loss: 0.5516 - val_categorical_accuracy: 0.7928 - val_loss: 0.8406 - learning_rate: 0.1000
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 49/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8778 - loss: 0.5612 - val_categorical_accuracy: 0.7491 - val_loss: 1.0659 - learning_rate: 0.1000
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 50/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8822 - loss: 0.5526 - val_categorical_accuracy: 0.7715 - val_loss: 0.9209 - learning_rate: 0.1000
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 51/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8811 - loss: 0.5530 - val_categorical_accuracy: 0.8303 - val_loss: 0.7065 - learning_rate: 0.1000
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 52/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8791 - loss: 0.5560 - val_categorical_accuracy: 0.7835 - val_loss: 0.8714 - learning_rate: 0.1000
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 53/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8832 - loss: 0.5510 - val_categorical_accuracy: 0.7846 - val_loss: 0.9071 - learning_rate: 0.1000
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 54/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8831 - loss: 0.5555 - val_categorical_accuracy: 0.8181 - val_loss: 0.7846 - learning_rate: 0.1000
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 55/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8825 - loss: 0.5506 - val_categorical_accuracy: 0.7715 - val_loss: 1.0270 - learning_rate: 0.1000
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 56/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8840 - loss: 0.5513 - val_categorical_accuracy: 0.8030 - val_loss: 0.8378 - learning_rate: 0.1000
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 57/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8830 - loss: 0.5527 - val_categorical_accuracy: 0.7868 - val_loss: 0.9088 - learning_rate: 0.1000
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 58/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8877 - loss: 0.5415 - val_categorical_accuracy: 0.8024 - val_loss: 0.8658 - learning_rate: 0.1000
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 59/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8863 - loss: 0.5447 - val_categorical_accuracy: 0.7057 - val_loss: 1.2236 - learning_rate: 0.1000
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 60/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8861 - loss: 0.5472 - val_categorical_accuracy: 0.6908 - val_loss: 1.3407 - learning_rate: 0.1000
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 61/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8893 - loss: 0.5401 - val_categorical_accuracy: 0.7530 - val_loss: 1.0070 - learning_rate: 0.1000
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 62/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8857 - loss: 0.5444 - val_categorical_accuracy: 0.7959 - val_loss: 0.8763 - learning_rate: 0.1000
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 63/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8862 - loss: 0.5461 - val_categorical_accuracy: 0.7829 - val_loss: 0.9080 - learning_rate: 0.1000
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 64/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8848 - loss: 0.5475 - val_categorical_accuracy: 0.7557 - val_loss: 1.0736 - learning_rate: 0.1000
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 65/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8855 - loss: 0.5482 - val_categorical_accuracy: 0.8251 - val_loss: 0.7573 - learning_rate: 0.1000
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 66/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8874 - loss: 0.5472 - val_categorical_accuracy: 0.7234 - val_loss: 1.2383 - learning_rate: 0.1000
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 67/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8879 - loss: 0.5428 - val_categorical_accuracy: 0.8086 - val_loss: 0.8305 - learning_rate: 0.1000
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 68/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8905 - loss: 0.5368 - val_categorical_accuracy: 0.8133 - val_loss: 0.8159 - learning_rate: 0.1000
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 69/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8909 - loss: 0.5361 - val_categorical_accuracy: 0.7449 - val_loss: 1.0892 - learning_rate: 0.1000
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 70/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8899 - loss: 0.5370 - val_categorical_accuracy: 0.7822 - val_loss: 0.9934 - learning_rate: 0.1000
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 71/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.8896 - loss: 0.5385 - val_categorical_accuracy: 0.7404 - val_loss: 1.1231 - learning_rate: 0.1000
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 72/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.
200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9841 - loss: 0.1767 - val_categorical_accuracy: 0.9075 - val_loss: 0.5052 - learning_rate: 1.0000e-03
#
# Epoch 188: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 188/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9833 - loss: 0.1787 - val_categorical_accuracy: 0.9078 - val_loss: 0.5106 - learning_rate: 1.0000e-03
#
# Epoch 189: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 189/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9839 - loss: 0.1771 - val_categorical_accuracy: 0.9050 - val_loss: 0.5086 - learning_rate: 1.0000e-03
#
# Epoch 190: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 190/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9833 - loss: 0.1777 - val_categorical_accuracy: 0.9075 - val_loss: 0.5040 - learning_rate: 1.0000e-03
#
# Epoch 191: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 191/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9825 - loss: 0.1782 - val_categorical_accuracy: 0.9075 - val_loss: 0.4971 - learning_rate: 1.0000e-03
#
# Epoch 192: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 192/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9828 - loss: 0.1776 - val_categorical_accuracy: 0.9087 - val_loss: 0.5081 - learning_rate: 1.0000e-03
#
# Epoch 193: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 193/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.9848 - loss: 0.1756 - val_categorical_accuracy: 0.9051 - val_loss: 0.5142 - learning_rate: 1.0000e-03
#
# Epoch 194: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 194/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9844 - loss: 0.1751 - val_categorical_accuracy: 0.9060 - val_loss: 0.5128 - learning_rate: 1.0000e-03
#
# Epoch 195: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 195/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.9840 - loss: 0.1754 - val_categorical_accuracy: 0.9076 - val_loss: 0.5038 - learning_rate: 1.0000e-03
#
# Epoch 196: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 196/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9843 - loss: 0.1758 - val_categorical_accuracy: 0.9090 - val_loss: 0.5031 - learning_rate: 1.0000e-03
#
# Epoch 197: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 197/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.9851 - loss: 0.1735 - val_categorical_accuracy: 0.9076 - val_loss: 0.5054 - learning_rate: 1.0000e-03
#
# Epoch 198: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 198/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.9839 - loss: 0.1767 - val_categorical_accuracy: 0.9066 - val_loss: 0.5065 - learning_rate: 1.0000e-03
#
# Epoch 199: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 199/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9838 - loss: 0.1756 - val_categorical_accuracy: 0.9079 - val_loss: 0.5110 - learning_rate: 1.0000e-03
#
# Epoch 200: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 200/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - categorical_accuracy: 0.9842 - loss: 0.1738 - val_categorical_accuracy: 0.9072 - val_loss: 0.5236 - learning_rate: 1.0000e-03
#
# MC Dropout single-sample test loss: 0.5176  Test accuracy: 0.9071

# %%
# Plotting training curves

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

## Plot 1
ax1.plot(history_mc.history["loss"], label="train loss")
ax1.plot(history_mc.history["val_loss"], label="val loss")
ax1.set_xlabel("epoch"); ax1.set_ylabel("loss")
ax1.set_title("MC Dropout ResNet-20 — Loss"); ax1.legend()

## Plot 2
ax2.plot(history_mc.history["categorical_accuracy"], label="train acc")
ax2.plot(history_mc.history["val_categorical_accuracy"], label="val acc")
ax2.set_xlabel("epoch"); ax2.set_ylabel("accuracy")
ax2.set_title("MC Dropout ResNet-20 — Accuracy"); ax2.legend()
plt.tight_layout(); plt.show()

# %%
# Loading SVHN as the out-of-distribution reference set
'''
Per the proposal §3.5, SVHN (street view of house numbers) is used as the
OOD test set. SVHN images are 32x32 colour photos like CIFAR-10, but of
digits, so a CIFAR-10 trained model should ideally report higher predictive
entropy on SVHN inputs than on its in-distribution CIFAR-10 test images.

The whole SVHN test split is ~26k examples; we load it via
tensorflow_datasets and rescale to [0, 1] to match CIFAR-10 preprocessing.
'''
import tensorflow_datasets as tfds

svhn = tfds.load("svhn_cropped", split="test", as_supervised=True)
svhn_images = []
for img, _ in svhn:
    svhn_images.append(img.numpy())
x_svhn = np.stack(svhn_images).astype("float32") / 255.0

print(f"SVHN OOD set: {x_svhn.shape}")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/svhn_cropped/3.1.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/svhn_cropped/3.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/svhn_cropped/incomplete.BAASV5_3.1.0/svhn_cropped-train.tfrecord-[0-9][0-9…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/svhn_cropped/incomplete.BAASV5_3.1.0/svhn_cropped-test.tfrecord-[0-9][0-9]…
# Generating extra examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/svhn_cropped/incomplete.BAASV5_3.1.0/svhn_cropped-extra.tfrecord-[0-9][0-9…
# Dataset svhn_cropped downloaded and prepared to /root/tensorflow_datasets/svhn_cropped/3.1.0. Subsequent calls will reuse this data.
# SVHN OOD set: (26032, 32, 32, 3)

# %%
# MC Dropout predictive distribution (S samples)
'''
For each input we run S=30 stochastic forward passes (each with an
independent dropout mask). Averaging the resulting softmax probabilities
gives the MC estimate of the posterior predictive distribution. Storing all
S sets of probabilities separately is what lets the evaluation file compute
the decomposition:
    Total uncertainty  = H[ mean_s p_s ]
    Aleatoric          = mean_s H[ p_s ]
    Epistemic (MI)     = Total - Aleatoric
which is the standard mutual-information style split (Depeweg et al. 2018).
'''

S = 30

def mc_predictive(x_ds_or_array, S=S, batch_size=128):
    '''
    Returns:
      all_probs: (S, N, 10) per-sample softmax probabilities
      mean_probs: (N, 10) Monte Carlo mean
    Accepts either a tf.data.Dataset or a numpy array.
    '''
    if isinstance(x_ds_or_array, np.ndarray):
        ds = tf.data.Dataset.from_tensor_slices(x_ds_or_array).batch(batch_size)
        get_x = lambda b: b
    else:
        ds = x_ds_or_array
        get_x = lambda b: b[0]

    samples = []
    for _ in range(S):
        per_sample = []
        for batch in ds:
            x_batch = get_x(batch)
            ### training=True keeps the dropout masks stochastic; the MCDropout subclass already forces this, but we pass it explicitly for clarity.
            logits = mc_model(x_batch, training=True)
            per_sample.append(tf.nn.softmax(logits, axis=-1).numpy())
        samples.append(np.concatenate(per_sample, axis=0))
    all_probs = np.stack(samples, axis=0)              # (S, N, 10)
    mean_probs = all_probs.mean(axis=0)                 # (N, 10)
    return all_probs, mean_probs

print("Running MC inference on CIFAR-10 test set...")
all_probs_test, probs_test = mc_predictive(test_ds, S=S)
preds_test  = np.argmax(probs_test, axis=1)
labels_test = np.argmax(y_test, axis=1)
print(f"MC Dropout (S={S}) test accuracy: {(preds_test == labels_test).mean():.4f}")

print("Running MC inference on SVHN OOD set...")
all_probs_svhn, probs_svhn = mc_predictive(x_svhn, S=S)

print(f"all_probs_test: {all_probs_test.shape}")
print(f"all_probs_svhn: {all_probs_svhn.shape}")
# Out:
# Running MC inference on CIFAR-10 test set...
# MC Dropout (S=30) test accuracy: 0.9105
# Running MC inference on SVHN OOD set...
# all_probs_test: (30, 10000, 10)
# all_probs_svhn: (30, 26032, 10)

# %%
# Saving raw outputs for the evaluation file
'''
Same .npz schema as the deterministic file. The S=30 per-sample arrays let
the eval file recover the mutual-information uncertainty decomposition.
'''
np.savez("mc_dropout_results.npz",
         model_name="mc_dropout",
         probs_test=probs_test,
         labels_test=labels_test,
         preds_test=preds_test,
         probs_svhn=probs_svhn,
         all_probs_test=all_probs_test,
         all_probs_svhn=all_probs_svhn)

print("Saved mc_dropout_results.npz")
# Out:
# Saved mc_dropout_results.npz
