# %%
from google.colab import drive
import os

drive.mount('/content/drive')                          # auth popup, once per session
RESULTS_DIR = '/content/drive/MyDrive/thesis_results'  # change name if you like
os.makedirs(RESULTS_DIR, exist_ok=True)
os.chdir(RESULTS_DIR)                                   # all relative saves now land here
print('Saving to:', os.getcwd())
# Out:
# Mounted at /content/drive
# Saving to: /content/drive/MyDrive/thesis_results

# %%
# Imports

## Core libraries
import numpy as np
import matplotlib.pyplot as plt

## TensorFlow / Keras
import tensorflow as tf
import keras
from keras import ops, layers
from keras.callbacks import Callback
from keras.models import Sequential, Model
from keras.layers import Input, Conv2D, Dense

# %%
# Setting seeds

np.random.seed(1999)
tf.random.set_seed(1999)

# %%
# Loading the dataset

(x_train_full, y_train_full), (x_test, y_test) = keras.datasets.cifar10.load_data()

## Feature scaling (mapping pixel values to [0,1])
'''
This is used as neural network training via gradient descent is sensitive to the
scale of inputs (through activations a = Wx + b). This causes gradients to vanish
and makes the loss landscape poorly conditioned.
'''
x_train_full = x_train_full / 255.0
x_test = x_test / 255.0

''' Recalling our y values are our categories '''
y_train_full = keras.utils.to_categorical(y_train_full, 10)
y_test = keras.utils.to_categorical(y_test, 10)

## Setting up our validation dataset
n_val = int(0.2 * len(x_train_full))
perm = np.random.permutation(len(x_train_full))
val_idx, train_idx = perm[:n_val], perm[n_val:]
x_val, y_val = x_train_full[val_idx], y_train_full[val_idx]
x_train, y_train = x_train_full[train_idx], y_train_full[train_idx]

## Check
print(f"train: {x_train.shape} val: {x_val.shape} test: {x_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step
# train: (40000, 32, 32, 3) val: (10000, 32, 32, 3) test: (10000, 32, 32, 3)

# %%
# Augmenting the dataset
'''
This involves creating new training examples by applying label preserving
transformations to existing examples e.g. flips, crops, scaling, colour jitter,
adding noise, ...
'''

'''
Applying three transformations in sequence, we pad the image with black 0s,
then randomly crop the newly padded image (so the model learns that a shifted
horse picture is still a horse), and then randomly mirroring the image from left
to right.
'''
augment = keras.Sequential([layers.ZeroPadding2D(padding=4),
                            layers.RandomCrop(32, 32),
                            layers.RandomFlip("horizontal")])

batch_size = 128

'''
This builds the full training data pipeline, where:
- The from_tensor_slices((x_train, y_train)) wraps the numpy arrays into a
  tf.data.Dataset that has image label pairs one at a time.
- For .shuffle(len(x_train)) - this shifts the entire dataset after each epoch.
- For .map(lambda x, y: (augment(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
  this applies the augmentation pipeline to each batch of images whilst leaving
  labels untouched. The training=True is important because RandomCrop and
  RandomFlip only apply their transformations during training. The
  num_parallel_calls=tf.data.AUTOTUNE lets TensorFlow decide how many batches to
  augment in parallel across CPU threads.
'''
train_ds = (tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size).map(lambda x, y: (augment(x, training=True), y),
            num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE))

### Recalling that there is no augmentation for validation and test datasets
val_ds  = (tf.data.Dataset.from_tensor_slices((x_val,  y_val ))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))
test_ds = (tf.data.Dataset.from_tensor_slices((x_test, y_test))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))

# %%
# Residual block (no dropout)
'''
Here is the specification requirements for a single residual block (the repeating
unit in ResNet-20). Instead of learning the mapping between the input and the
output, we instead learn the difference between the input and the desired output
(the residual).

In this, the shortcut path passes the input unchanged (albeit with a channel
count change to match shapes at times). These two paths are added together for
a final ReLU.
'''

### We recall that a convolution slides a small window (a kernel/filter) across our grid.
### A single kernel produces one output grid (one channel). One kernel might learn to detect vertical edges, another colour gradients, and so on.
### We thus use 16 kernels simultaneously to produce an output with 16 channels.

class ResidualBlock(keras.layers.Layer):

    '''
    The init method constructs everything which doesn't fit into the other categories.
    In this, we construct the two convolutional layers and the ReLU activation.
    Everything here is created once and reused when the block processes an input.
    Projection is handled separately, as the input's channel count changes.
    '''
    def __init__(self, filters, stride=1, **kwargs):
        super().__init__(**kwargs)
        self.filters = filters
        self.stride = stride

        ### The same padding here adds just enough padding at each convolution step so the output spatial dimensions match the input.
        ### The kernel initialiser establishes starting weights for the kernels such that they are not all zero (each kernel learns the same thing), too large (where activations explode), or too small (vanishing to zero).
        self.conv1 = layers.Conv2D(filters, 3, strides=stride, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")

        ### Batch normalisation ensures each channel has a mean of 0 and a variance of 1.
        ### This is necessary for faster and more stable training as the weights update during training, causing our outputs to shift considerably (and calibrated to the old weights).
        ### The purpose of batch normalisation is to ensure a stable range of outputs.
        self.bn1 = layers.BatchNormalization()
        self.conv2 = layers.Conv2D(filters, 3, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")
        self.bn2 = layers.BatchNormalization()
        self.relu = layers.Activation("relu")

    ### Going deeper into the network, we want to detect increasingly abstract features.
    ### We therefore downsample (have a bigger stride) as we detect combinations.
    ### We compensate for that by increasing the number of channels.

    '''
    The build method handles the projection shortcut (and handles shape-matching if needed).
    '''
    def build(self, input_shape):
        in_channels = input_shape[-1]

        if self.stride != 1 or in_channels != self.filters:
            self.proj = layers.Conv2D(self.filters, 1, strides=self.stride, padding="valid",
                                      kernel_regularizer=keras.regularizers.L2(1e-4),
                                      kernel_initializer="he_normal")
            self.bn_proj = layers.BatchNormalization()
        else:
            self.proj = None

        super().build(input_shape)

    '''
    The call method runs the actual forward pass of the model organising the
    split into the main convolutional path and the shortcut path, then summing
    them and applying ReLU.
    '''
    def call(self, x):
        if self.proj is not None:
            shortcut = self.bn_proj(self.proj(x))
        else:
            shortcut = x

        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))

        return self.relu(out + shortcut)

    '''
    The get_config method enables serialisation so Keras can save/load the model.
    '''
    def get_config(self):
        config = super().get_config()
        config.update({"filters": self.filters,
                       "stride": self.stride})
        return config

# %%
# build_resnet20_vib — VIB alone variant (no SWAG / no weight uncertainty)
'''
The feature extractor follows the deterministic ResNet-20 specification above.
The only architectural change is after global average pooling: instead of sending
the feature vector directly to the classifier, we map it to the parameters of a
diagonal Gaussian bottleneck, sample z, and classify from z.

This is VIB alone. The weights are fixed after training; uncertainty at test time
comes only from repeatedly sampling the bottleneck representation z.
'''

class VIBSampling(keras.layers.Layer):

    """
    Reparameterisation layer for VIB.

    Given mu and log_var, sample z = mu + sigma * epsilon and add the VIB KL
    penalty beta * KL(q(z|x) || N(0, I)) to the model loss.
    """
    def __init__(self, beta=1e-3, **kwargs):
        super().__init__(**kwargs)
        self.beta = beta

    def call(self, inputs):
        mu, log_var = inputs
        eps = tf.random.normal(shape=tf.shape(mu), dtype=mu.dtype)
        z = mu + tf.exp(0.5 * log_var) * eps

        kl_per_example = -0.5 * tf.reduce_sum(
            1.0 + log_var - tf.square(mu) - tf.exp(log_var), axis=-1
        )
        self.add_loss(self.beta * tf.reduce_mean(kl_per_example))

        return z

    def get_config(self):
        config = super().get_config()
        config.update({"beta": self.beta})
        return config


def build_vib_resnet20(beta=1e-3, latent_dim=64):
    inputs = keras.Input(shape=(32, 32, 3))

    x = layers.Conv2D(16, 3, padding="same",
                      kernel_regularizer=keras.regularizers.L2(1e-4),
                      kernel_initializer="he_normal")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    for _ in range(3):
        x = ResidualBlock(16)(x)

    x = ResidualBlock(32, stride=2)(x)
    for _ in range(2):
        x = ResidualBlock(32)(x)

    x = ResidualBlock(64, stride=2)(x)
    for _ in range(2):
        x = ResidualBlock(64)(x)

    ### Global average pooling takes the block's output and turns it into a flat
    ### feature vector. In the deterministic version this went straight into the
    ### final dense layer; here it becomes the input to the VIB bottleneck.
    x = layers.GlobalAveragePooling2D()(x)

    z_mu = layers.Dense(latent_dim,
                        kernel_initializer="he_normal",
                        name="z_mu")(x)
    z_log_var = layers.Dense(latent_dim,
                             kernel_initializer="zeros",
                             bias_initializer="zeros",
                             name="z_log_var")(x)
    z = VIBSampling(beta=beta, name="vib_bottleneck")([z_mu, z_log_var])

    outputs = layers.Dense(10, kernel_initializer="he_normal")(z)

    return keras.Model(inputs, outputs)

# %%
# Building VIB-alone model

beta = 1e-3      # compression strength; useful alternatives: 1e-4, 1e-2
latent_dim = 64  # keep equal to the deterministic ResNet-20 pooled feature width

model = build_vib_resnet20(beta=beta, latent_dim=latent_dim)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        448 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block      │ (None, 32, 32,    │      4,768 │ activation[0][0]  │
# │ (ResidualBlock)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_1    │ (None, 32, 32,    │      4,768 │ residual_block[0… │
# │ (ResidualBlock)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_2    │ (None, 32, 32,    │      4,768 │ residual_block_1… │
# │ (ResidualBlock)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_3    │ (None, 16, 16,    │     14,816 │ residual_block_2… │
# │ (ResidualBlock)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_4    │ (None, 16, 16,    │     18,752 │ residual_block_3… │
# │ (ResidualBlock)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_5    │ (None, 16, 16,    │     18,752 │ residual_block_4… │
# │ (ResidualBlock)     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_6    │ (None, 8, 8, 64)  │     58,304 │ residual_block_5… │
# │ (ResidualBlock)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_7    │ (None, 8, 8, 64)  │     74,368 │ residual_block_6… │
# │ (ResidualBlock)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ residual_block_8    │ (None, 8, 8, 64)  │     74,368 │ residual_block_7… │
# │ (ResidualBlock)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ residual_block_8… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mu (Dense)        │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vib_bottleneck      │ (None, 64)        │          0 │ z_mu[0][0],       │
# │ (VIBSampling)       │                   │            │ z_log_var[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10)        │        650 │ vib_bottleneck[0… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 283,146 (1.08 MB)
#  Trainable params: 281,578 (1.07 MB)
#  Non-trainable params: 1,568 (6.12 KB)

# %%
# Training VIB-alone model

'''
Step-wise learning-rate schedule: drop by 10x at epochs 100 and 150.
This is unchanged from the deterministic notebook so that the VIB-alone model
uses the same optimisation recipe.
'''
def lr_schedule(epoch, lr):
    if epoch in (100, 150):
        return lr * 0.1
    return lr

# %%
# Compiling

### This doesn't run any training or touch any data, but it configures the optimiser (how weights are updated), the loss function, and optionally any metrics we want to track.
### The VIB KL term is added inside the VIBSampling layer via self.add_loss(...), so the compile loss remains categorical cross-entropy.
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1, momentum=0.9),
              loss=keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=["categorical_accuracy"])

# %%
# Callbacks for checkpoints

callbacks = [keras.callbacks.ModelCheckpoint("vib_resnet20_best.weights.h5",
                                             monitor="val_loss",
                                             save_best_only=True,
                                             save_weights_only=True),
             keras.callbacks.LearningRateScheduler(lr_schedule, verbose=1)] # calls lr_schedule function each epoch to reduce learning rate

# %%
# Training

history = model.fit(train_ds,
                    epochs=200,
                    validation_data=val_ds,
                    callbacks=callbacks)


model.load_weights("vib_resnet20_best.weights.h5") # Loading best checkpoints

# Final evaluation on test set
# This is a single stochastic pass, so the MC evaluation cell below is the better
# number to report for the VIB predictive distribution.
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"\nSingle-sample test loss: {test_loss:.4f}  Single-sample test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 1/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 61ms/step - categorical_accuracy: 0.3239 - loss: 2.0513 - val_categorical_accuracy: 0.2241 - val_loss: 2.6603 - learning_rate: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 2/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.4912 - loss: 1.5902 - val_categorical_accuracy: 0.3092 - val_loss: 3.0897 - learning_rate: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 3/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.5883 - loss: 1.3537 - val_categorical_accuracy: 0.5703 - val_loss: 1.5024 - learning_rate: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 4/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.6485 - loss: 1.1975 - val_categorical_accuracy: 0.5191 - val_loss: 1.7706 - learning_rate: 0.1000
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 5/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.6930 - loss: 1.0812 - val_categorical_accuracy: 0.6042 - val_loss: 1.3560 - learning_rate: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 6/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.7300 - loss: 0.9826 - val_categorical_accuracy: 0.6722 - val_loss: 1.2472 - learning_rate: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 7/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.7571 - loss: 0.9159 - val_categorical_accuracy: 0.6884 - val_loss: 1.1765 - learning_rate: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 8/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7665 - loss: 0.8887 - val_categorical_accuracy: 0.6398 - val_loss: 1.3951 - learning_rate: 0.1000
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 9/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7857 - loss: 0.8361 - val_categorical_accuracy: 0.6838 - val_loss: 1.2678 - learning_rate: 0.1000
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 10/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.7966 - loss: 0.7999 - val_categorical_accuracy: 0.7355 - val_loss: 1.0442 - learning_rate: 0.1000
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 11/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8015 - loss: 0.7898 - val_categorical_accuracy: 0.7293 - val_loss: 1.1006 - learning_rate: 0.1000
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 12/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8102 - loss: 0.7652 - val_categorical_accuracy: 0.7525 - val_loss: 0.9819 - learning_rate: 0.1000
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 13/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8203 - loss: 0.7421 - val_categorical_accuracy: 0.7132 - val_loss: 1.2059 - learning_rate: 0.1000
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 14/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8273 - loss: 0.7257 - val_categorical_accuracy: 0.7186 - val_loss: 1.1036 - learning_rate: 0.1000
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 15/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8311 - loss: 0.7124 - val_categorical_accuracy: 0.7103 - val_loss: 1.3244 - learning_rate: 0.1000
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 16/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8355 - loss: 0.6976 - val_categorical_accuracy: 0.8038 - val_loss: 0.8245 - learning_rate: 0.1000
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 17/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8355 - loss: 0.6977 - val_categorical_accuracy: 0.7864 - val_loss: 0.8824 - learning_rate: 0.1000
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 18/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8468 - loss: 0.6758 - val_categorical_accuracy: 0.6964 - val_loss: 1.2494 - learning_rate: 0.1000
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 19/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8446 - loss: 0.6804 - val_categorical_accuracy: 0.8077 - val_loss: 0.8048 - learning_rate: 0.1000
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 20/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8514 - loss: 0.6663 - val_categorical_accuracy: 0.7238 - val_loss: 1.1205 - learning_rate: 0.1000
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 21/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8536 - loss: 0.6591 - val_categorical_accuracy: 0.8100 - val_loss: 0.8305 - learning_rate: 0.1000
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 22/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8550 - loss: 0.6507 - val_categorical_accuracy: 0.7823 - val_loss: 0.9118 - learning_rate: 0.1000
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 23/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8573 - loss: 0.6494 - val_categorical_accuracy: 0.7484 - val_loss: 1.1035 - learning_rate: 0.1000
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 24/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8588 - loss: 0.6432 - val_categorical_accuracy: 0.7700 - val_loss: 0.9548 - learning_rate: 0.1000
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 25/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8612 - loss: 0.6412 - val_categorical_accuracy: 0.8073 - val_loss: 0.8370 - learning_rate: 0.1000
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 26/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8641 - loss: 0.6329 - val_categorical_accuracy: 0.8147 - val_loss: 0.8492 - learning_rate: 0.1000
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 27/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8686 - loss: 0.6248 - val_categorical_accuracy: 0.7714 - val_loss: 0.9793 - learning_rate: 0.1000
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 28/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 108/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9743 - loss: 0.3371 - val_categorical_accuracy: 0.9116 - val_loss: 0.5884 - learning_rate: 0.0100
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 109/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9751 - loss: 0.3319 - val_categorical_accuracy: 0.9120 - val_loss: 0.5840 - learning_rate: 0.0100
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 110/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9757 - loss: 0.3260 - val_categorical_accuracy: 0.9093 - val_loss: 0.5931 - learning_rate: 0.0100
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 111/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9758 - loss: 0.3212 - val_categorical_accuracy: 0.9089 - val_loss: 0.5902 - learning_rate: 0.0100
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 112/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9778 - loss: 0.3144 - val_categorical_accuracy: 0.9092 - val_loss: 0.5956 - learning_rate: 0.0100
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 113/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9793 - loss: 0.3074 - val_categorical_accuracy: 0.9096 - val_loss: 0.5843 - learning_rate: 0.0100
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 114/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9800 - loss: 0.3024 - val_categorical_accuracy: 0.9099 - val_loss: 0.5848 - learning_rate: 0.0100
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 115/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9805 - loss: 0.2983 - val_categorical_accuracy: 0.9108 - val_loss: 0.5835 - learning_rate: 0.0100
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 116/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9804 - loss: 0.2943 - val_categorical_accuracy: 0.9111 - val_loss: 0.5871 - learning_rate: 0.0100
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 117/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9819 - loss: 0.2885 - val_categorical_accuracy: 0.9084 - val_loss: 0.5978 - learning_rate: 0.0100
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 118/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9821 - loss: 0.2858 - val_categorical_accuracy: 0.9104 - val_loss: 0.5945 - learning_rate: 0.0100
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 119/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9840 - loss: 0.2793 - val_categorical_accuracy: 0.9112 - val_loss: 0.5926 - learning_rate: 0.0100
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 120/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9831 - loss: 0.2779 - val_categorical_accuracy: 0.9068 - val_loss: 0.6047 - learning_rate: 0.0100
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 121/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9849 - loss: 0.2716 - val_categorical_accuracy: 0.9093 - val_loss: 0.5920 - learning_rate: 0.0100
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 122/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9823 - loss: 0.2738 - val_categorical_accuracy: 0.9102 - val_loss: 0.5830 - learning_rate: 0.0100
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 123/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9853 - loss: 0.2640 - val_categorical_accuracy: 0.9110 - val_loss: 0.5900 - learning_rate: 0.0100
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 124/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9856 - loss: 0.2620 - val_categorical_accuracy: 0.9088 - val_loss: 0.5937 - learning_rate: 0.0100
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 125/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9853 - loss: 0.2587 - val_categorical_accuracy: 0.9057 - val_loss: 0.5963 - learning_rate: 0.0100
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 126/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9868 - loss: 0.2533 - val_categorical_accuracy: 0.9066 - val_loss: 0.5998 - learning_rate: 0.0100
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 127/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9868 - loss: 0.2518 - val_categorical_accuracy: 0.9068 - val_loss: 0.5976 - learning_rate: 0.0100
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 128/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9865 - loss: 0.2491 - val_categorical_accuracy: 0.9065 - val_loss: 0.6173 - learning_rate: 0.0100
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 129/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9877 - loss: 0.2440 - val_categorical_accuracy: 0.9079 - val_loss: 0.6031 - learning_rate: 0.0100
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 130/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9869 - loss: 0.2432 - val_categorical_accuracy: 0.9085 - val_loss: 0.6097 - learning_rate: 0.0100
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 131/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9870 - loss: 0.2406 - val_categorical_accuracy: 0.9092 - val_loss: 0.6050 - learning_rate: 0.0100
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 132/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9883 - loss: 0.2366 - val_categorical_accuracy: 0.9080 - val_loss: 0.6065 - learning_rate: 0.0100
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 133/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9873 - loss: 0.2354 - val_categorical_accuracy: 0.9095 - val_loss: 0.6045 - learning_rate: 0.0100
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 134/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9881 - loss: 0.2329 - val_categorical_accuracy: 0.9080 - val_loss: 0.6009 - learning_rate: 0.0100
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 135/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.
- learning_rate: 1.0000e-03
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 170/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1780 - val_categorical_accuracy: 0.9120 - val_loss: 0.5681 - learning_rate: 1.0000e-03
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 171/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9956 - loss: 0.1778 - val_categorical_accuracy: 0.9111 - val_loss: 0.5712 - learning_rate: 1.0000e-03
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 172/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1769 - val_categorical_accuracy: 0.9108 - val_loss: 0.5677 - learning_rate: 1.0000e-03
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 173/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9960 - loss: 0.1774 - val_categorical_accuracy: 0.9127 - val_loss: 0.5671 - learning_rate: 1.0000e-03
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 174/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9964 - loss: 0.1768 - val_categorical_accuracy: 0.9119 - val_loss: 0.5667 - learning_rate: 1.0000e-03
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 175/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1762 - val_categorical_accuracy: 0.9130 - val_loss: 0.5651 - learning_rate: 1.0000e-03
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 176/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1760 - val_categorical_accuracy: 0.9130 - val_loss: 0.5668 - learning_rate: 1.0000e-03
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 177/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1755 - val_categorical_accuracy: 0.9118 - val_loss: 0.5664 - learning_rate: 1.0000e-03
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 178/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1761 - val_categorical_accuracy: 0.9117 - val_loss: 0.5668 - learning_rate: 1.0000e-03
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 179/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1750 - val_categorical_accuracy: 0.9112 - val_loss: 0.5709 - learning_rate: 1.0000e-03
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 180/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1750 - val_categorical_accuracy: 0.9118 - val_loss: 0.5681 - learning_rate: 1.0000e-03
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 181/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9957 - loss: 0.1752 - val_categorical_accuracy: 0.9138 - val_loss: 0.5650 - learning_rate: 1.0000e-03
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 182/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.9962 - loss: 0.1745 - val_categorical_accuracy: 0.9115 - val_loss: 0.5622 - learning_rate: 1.0000e-03
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 183/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1748 - val_categorical_accuracy: 0.9121 - val_loss: 0.5657 - learning_rate: 1.0000e-03
#
# Epoch 184: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 184/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9955 - loss: 0.1743 - val_categorical_accuracy: 0.9118 - val_loss: 0.5633 - learning_rate: 1.0000e-03
#
# Epoch 185: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 185/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1735 - val_categorical_accuracy: 0.9124 - val_loss: 0.5654 - learning_rate: 1.0000e-03
#
# Epoch 186: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 186/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9972 - loss: 0.1723 - val_categorical_accuracy: 0.9127 - val_loss: 0.5663 - learning_rate: 1.0000e-03
#
# Epoch 187: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 187/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1732 - val_categorical_accuracy: 0.9119 - val_loss: 0.5705 - learning_rate: 1.0000e-03
#
# Epoch 188: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 188/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1730 - val_categorical_accuracy: 0.9115 - val_loss: 0.5688 - learning_rate: 1.0000e-03
#
# Epoch 189: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 189/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1726 - val_categorical_accuracy: 0.9129 - val_loss: 0.5633 - learning_rate: 1.0000e-03
#
# Epoch 190: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 190/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9964 - loss: 0.1721 - val_categorical_accuracy: 0.9136 - val_loss: 0.5685 - learning_rate: 1.0000e-03
#
# Epoch 191: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 191/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9967 - loss: 0.1710 - val_categorical_accuracy: 0.9134 - val_loss: 0.5627 - learning_rate: 1.0000e-03
#
# Epoch 192: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 192/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9972 - loss: 0.1706 - val_categorical_accuracy: 0.9130 - val_loss: 0.5657 - learning_rate: 1.0000e-03
#
# Epoch 193: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 193/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1712 - val_categorical_accuracy: 0.9137 - val_loss: 0.5624 - learning_rate: 1.0000e-03
#
# Epoch 194: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 194/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.9969 - loss: 0.1706 - val_categorical_accuracy: 0.9118 - val_loss: 0.5575 - learning_rate: 1.0000e-03
#
# Epoch 195: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 195/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9971 - loss: 0.1700 - val_categorical_accuracy: 0.9133 - val_loss: 0.5654 - learning_rate: 1.0000e-03
#
# Epoch 196: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 196/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9968 - loss: 0.1705 - val_categorical_accuracy: 0.9119 - val_loss: 0.5658 - learning_rate: 1.0000e-03
#
# Epoch 197: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 197/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1706 - val_categorical_accuracy: 0.9139 - val_loss: 0.5748 - learning_rate: 1.0000e-03
#
# Epoch 198: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 198/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1700 - val_categorical_accuracy: 0.9125 - val_loss: 0.5688 - learning_rate: 1.0000e-03
#
# Epoch 199: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 199/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9967 - loss: 0.1699 - val_categorical_accuracy: 0.9119 - val_loss: 0.5642 - learning_rate: 1.0000e-03
#
# Epoch 200: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 200/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9967 - loss: 0.1696 - val_categorical_accuracy: 0.9123 - val_loss: 0.5632 - learning_rate: 1.0000e-03
#
# Single-sample test loss: 0.5764  Single-sample test accuracy: 0.9087

# %%
# Plotting training curves

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

## Plot 1
ax1.plot(history.history["loss"], label="train loss")
ax1.plot(history.history["val_loss"], label="val loss")
ax1.set_xlabel("epoch"); ax1.set_ylabel("loss")
ax1.set_title("VIB-alone ResNet-20 — Loss"); ax1.legend()

## Plot 2
ax2.plot(history.history["categorical_accuracy"], label="train acc")
ax2.plot(history.history["val_categorical_accuracy"], label="val acc")
ax2.set_xlabel("epoch"); ax2.set_ylabel("accuracy")
ax2.set_title("VIB-alone ResNet-20 — Accuracy"); ax2.legend()
plt.tight_layout(); plt.show()

# %%
# Loading SVHN as the out-of-distribution reference set
'''
Per the proposal §3.5, SVHN (street view of house numbers) is used as the
OOD test set. SVHN images are 32x32 colour photos like CIFAR-10, but of
digits, so a CIFAR-10 trained model should ideally report higher predictive
entropy on SVHN inputs than on its in-distribution CIFAR-10 test images.

The whole SVHN test split is ~26k examples; we load it via
tensorflow_datasets and rescale to [0, 1] to match CIFAR-10 preprocessing.
'''
import tensorflow_datasets as tfds

svhn = tfds.load("svhn_cropped", split="test", as_supervised=True)
svhn_images = []
for img, _ in svhn:
    svhn_images.append(img.numpy())
x_svhn = np.stack(svhn_images).astype("float32") / 255.0

print(f"SVHN OOD set: {x_svhn.shape}")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/svhn_cropped/3.1.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/svhn_cropped/3.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/svhn_cropped/incomplete.JH8DXD_3.1.0/svhn_cropped-train.tfrecord-[0-9][0-9…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/svhn_cropped/incomplete.JH8DXD_3.1.0/svhn_cropped-test.tfrecord-[0-9][0-9]…
# Generating extra examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/svhn_cropped/incomplete.JH8DXD_3.1.0/svhn_cropped-extra.tfrecord-[0-9][0-9…
# Dataset svhn_cropped downloaded and prepared to /root/tensorflow_datasets/svhn_cropped/3.1.0. Subsequent calls will reuse this data.
# SVHN OOD set: (26032, 32, 32, 3)

# %%
# Generating predictions for the evaluation file
'''
This is the only output the downstream evaluation notebook needs from this
file. We produce softmax probabilities on:
  - the CIFAR-10 test set (in-distribution),
  - the SVHN test set (out-of-distribution),
and stash the true labels and the predicted classes alongside.

The VIB-alone model has stochasticity at the representation level only. The MC
axis below is therefore repeated bottleneck samples with fixed trained weights:
there is no SWAG posterior and no weight sampling in this notebook.
'''

def predict_vib_mc(model, data, mc_samples=30, batch_size=128):
    all_probs = []

    for s in range(mc_samples):
        if isinstance(data, tf.data.Dataset):
            logits = model.predict(data, verbose=0)
        else:
            logits = model.predict(data, batch_size=batch_size, verbose=0)

        probs = tf.nn.softmax(logits, axis=-1).numpy()
        all_probs.append(probs)

        print(f"MC sample {s + 1:02d}/{mc_samples} complete")

    all_probs = np.stack(all_probs, axis=0)   # (M, N, 10)
    mean_probs = all_probs.mean(axis=0)       # (N, 10)

    return mean_probs, all_probs

n_mc_samples = 30

## In-distribution: CIFAR-10 test set
probs_test, all_probs_test = predict_vib_mc(model, test_ds, mc_samples=n_mc_samples)
preds_test  = np.argmax(probs_test, axis=1)
labels_test = np.argmax(y_test, axis=1)

print(f"MC-averaged test accuracy: {(preds_test == labels_test).mean():.4f}")

## Out-of-distribution: SVHN test set
probs_svhn, all_probs_svhn = predict_vib_mc(model, x_svhn, mc_samples=n_mc_samples, batch_size=128)

print(f"probs_test:      {probs_test.shape}")
print(f"all_probs_test:  {all_probs_test.shape}")
print(f"probs_svhn:      {probs_svhn.shape}")
print(f"all_probs_svhn:  {all_probs_svhn.shape}")
# Out:
# MC sample 01/30 complete
# MC sample 02/30 complete
# MC sample 03/30 complete
# MC sample 04/30 complete
# MC sample 05/30 complete
# MC sample 06/30 complete
# MC sample 07/30 complete
# MC sample 08/30 complete
# MC sample 09/30 complete
# MC sample 10/30 complete
# MC sample 11/30 complete
# MC sample 12/30 complete
# MC sample 13/30 complete
# MC sample 14/30 complete
# MC sample 15/30 complete
# MC sample 16/30 complete
# MC sample 17/30 complete
# MC sample 18/30 complete
# MC sample 19/30 complete
# MC sample 20/30 complete
# MC sample 21/30 complete
# MC sample 22/30 complete
# MC sample 23/30 complete
# MC sample 24/30 complete
# MC sample 25/30 complete
# MC sample 26/30 complete
# MC sample 27/30 complete
# MC sample 28/30 complete
# MC sample 29/30 complete
# MC sample 30/30 complete
# MC-averaged test accuracy: 0.9103
# MC sample 01/30 complete
# MC sample 02/30 complete
# MC sample 03/30 complete
# MC sample 04/30 complete
# MC sample 05/30 complete
# MC sample 06/30 complete
# MC sample 07/30 complete
# MC sample 08/30 complete
# MC sample 09/30 complete
# MC sample 10/30 complete
# MC sample 11/30 complete
# MC sample 12/30 complete
# MC sample 13/30 complete
# MC sample 14/30 complete
# MC sample 15/30 complete
# MC sample 16/30 complete
# MC sample 17/30 complete
# MC sample 18/30 complete
# MC sample 19/30 complete
# MC sample 20/30 complete
# MC sample 21/30 complete
# MC sample 22/30 complete
# MC sample 23/30 complete
# MC sample 24/30 complete
# MC sample 25/30 complete
# MC sample 26/30 complete
# MC sample 27/30 complete
# MC sample 28/30 complete
# MC sample 29/30 complete
# MC sample 30/30 complete
# probs_test:      (10000, 10)
# all_probs_test:  (30, 10000, 10)
# probs_svhn:      (26032, 10)
# all_probs_svhn:  (30, 26032, 10)

# %%
# Saving raw outputs for the evaluation file
'''
Save format (shared across all benchmarks). The evaluation notebook will
load these by filename and produce ECE, reliability diagrams, OOD AUROC,
risk-coverage and uncertainty summaries.

Keys:
  model_name     - human-readable string identifier
  beta           - VIB compression strength used for training
  latent_dim     - bottleneck dimensionality
  n_mc_samples   - number of representation samples used at inference
  probs_test     - (N_test, 10)  mean predictive distribution on CIFAR-10 test
  labels_test    - (N_test,)     true labels (integer 0-9)
  preds_test     - (N_test,)     argmax of probs_test
  probs_svhn     - (N_svhn, 10)  mean predictive distribution on SVHN OOD
  all_probs_test - (M, N_test, 10) per-representation-sample probs
  all_probs_svhn - (M, N_svhn, 10) per-representation-sample probs

There is intentionally no weight-sample axis here. The MC axis is bottleneck /
representation stochasticity only.
'''
np.savez("vib_alone_results.npz",
         model_name="vib_alone",
         beta=beta,
         latent_dim=latent_dim,
         n_mc_samples=n_mc_samples,
         probs_test=probs_test,
         labels_test=labels_test,
         preds_test=preds_test,
         probs_svhn=probs_svhn,
         all_probs_test=all_probs_test,
         all_probs_svhn=all_probs_svhn,
         rep_probs_test=all_probs_test,
         rep_probs_svhn=all_probs_svhn)

print("Saved vib_alone_results.npz")
# Out:
# Saved vib_alone_results.npz
