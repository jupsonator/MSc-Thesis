# %%
from google.colab import drive
import os

drive.mount('/content/drive')                          # auth popup, once per session
RESULTS_DIR = '/content/drive/MyDrive/thesis_results'  # change name if you like
os.makedirs(RESULTS_DIR, exist_ok=True)
os.chdir(RESULTS_DIR)                                   # all relative saves now land here
print('Saving to:', os.getcwd())
# Out:
# Mounted at /content/drive
# Saving to: /content/drive/MyDrive/thesis_results

# %%
# Imports

## Core libraries
import numpy as np
import matplotlib.pyplot as plt

## TensorFlow / Keras
import tensorflow as tf
import keras
from keras import ops, layers
from keras.callbacks import Callback
from keras.models import Sequential, Model
from keras.layers import Input, Conv2D, Dense

# %%
# Setting seeds

np.random.seed(1999)
tf.random.set_seed(1999)

# %%
# Loading the dataset

(x_train_full, y_train_full), (x_test, y_test) = keras.datasets.cifar10.load_data()

## Feature scaling (mapping pixel values to [0,1])
'''
This is used as neural network training via gradient descent is sensitive to the
scale of inputs (through activations a = Wx + b). This causes gradients to vanish
and makes the loss landscape poorly conditioned.
'''
x_train_full = x_train_full / 255.0
x_test = x_test / 255.0

''' Recalling our y values are our categories '''
y_train_full = keras.utils.to_categorical(y_train_full, 10)
y_test = keras.utils.to_categorical(y_test, 10)

## Setting up our validation dataset
n_val = int(0.2 * len(x_train_full))
perm = np.random.permutation(len(x_train_full))
val_idx, train_idx = perm[:n_val], perm[n_val:]
x_val, y_val = x_train_full[val_idx], y_train_full[val_idx]
x_train, y_train = x_train_full[train_idx], y_train_full[train_idx]

## Check
print(f"train: {x_train.shape} val: {x_val.shape} test: {x_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# train: (40000, 32, 32, 3) val: (10000, 32, 32, 3) test: (10000, 32, 32, 3)

# %%
# Augmenting the dataset
'''
This involves creating new training examples by applying label preserving
transformations to existing examples e.g. flips, crops, scaling, colour jitter,
adding noise, ...
'''

'''
Applying three transformations in sequence, we pad the image with black 0s,
then randomly crop the newly padded image (so the model learns that a shifted
horse picture is still a horse), and then randomly mirroring the image from left
to right.
'''
augment = keras.Sequential([layers.ZeroPadding2D(padding=4),
                            layers.RandomCrop(32, 32),
                            layers.RandomFlip("horizontal")])

batch_size = 128

'''
This builds the full training data pipeline, where:
- The from_tensor_slices((x_train, y_train)) wraps the numpy arrays into a
  tf.data.Dataset that has image label pairs one at a time.
- For .shuffle(len(x_train)) - this shifts the entire dataset after each epoch.
- For .map(lambda x, y: (augment(x, training=True), y), num_parallel_calls=tf.data.AUTOTUNE)
  this applies the augmentation pipeline to each batch of images whilst leaving
  labels untouched. The training=True is important because RandomCrop and
  RandomFlip only apply their transformations during training. The
  num_parallel_calls=tf.data.AUTOTUNE lets TensorFlow decide how many batches to
  augment in parallel across CPU threads.
'''
train_ds = (tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(len(x_train)).batch(batch_size).map(lambda x, y: (augment(x, training=True), y),
            num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE))

### Recalling that there is no augmentation for validation and test datasets
val_ds  = (tf.data.Dataset.from_tensor_slices((x_val,  y_val ))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))
test_ds = (tf.data.Dataset.from_tensor_slices((x_test, y_test))
           .batch(batch_size).prefetch(tf.data.AUTOTUNE))

# %%
# Residual block (no dropout)
'''
Here is the specification requirements for a single residual block (the repeating
unit in ResNet-20). Instead of learning the mapping between the input and the
output, we instead learn the difference between the input and the desired output
(the residual).

In this, the shortcut path passes the input unchanged (albeit with a channel
count change to match shapes at times). These two paths are added together for
a final ReLU.
'''

### We recall that a convolution slides a small window (a kernel/filter) across our grid.
### A single kernel produces one output grid (one channel). One kernel might learn to detect vertical edges, another colour gradients, and so on.
### We thus use 16 kernels simultaneously to produce an output with 16 channels.

class ResidualBlock(keras.layers.Layer):

    '''
    The init method constructs everything which doesn't fit into the other categories.
    In this, we construct the two convolutional layers and the ReLU activation.
    Everything here is created once and reused when the block processes an input.
    Projection is handled separately, as the input's channel count changes.
    '''
    def __init__(self, filters, stride=1, **kwargs):
        super().__init__(**kwargs)
        self.filters = filters
        self.stride = stride

        ### The same padding here adds just enough padding at each convolution step so the output spatial dimensions match the input.
        ### The kernel initialiser establishes starting weights for the kernels such that they are not all zero (each kernel learns the same thing), too large (where activations explode), or too small (vanishing to zero).
        self.conv1 = layers.Conv2D(filters, 3, strides=stride, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")

        ### Batch normalisation ensures each channel has a mean of 0 and a variance of 1.
        ### This is necessary for faster and more stable training as the weights update during training, causing our outputs to shift considerably (and calibrated to the old weights).
        ### The purpose of batch normalisation is to ensure a stable range of outputs.
        self.bn1 = layers.BatchNormalization()
        self.conv2 = layers.Conv2D(filters, 3, padding="same",
                                   kernel_regularizer=keras.regularizers.L2(1e-4),
                                   kernel_initializer="he_normal")
        self.bn2 = layers.BatchNormalization()
        self.relu = layers.Activation("relu")

    ### Going deeper into the network, we want to detect increasingly abstract features.
    ### We therefore downsample (have a bigger stride) as we detect combinations.
    ### We compensate for that by increasing the number of channels.

    '''
    The build method handles the projection shortcut (and handles shape-matching if needed).
    '''
    def build(self, input_shape):
        in_channels = input_shape[-1]

        if self.stride != 1 or in_channels != self.filters:
            self.proj = layers.Conv2D(self.filters, 1, strides=self.stride, padding="valid",
                                      kernel_regularizer=keras.regularizers.L2(1e-4),
                                      kernel_initializer="he_normal")
            self.bn_proj = layers.BatchNormalization()
        else:
            self.proj = None

        super().build(input_shape)

    '''
    The call method runs the actual forward pass of the model organising the
    split into the main convolutional path and the shortcut path, then summing
    them and applying ReLU.
    '''
    def call(self, x):
        if self.proj is not None:
            shortcut = self.bn_proj(self.proj(x))
        else:
            shortcut = x

        out = self.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))

        return self.relu(out + shortcut)

    '''
    The get_config method enables serialisation so Keras can save/load the model.
    '''
    def get_config(self):
        config = super().get_config()
        config.update({"filters": self.filters,
                       "stride": self.stride})
        return config

# %%
# build_resnet20 — deterministic / SWAG variant (no dropout)
'''
The full architecture follows the ResNet-20 spec of He et al. (2016) for CIFAR:
an initial conv, three stages of three residual blocks at filter widths
{16, 32, 64}, with the first block of stages 2 and 3 using stride 2 to halve
spatial resolution while doubling channels.
'''
def build_resnet20():
    inputs = keras.Input(shape=(32, 32, 3))

    x = layers.Conv2D(16, 3, padding="same",
                      kernel_regularizer=keras.regularizers.L2(1e-4),
                      kernel_initializer="he_normal")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    for _ in range(3):
        x = ResidualBlock(16)(x)

    x = ResidualBlock(32, stride=2)(x)
    for _ in range(2):
        x = ResidualBlock(32)(x)

    x = ResidualBlock(64, stride=2)(x)
    for _ in range(2):
        x = ResidualBlock(64)(x)

    ### Global average pooling takes the block's output and feeds it into a final dense layer for classification.
    ### It takes the 64 feature maps (each of which is an 8x8 grid) and averages each grid into a single number. The output is a flat vector of length 64, that feeds into the final dense layer for classification.
    ### This is therefore translation invariant (if a feature shifts position in the 8x8 grid, the average barely changes), so classification is stable.
    x = layers.GlobalAveragePooling2D()(x)

    outputs = layers.Dense(10, kernel_initializer="he_normal")(x)

    return keras.Model(inputs, outputs)

# %%
# Building deterministic model

model = build_resnet20()

# %%
# Training deterministic model

'''
Step-wise learning-rate schedule: drop by 10x at epochs 100 and 150.
This is the standard CIFAR ResNet schedule from He et al. (2016) and matches
what we'll re-use for MC Dropout (so the three baselines differ only in the
stochasticity mechanism, not in the optimisation recipe).
'''
def lr_schedule(epoch, lr):
    if epoch in (100, 150):
        return lr * 0.1
    return lr

# %%
# Compiling

### This doesn't run any training or touch any data, but it configures the optimiser (how weights are updated), the loss function, and optionally any metrics we want to track.
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1, momentum=0.9),
              loss=keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=["categorical_accuracy"])

# %%
# Callbacks for checkpoints

callbacks = [keras.callbacks.ModelCheckpoint("resnet20_best.weights.h5",
                                             monitor="val_loss",
                                             save_best_only=True,
                                             save_weights_only=True),
             keras.callbacks.LearningRateScheduler(lr_schedule, verbose=1)] # calls lr_schedule function each epoch to reduce learning rate

# %%
# Training

history = model.fit(train_ds,
                    epochs=200,
                    validation_data=val_ds,
                    callbacks=callbacks)


model.load_weights("resnet20_best.weights.h5") # Loading best checkpoints

# Final evaluation on test set
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"\nTest loss: {test_loss:.4f}  Test accuracy: {test_acc:.4f}")
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 1/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - categorical_accuracy: 0.3918 - loss: 1.8068 - val_categorical_accuracy: 0.4201 - val_loss: 1.9346 - learning_rate: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 2/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.5766 - loss: 1.3399 - val_categorical_accuracy: 0.4380 - val_loss: 2.0989 - learning_rate: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 3/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.6566 - loss: 1.1279 - val_categorical_accuracy: 0.6421 - val_loss: 1.2125 - learning_rate: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 4/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7110 - loss: 0.9865 - val_categorical_accuracy: 0.3782 - val_loss: 3.0275 - learning_rate: 0.1000
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 5/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7448 - loss: 0.8972 - val_categorical_accuracy: 0.5797 - val_loss: 1.5703 - learning_rate: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 6/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.7678 - loss: 0.8319 - val_categorical_accuracy: 0.6434 - val_loss: 1.3716 - learning_rate: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 7/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.7868 - loss: 0.7850 - val_categorical_accuracy: 0.6922 - val_loss: 1.1277 - learning_rate: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 8/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.7963 - loss: 0.7625 - val_categorical_accuracy: 0.7036 - val_loss: 1.0770 - learning_rate: 0.1000
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 9/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8098 - loss: 0.7247 - val_categorical_accuracy: 0.7096 - val_loss: 1.1160 - learning_rate: 0.1000
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 10/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8181 - loss: 0.7002 - val_categorical_accuracy: 0.7156 - val_loss: 1.0429 - learning_rate: 0.1000
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 11/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.8255 - loss: 0.6837 - val_categorical_accuracy: 0.7844 - val_loss: 0.8315 - learning_rate: 0.1000
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 12/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8288 - loss: 0.6691 - val_categorical_accuracy: 0.6886 - val_loss: 1.2119 - learning_rate: 0.1000
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 13/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8373 - loss: 0.6522 - val_categorical_accuracy: 0.7787 - val_loss: 0.8535 - learning_rate: 0.1000
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 14/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8411 - loss: 0.6393 - val_categorical_accuracy: 0.7220 - val_loss: 1.0659 - learning_rate: 0.1000
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 15/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8445 - loss: 0.6261 - val_categorical_accuracy: 0.7785 - val_loss: 0.9006 - learning_rate: 0.1000
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 16/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8474 - loss: 0.6193 - val_categorical_accuracy: 0.7792 - val_loss: 0.8816 - learning_rate: 0.1000
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 17/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - categorical_accuracy: 0.8511 - loss: 0.6145 - val_categorical_accuracy: 0.7851 - val_loss: 0.8265 - learning_rate: 0.1000
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 18/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8579 - loss: 0.5981 - val_categorical_accuracy: 0.7871 - val_loss: 0.8545 - learning_rate: 0.1000
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 19/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8598 - loss: 0.5964 - val_categorical_accuracy: 0.7250 - val_loss: 1.1182 - learning_rate: 0.1000
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 20/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8600 - loss: 0.5946 - val_categorical_accuracy: 0.7320 - val_loss: 1.0159 - learning_rate: 0.1000
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 21/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8643 - loss: 0.5817 - val_categorical_accuracy: 0.7709 - val_loss: 0.9111 - learning_rate: 0.1000
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 22/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8653 - loss: 0.5774 - val_categorical_accuracy: 0.7742 - val_loss: 0.9021 - learning_rate: 0.1000
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 23/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8702 - loss: 0.5706 - val_categorical_accuracy: 0.7368 - val_loss: 1.1049 - learning_rate: 0.1000
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 24/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8708 - loss: 0.5682 - val_categorical_accuracy: 0.8063 - val_loss: 0.7924 - learning_rate: 0.1000
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 25/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8736 - loss: 0.5644 - val_categorical_accuracy: 0.7020 - val_loss: 1.4880 - learning_rate: 0.1000
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 26/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8741 - loss: 0.5598 - val_categorical_accuracy: 0.7982 - val_loss: 0.8636 - learning_rate: 0.1000
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 27/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8779 - loss: 0.5534 - val_categorical_accuracy: 0.7754 - val_loss: 0.9513 - learning_rate: 0.1000
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 28/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8777 - loss: 0.5536 - val_categorical_accuracy: 0.7809 - val_loss: 0.8764 - learning_rate: 0.1000
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 29/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8813 - loss: 0.5500 - val_categorical_accuracy: 0.6244 - val_loss: 1.7402 - learning_rate: 0.1000
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 30/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8803 - loss: 0.5456 - val_categorical_accuracy: 0.6428 - val_loss: 1.7545 - learning_rate: 0.1000
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 31/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8798 - loss: 0.5490 - val_categorical_accuracy: 0.8140 - val_loss: 0.7745 - learning_rate: 0.1000
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 32/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8812 - loss: 0.5455 - val_categorical_accuracy: 0.8091 - val_loss: 0.8186 - learning_rate: 0.1000
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 33/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8839 - loss: 0.5408 - val_categorical_accuracy: 0.7249 - val_loss: 1.2455 - learning_rate: 0.1000
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 34/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8872 - loss: 0.5300 - val_categorical_accuracy: 0.7719 - val_loss: 0.9680 - learning_rate: 0.1000
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 35/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8861 - loss: 0.5387 - val_categorical_accuracy: 0.7994 - val_loss: 0.8560 - learning_rate: 0.1000
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 36/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8883 - loss: 0.5325 - val_categorical_accuracy: 0.7363 - val_loss: 1.0989 - learning_rate: 0.1000
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 37/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8874 - loss: 0.5319 - val_categorical_accuracy: 0.7123 - val_loss: 1.3727 - learning_rate: 0.1000
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 38/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8897 - loss: 0.5288 - val_categorical_accuracy: 0.7843 - val_loss: 1.0180 - learning_rate: 0.1000
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 39/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - categorical_accuracy: 0.8903 - loss: 0.5287 - val_categorical_accuracy: 0.8370 - val_loss: 0.7209 - learning_rate: 0.1000
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 40/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8927 - loss: 0.5277 - val_categorical_accuracy: 0.7666 - val_loss: 1.0019 - learning_rate: 0.1000
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 41/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8921 - loss: 0.5266 - val_categorical_accuracy: 0.7394 - val_loss: 1.1671 - learning_rate: 0.1000
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 42/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8936 - loss: 0.5194 - val_categorical_accuracy: 0.7497 - val_loss: 1.0275 - learning_rate: 0.1000
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 43/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8917 - loss: 0.5281 - val_categorical_accuracy: 0.7619 - val_loss: 1.0640 - learning_rate: 0.1000
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 44/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8941 - loss: 0.5221 - val_categorical_accuracy: 0.8250 - val_loss: 0.7784 - learning_rate: 0.1000
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 45/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8937 - loss: 0.5257 - val_categorical_accuracy: 0.7901 - val_loss: 0.9404 - learning_rate: 0.1000
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 46/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8943 - loss: 0.5216 - val_categorical_accuracy: 0.8163 - val_loss: 0.7950 - learning_rate: 0.1000
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 47/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8975 - loss: 0.5170 - val_categorical_accuracy: 0.7104 - val_loss: 1.4164 - learning_rate: 0.1000
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 48/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8964 - loss: 0.5169 - val_categorical_accuracy: 0.7998 - val_loss: 0.9078 - learning_rate: 0.1000
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 49/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8990 - loss: 0.5119 - val_categorical_accuracy: 0.8223 - val_loss: 0.8264 - learning_rate: 0.1000
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 50/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8975 - loss: 0.5150 - val_categorical_accuracy: 0.7970 - val_loss: 0.8988 - learning_rate: 0.1000
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 51/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8979 - loss: 0.5137 - val_categorical_accuracy: 0.7697 - val_loss: 0.9615 - learning_rate: 0.1000
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 52/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.8997 - loss: 0.5126 - val_categorical_accuracy: 0.6025 - val_loss: 2.4167 - learning_rate: 0.1000
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 53/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9015 - loss: 0.5101 - val_categorical_accuracy: 0.7267 - val_loss: 1.1604 - learning_rate: 0.1000
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 54/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9006 - loss: 0.5094 - val_categorical_accuracy: 0.7780 - val_loss: 0.9873 - learning_rate: 0.1000
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 55/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9004 - loss: 0.5109 - val_categorical_accuracy: 0.8221 - val_loss: 0.7977 - learning_rate: 0.1000
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 56/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9024 - loss: 0.5088 - val_categorical_accuracy: 0.8178 - val_loss: 0.8200 - learning_rate: 0.1000
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 57/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9008 - loss: 0.5116 - val_categorical_accuracy: 0.7836 - val_loss: 0.9575 - learning_rate: 0.1000
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 58/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9013 - loss: 0.5094 - val_categorical_accuracy: 0.8130 - val_loss: 0.8879 - learning_rate: 0.1000
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 59/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9035 - loss: 0.5040 - val_categorical_accuracy: 0.7950 - val_loss: 0.9200 - learning_rate: 0.1000
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 60/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9006 - loss: 0.5116 - val_categorical_accuracy: 0.7444 - val_loss: 1.2393 - learning_rate: 0.1000
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 61/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9037 - loss: 0.4995 - val_categorical_accuracy: 0.7699 - val_loss: 1.0152 - learning_rate: 0.1000
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 62/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9034 - loss: 0.5056 - val_categorical_accuracy: 0.7823 - val_loss: 1.0361 - learning_rate: 0.1000
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 63/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9033 - loss: 0.5074 - val_categorical_accuracy: 0.7913 - val_loss: 0.9340 - learning_rate: 0.1000
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 64/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9040 - loss: 0.5044 - val_categorical_accuracy: 0.7435 - val_loss: 1.2401 - learning_rate: 0.1000
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 65/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9056 - loss: 0.4994 - val_categorical_accuracy: 0.7464 - val_loss: 1.1209 - learning_rate: 0.1000
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 66/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9043 - loss: 0.5037 - val_categorical_accuracy: 0.8000 - val_loss: 0.9172 - learning_rate: 0.1000
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 67/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9037 - loss: 0.5053 - val_categorical_accuracy: 0.7931 - val_loss: 0.9601 - learning_rate: 0.1000
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 68/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9066 - loss: 0.4992 - val_categorical_accuracy: 0.8007 - val_loss: 0.8782 - learning_rate: 0.1000
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 69/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9086 - loss: 0.4913 - val_categorical_accuracy: 0.7701 - val_loss: 1.1217 - learning_rate: 0.1000
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 70/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9072 - loss: 0.5012 - val_categorical_accuracy: 0.8118 - val_loss: 0.8815 - learning_rate: 0.1000
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 71/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9072 - loss: 0.4996 - val_categorical_accuracy: 0.8243 - val_loss: 0.8250 - learning_rate: 0.1000
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 72/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9057 - loss: 0.5012 - val_categorical_accuracy: 0.7520 - val_loss: 1.2027 - learning_rate: 0.1000
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 73/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9087 - loss: 0.4892 - val_categorical_accuracy: 0.7911 - val_loss: 1.0342 - learning_rate: 0.1000
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 74/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9094 - loss: 0.4959 - val_categorical_accuracy: 0.8017 - val_loss: 0.9605 - learning_rate: 0.1000
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 75/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9103 - loss: 0.4902 - val_categorical_accuracy: 0.8359 - val_loss: 0.7671 - learning_rate: 0.1000
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 76/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9095 - loss: 0.4959 - val_categorical_accuracy: 0.8041 - val_loss: 0.9149 - learning_rate: 0.1000
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 77/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9105 - loss: 0.4956 - val_categorical_accuracy: 0.8265 - val_loss: 0.7837 - learning_rate: 0.1000
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 78/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9085 - loss: 0.4961 - val_categorical_accuracy: 0.7221 - val_loss: 1.3259 - learning_rate: 0.1000
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 79/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9098 - loss: 0.4932 - val_categorical_accuracy: 0.7640 - val_loss: 1.0021 - learning_rate: 0.1000
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 80/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9116 - loss: 0.4935 - val_categorical_accuracy: 0.7787 - val_loss: 1.0132 - learning_rate: 0.1000
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 81/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9082 - loss: 0.4961 - val_categorical_accuracy: 0.8006 - val_loss: 0.9248 - learning_rate: 0.1000
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 82/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9103 - loss: 0.4946 - val_categorical_accuracy: 0.6692 - val_loss: 1.5833 - learning_rate: 0.1000
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 83/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9141 - loss: 0.4829 - val_categorical_accuracy: 0.8337 - val_loss: 0.7977 - learning_rate: 0.1000
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 84/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9099 - loss: 0.4907 - val_categorical_accuracy: 0.8208 - val_loss: 0.8248 - learning_rate: 0.1000
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 85/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9124 - loss: 0.4866 - val_categorical_accuracy: 0.8013 - val_loss: 0.8843 - learning_rate: 0.1000
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 86/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9097 - loss: 0.4923 - val_categorical_accuracy: 0.8195 - val_loss: 0.8073 - learning_rate: 0.1000
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 87/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9142 - loss: 0.4863 - val_categorical_accuracy: 0.7787 - val_loss: 0.9937 - learning_rate: 0.1000
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 88/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9117 - loss: 0.4856 - val_categorical_accuracy: 0.7976 - val_loss: 0.9252 - learning_rate: 0.1000
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 89/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9129 - loss: 0.4857 - val_categorical_accuracy: 0.8083 - val_loss: 0.8221 - learning_rate: 0.1000
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 90/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9099 - loss: 0.4924 - val_categorical_accuracy: 0.7465 - val_loss: 1.2828 - learning_rate: 0.1000
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 91/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9119 - loss: 0.4892 - val_categorical_accuracy: 0.8175 - val_loss: 0.9017 - learning_rate: 0.1000
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 92/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9143 - loss: 0.4844 - val_categorical_accuracy: 0.7905 - val_loss: 0.9851 - learning_rate: 0.1000
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 93/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9117 - loss: 0.4910 - val_categorical_accuracy: 0.7318 - val_loss: 1.3218 - learning_rate: 0.1000
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 94/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9118 - loss: 0.4890 - val_categorical_accuracy: 0.7937 - val_loss: 0.9428 - learning_rate: 0.1000
#
# Epoch 95: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 95/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9136 - loss: 0.4822 - val_categorical_accuracy: 0.8383 - val_loss: 0.7908 - learning_rate: 0.1000
#
# Epoch 96: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 96/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9101 - loss: 0.4936 - val_categorical_accuracy: 0.8334 - val_loss: 0.7568 - learning_rate: 0.1000
#
# Epoch 97: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 97/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9154 - loss: 0.4774 - val_categorical_accuracy: 0.7861 - val_loss: 0.9945 - learning_rate: 0.1000
#
# Epoch 98: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 98/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9130 - loss: 0.4903 - val_categorical_accuracy: 0.8249 - val_loss: 0.7899 - learning_rate: 0.1000
#
# Epoch 99: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 99/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9153 - loss: 0.4811 - val_categorical_accuracy: 0.7810 - val_loss: 0.9888 - learning_rate: 0.1000
#
# Epoch 100: LearningRateScheduler setting learning rate to 0.10000000149011612.
# Epoch 100/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9142 - loss: 0.4885 - val_categorical_accuracy: 0.7632 - val_loss: 1.0955 - learning_rate: 0.1000
#
# Epoch 101: LearningRateScheduler setting learning rate to 0.010000000149011612.
# Epoch 101/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - categorical_accuracy: 0.9356 - loss: 0.4262 - val_categorical_accuracy: 0.9002 - val_loss: 0.5665 - learning_rate: 0.0100
#
# Epoch 102: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 102/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9559 - loss: 0.3689 - val_categorical_accuracy: 0.8980 - val_loss: 0.5632 - learning_rate: 0.0100
#
# Epoch 103: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 103/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9616 - loss: 0.3480 - val_categorical_accuracy: 0.9029 - val_loss: 0.5541 - learning_rate: 0.0100
#
# Epoch 104: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 104/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9660 - loss: 0.3338 - val_categorical_accuracy: 0.9018 - val_loss: 0.5618 - learning_rate: 0.0100
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 105/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9673 - loss: 0.3256 - val_categorical_accuracy: 0.9056 - val_loss: 0.5482 - learning_rate: 0.0100
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 106/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - categorical_accuracy: 0.9700 - loss: 0.3163 - val_categorical_accuracy: 0.9042 - val_loss: 0.5391 - learning_rate: 0.0100
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 107/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9707 - loss: 0.3116 - val_categorical_accuracy: 0.9038 - val_loss: 0.5642 - learning_rate: 0.0100
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 108/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9732 - loss: 0.3002 - val_categorical_accuracy: 0.9079 - val_loss: 0.5463 - learning_rate: 0.0100
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 109/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9756 - loss: 0.2915 - val_categorical_accuracy: 0.9073 - val_loss: 0.5522 - learning_rate: 0.0100
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 110/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9760 - loss: 0.2887 - val_categorical_accuracy: 0.9093 - val_loss: 0.5531 - learning_rate: 0.0100
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 111/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9756 - loss: 0.2855 - val_categorical_accuracy: 0.9060 - val_loss: 0.5551 - learning_rate: 0.0100
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 112/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9779 - loss: 0.2767 - val_categorical_accuracy: 0.9080 - val_loss: 0.5582 - learning_rate: 0.0100
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 113/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9782 - loss: 0.2729 - val_categorical_accuracy: 0.9060 - val_loss: 0.5576 - learning_rate: 0.0100
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 114/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9798 - loss: 0.2672 - val_categorical_accuracy: 0.9061 - val_loss: 0.5571 - learning_rate: 0.0100
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 115/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9809 - loss: 0.2611 - val_categorical_accuracy: 0.9075 - val_loss: 0.5588 - learning_rate: 0.0100
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 116/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9808 - loss: 0.2588 - val_categorical_accuracy: 0.9048 - val_loss: 0.5539 - learning_rate: 0.0100
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 117/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9820 - loss: 0.2532 - val_categorical_accuracy: 0.9036 - val_loss: 0.5763 - learning_rate: 0.0100
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 118/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9831 - loss: 0.2484 - val_categorical_accuracy: 0.9064 - val_loss: 0.5556 - learning_rate: 0.0100
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 119/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9836 - loss: 0.2457 - val_categorical_accuracy: 0.9054 - val_loss: 0.5709 - learning_rate: 0.0100
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 120/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9833 - loss: 0.2430 - val_categorical_accuracy: 0.9042 - val_loss: 0.5698 - learning_rate: 0.0100
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 121/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9847 - loss: 0.2377 - val_categorical_accuracy: 0.9075 - val_loss: 0.5625 - learning_rate: 0.0100
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 122/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9831 - loss: 0.2373 - val_categorical_accuracy: 0.9060 - val_loss: 0.5682 - learning_rate: 0.0100
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 123/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9845 - loss: 0.2311 - val_categorical_accuracy: 0.9038 - val_loss: 0.5814 - learning_rate: 0.0100
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 124/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9845 - loss: 0.2294 - val_categorical_accuracy: 0.9056 - val_loss: 0.5779 - learning_rate: 0.0100
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 125/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9853 - loss: 0.2249 - val_categorical_accuracy: 0.9055 - val_loss: 0.5648 - learning_rate: 0.0100
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 126/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9862 - loss: 0.2203 - val_categorical_accuracy: 0.9016 - val_loss: 0.5902 - learning_rate: 0.0100
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 127/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9877 - loss: 0.2169 - val_categorical_accuracy: 0.9061 - val_loss: 0.5850 - learning_rate: 0.0100
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 128/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9869 - loss: 0.2153 - val_categorical_accuracy: 0.9054 - val_loss: 0.5723 - learning_rate: 0.0100
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 129/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9869 - loss: 0.2127 - val_categorical_accuracy: 0.9060 - val_loss: 0.5861 - learning_rate: 0.0100
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 130/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9875 - loss: 0.2102 - val_categorical_accuracy: 0.9063 - val_loss: 0.5746 - learning_rate: 0.0100
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 131/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9873 - loss: 0.2072 - val_categorical_accuracy: 0.9075 - val_loss: 0.5696 - learning_rate: 0.0100
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 132/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9887 - loss: 0.2022 - val_categorical_accuracy: 0.9015 - val_loss: 0.6023 - learning_rate: 0.0100
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 133/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9875 - loss: 0.2026 - val_categorical_accuracy: 0.9029 - val_loss: 0.6017 - learning_rate: 0.0100
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 134/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9876 - loss: 0.2011 - val_categorical_accuracy: 0.9046 - val_loss: 0.5921 - learning_rate: 0.0100
#
# Epoch 135: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 135/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9881 - loss: 0.1978 - val_categorical_accuracy: 0.9007 - val_loss: 0.6012 - learning_rate: 0.0100
#
# Epoch 136: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 136/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9876 - loss: 0.1978 - val_categorical_accuracy: 0.9052 - val_loss: 0.5879 - learning_rate: 0.0100
#
# Epoch 137: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 137/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9887 - loss: 0.1927 - val_categorical_accuracy: 0.8884 - val_loss: 0.6719 - learning_rate: 0.0100
#
# Epoch 138: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 138/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9882 - loss: 0.1936 - val_categorical_accuracy: 0.9048 - val_loss: 0.5949 - learning_rate: 0.0100
#
# Epoch 139: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 139/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9882 - loss: 0.1900 - val_categorical_accuracy: 0.9038 - val_loss: 0.6023 - learning_rate: 0.0100
#
# Epoch 140: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 140/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9903 - loss: 0.1861 - val_categorical_accuracy: 0.9071 - val_loss: 0.5772 - learning_rate: 0.0100
#
# Epoch 141: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 141/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9893 - loss: 0.1845 - val_categorical_accuracy: 0.9017 - val_loss: 0.6121 - learning_rate: 0.0100
#
# Epoch 142: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 142/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9873 - loss: 0.1860 - val_categorical_accuracy: 0.8984 - val_loss: 0.6074 - learning_rate: 0.0100
#
# Epoch 143: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 143/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9898 - loss: 0.1808 - val_categorical_accuracy: 0.9052 - val_loss: 0.5821 - learning_rate: 0.0100
#
# Epoch 144: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 144/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9887 - loss: 0.1806 - val_categorical_accuracy: 0.8978 - val_loss: 0.6138 - learning_rate: 0.0100
#
# Epoch 145: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 145/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9906 - loss: 0.1764 - val_categorical_accuracy: 0.9059 - val_loss: 0.5795 - learning_rate: 0.0100
#
# Epoch 146: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 146/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9892 - loss: 0.1757 - val_categorical_accuracy: 0.9050 - val_loss: 0.5785 - learning_rate: 0.0100
#
# Epoch 147: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 147/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9893 - loss: 0.1742 - val_categorical_accuracy: 0.9009 - val_loss: 0.6228 - learning_rate: 0.0100
#
# Epoch 148: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 148/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9897 - loss: 0.1718 - val_categorical_accuracy: 0.9022 - val_loss: 0.6128 - learning_rate: 0.0100
#
# Epoch 149: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 149/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9903 - loss: 0.1695 - val_categorical_accuracy: 0.9014 - val_loss: 0.5977 - learning_rate: 0.0100
#
# Epoch 150: LearningRateScheduler setting learning rate to 0.009999999776482582.
# Epoch 150/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9908 - loss: 0.1673 - val_categorical_accuracy: 0.9002 - val_loss: 0.6170 - learning_rate: 0.0100
#
# Epoch 151: LearningRateScheduler setting learning rate to 0.0009999999776482583.
# Epoch 151/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9920 - loss: 0.1629 - val_categorical_accuracy: 0.9075 - val_loss: 0.5690 - learning_rate: 1.0000e-03
#
# Epoch 152: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 152/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9930 - loss: 0.1602 - val_categorical_accuracy: 0.9080 - val_loss: 0.5658 - learning_rate: 1.0000e-03
#
# Epoch 153: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 153/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9941 - loss: 0.1582 - val_categorical_accuracy: 0.9092 - val_loss: 0.5667 - learning_rate: 1.0000e-03
#
# Epoch 154: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 154/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9939 - loss: 0.1569 - val_categorical_accuracy: 0.9083 - val_loss: 0.5613 - learning_rate: 1.0000e-03
#
# Epoch 155: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 155/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9945 - loss: 0.1561 - val_categorical_accuracy: 0.9095 - val_loss: 0.5625 - learning_rate: 1.0000e-03
#
# Epoch 156: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 156/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9958 - loss: 0.1538 - val_categorical_accuracy: 0.9101 - val_loss: 0.5644 - learning_rate: 1.0000e-03
#
# Epoch 157: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 157/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9950 - loss: 0.1544 - val_categorical_accuracy: 0.9102 - val_loss: 0.5625 - learning_rate: 1.0000e-03
#
# Epoch 158: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 158/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9949 - loss: 0.1548 - val_categorical_accuracy: 0.9098 - val_loss: 0.5676 - learning_rate: 1.0000e-03
#
# Epoch 159: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 159/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9953 - loss: 0.1535 - val_categorical_accuracy: 0.9105 - val_loss: 0.5675 - learning_rate: 1.0000e-03
#
# Epoch 160: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 160/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9950 - loss: 0.1536 - val_categorical_accuracy: 0.9103 - val_loss: 0.5721 - learning_rate: 1.0000e-03
#
# Epoch 161: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 161/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9961 - loss: 0.1519 - val_categorical_accuracy: 0.9096 - val_loss: 0.5694 - learning_rate: 1.0000e-03
#
# Epoch 162: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 162/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9956 - loss: 0.1527 - val_categorical_accuracy: 0.9094 - val_loss: 0.5747 - learning_rate: 1.0000e-03
#
# Epoch 163: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 163/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1521 - val_categorical_accuracy: 0.9102 - val_loss: 0.5708 - learning_rate: 1.0000e-03
#
# Epoch 164: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 164/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9960 - loss: 0.1511 - val_categorical_accuracy: 0.9090 - val_loss: 0.5676 - learning_rate: 1.0000e-03
#
# Epoch 165: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 165/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1508 - val_categorical_accuracy: 0.9091 - val_loss: 0.5683 - learning_rate: 1.0000e-03
#
# Epoch 166: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 166/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1504 - val_categorical_accuracy: 0.9096 - val_loss: 0.5750 - learning_rate: 1.0000e-03
#
# Epoch 167: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 167/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1496 - val_categorical_accuracy: 0.9094 - val_loss: 0.5755 - learning_rate: 1.0000e-03
#
# Epoch 168: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 168/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9962 - loss: 0.1496 - val_categorical_accuracy: 0.9089 - val_loss: 0.5698 - learning_rate: 1.0000e-03
#
# Epoch 169: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 169/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9963 - loss: 0.1492 - val_categorical_accuracy: 0.9104 - val_loss: 0.5721 - learning_rate: 1.0000e-03
#
# Epoch 170: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 170/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9959 - loss: 0.1495 - val_categorical_accuracy: 0.9101 - val_loss: 0.5693 - learning_rate: 1.0000e-03
#
# Epoch 171: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 171/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1492 - val_categorical_accuracy: 0.9107 - val_loss: 0.5715 - learning_rate: 1.0000e-03
#
# Epoch 172: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 172/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9967 - loss: 0.1489 - val_categorical_accuracy: 0.9101 - val_loss: 0.5705 - learning_rate: 1.0000e-03
#
# Epoch 173: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 173/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9960 - loss: 0.1487 - val_categorical_accuracy: 0.9094 - val_loss: 0.5701 - learning_rate: 1.0000e-03
#
# Epoch 174: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 174/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9963 - loss: 0.1483 - val_categorical_accuracy: 0.9108 - val_loss: 0.5717 - learning_rate: 1.0000e-03
#
# Epoch 175: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 175/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9968 - loss: 0.1476 - val_categorical_accuracy: 0.9101 - val_loss: 0.5718 - learning_rate: 1.0000e-03
#
# Epoch 176: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 176/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1478 - val_categorical_accuracy: 0.9098 - val_loss: 0.5740 - learning_rate: 1.0000e-03
#
# Epoch 177: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 177/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9965 - loss: 0.1471 - val_categorical_accuracy: 0.9090 - val_loss: 0.5715 - learning_rate: 1.0000e-03
#
# Epoch 178: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 178/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9964 - loss: 0.1472 - val_categorical_accuracy: 0.9097 - val_loss: 0.5654 - learning_rate: 1.0000e-03
#
# Epoch 179: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 179/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1472 - val_categorical_accuracy: 0.9088 - val_loss: 0.5720 - learning_rate: 1.0000e-03
#
# Epoch 180: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 180/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9971 - loss: 0.1460 - val_categorical_accuracy: 0.9099 - val_loss: 0.5718 - learning_rate: 1.0000e-03
#
# Epoch 181: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 181/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1467 - val_categorical_accuracy: 0.9104 - val_loss: 0.5739 - learning_rate: 1.0000e-03
#
# Epoch 182: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 182/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1457 - val_categorical_accuracy: 0.9101 - val_loss: 0.5719 - learning_rate: 1.0000e-03
#
# Epoch 183: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 183/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9966 - loss: 0.1460 - val_categorical_accuracy: 0.9094 - val_loss: 0.5747 - learning_rate: 1.0000e-03
#
# Epoch 184: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 184/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9970 - loss: 0.1461 - val_categorical_accuracy: 0.9097 - val_loss: 0.5784 - learning_rate: 1.0000e-03
#
# Epoch 185: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 185/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9970 - loss: 0.1451 - val_categorical_accuracy: 0.9101 - val_loss: 0.5762 - learning_rate: 1.0000e-03
#
# Epoch 186: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 186/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9967 - loss: 0.1442 - val_categorical_accuracy: 0.9107 - val_loss: 0.5745 - learning_rate: 1.0000e-03
#
# Epoch 187: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 187/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9974 - loss: 0.1437 - val_categorical_accuracy: 0.9095 - val_loss: 0.5732 - learning_rate: 1.0000e-03
#
# Epoch 188: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 188/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9971 - loss: 0.1443 - val_categorical_accuracy: 0.9089 - val_loss: 0.5795 - learning_rate: 1.0000e-03
#
# Epoch 189: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 189/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9967 - loss: 0.1449 - val_categorical_accuracy: 0.9108 - val_loss: 0.5778 - learning_rate: 1.0000e-03
#
# Epoch 190: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 190/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9963 - loss: 0.1443 - val_categorical_accuracy: 0.9096 - val_loss: 0.5801 - learning_rate: 1.0000e-03
#
# Epoch 191: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 191/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9968 - loss: 0.1440 - val_categorical_accuracy: 0.9102 - val_loss: 0.5786 - learning_rate: 1.0000e-03
#
# Epoch 192: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 192/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9970 - loss: 0.1434 - val_categorical_accuracy: 0.9103 - val_loss: 0.5744 - learning_rate: 1.0000e-03
#
# Epoch 193: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 193/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9974 - loss: 0.1427 - val_categorical_accuracy: 0.9096 - val_loss: 0.5786 - learning_rate: 1.0000e-03
#
# Epoch 194: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 194/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9972 - loss: 0.1428 - val_categorical_accuracy: 0.9104 - val_loss: 0.5784 - learning_rate: 1.0000e-03
#
# Epoch 195: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 195/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9972 - loss: 0.1426 - val_categorical_accuracy: 0.9096 - val_loss: 0.5798 - learning_rate: 1.0000e-03
#
# Epoch 196: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 196/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9969 - loss: 0.1423 - val_categorical_accuracy: 0.9107 - val_loss: 0.5771 - learning_rate: 1.0000e-03
#
# Epoch 197: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 197/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9968 - loss: 0.1424 - val_categorical_accuracy: 0.9101 - val_loss: 0.5805 - learning_rate: 1.0000e-03
#
# Epoch 198: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 198/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9969 - loss: 0.1424 - val_categorical_accuracy: 0.9096 - val_loss: 0.5821 - learning_rate: 1.0000e-03
#
# Epoch 199: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 199/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9968 - loss: 0.1426 - val_categorical_accuracy: 0.9099 - val_loss: 0.5803 - learning_rate: 1.0000e-03
#
# Epoch 200: LearningRateScheduler setting learning rate to 0.0009999999310821295.
# Epoch 200/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - categorical_accuracy: 0.9972 - loss: 0.1415 - val_categorical_accuracy: 0.9102 - val_loss: 0.5797 - learning_rate: 1.0000e-03
#
# Test loss: 0.5381  Test accuracy: 0.9065

# %%
# Plotting training curves

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

## Plot 1
ax1.plot(history.history["loss"], label="train loss")
ax1.plot(history.history["val_loss"], label="val loss")
ax1.set_xlabel("epoch"); ax1.set_ylabel("loss")
ax1.set_title("Deterministic ResNet-20 — Loss"); ax1.legend()

## Plot 2
ax2.plot(history.history["categorical_accuracy"], label="train acc")
ax2.plot(history.history["val_categorical_accuracy"], label="val acc")
ax2.set_xlabel("epoch"); ax2.set_ylabel("accuracy")
ax2.set_title("Deterministic ResNet-20 — Accuracy"); ax2.legend()
plt.tight_layout(); plt.show()

# %%
# Loading SVHN as the out-of-distribution reference set
'''
Per the proposal §3.5, SVHN (street view of house numbers) is used as the
OOD test set. SVHN images are 32x32 colour photos like CIFAR-10, but of
digits, so a CIFAR-10 trained model should ideally report higher predictive
entropy on SVHN inputs than on its in-distribution CIFAR-10 test images.

We download the official SVHN test split (.mat) directly instead of using
tensorflow_datasets, which removes a flaky lazy-import dependency. The ~26k
images rescale to [0, 1] to match CIFAR-10 preprocessing; cached after the
first download.
'''
import os, urllib.request
from scipy.io import loadmat

svhn_path = "svhn_test_32x32.mat"
if not os.path.exists(svhn_path):
    urllib.request.urlretrieve(
        "http://ufldl.stanford.edu/housenumbers/test_32x32.mat", svhn_path)

mat = loadmat(svhn_path)
# mat["X"] has shape (32, 32, 3, N); move the sample axis to the front, rescale.
x_svhn = np.transpose(mat["X"], (3, 0, 1, 2)).astype("float32") / 255.0

print(f"SVHN OOD set: {x_svhn.shape}")
# Out:
# SVHN OOD set: (26032, 32, 32, 3)

# %%
# Loading CIFAR-10-C (common corruptions) as the in-distribution shift set
'''
Per the proposal §3.5, CIFAR-10-C (Hendrycks & Dietterich 2019) is the
corruption / covariate-shift evaluation set: the same 10 CIFAR-10 classes but
with algorithmic corruptions at graded severity. Unlike SVHN (far / semantic
OOD), these are in-domain-but-degraded inputs, so they probe a different kind
of uncertainty.

This patched version verifies the full CIFAR-10-C release, not just labels.npy.
The previous version could fail when labels.npy existed but corruption files
such as gaussian_noise.npy were missing after a partial extraction.
'''
import os, urllib.request, tarfile
import numpy as np

SEVERITY = globals().get("SEVERITY", 3)
CORRUPTIONS = globals().get("CORRUPTIONS", [
    "gaussian_noise", "shot_noise", "impulse_noise", "defocus_blur",
    "glass_blur", "motion_blur", "zoom_blur", "snow", "frost", "fog",
    "brightness", "contrast", "elastic_transform", "pixelate", "jpeg_compression",
])

CIFAR10C_ROOT = "CIFAR-10-C"
CIFAR10C_TAR = "CIFAR-10-C.tar"
CIFAR10C_URLS = [
    "https://zenodo.org/records/2535967/files/CIFAR-10-C.tar?download=1",
    "https://zenodo.org/record/2535967/files/CIFAR-10-C.tar",
]


def _required_cifar10c_files(corruptions=CORRUPTIONS):
    return ["labels.npy"] + [f"{corr}.npy" for corr in corruptions]


def _find_cifar10c_root(start=".", corruptions=CORRUPTIONS):
    """Return the directory that best looks like the extracted CIFAR-10-C root."""
    required = set(_required_cifar10c_files(corruptions))
    candidates = []

    for root, _dirs, files in os.walk(start):
        file_set = set(files)
        if "labels.npy" in file_set:
            score = len(required.intersection(file_set))
            candidates.append((score, root))

    if not candidates:
        return CIFAR10C_ROOT

    candidates.sort(reverse=True)
    return candidates[0][1]


def _missing_cifar10c_files(root, corruptions=CORRUPTIONS):
    return [
        filename
        for filename in _required_cifar10c_files(corruptions)
        if not os.path.exists(os.path.join(root, filename))
    ]


def _safe_extract_tar(tar, path="."):
    """Protect against path traversal before extracting the downloaded tar."""
    base = os.path.abspath(path)
    for member in tar.getmembers():
        member_path = os.path.abspath(os.path.join(path, member.name))
        if not (member_path == base or member_path.startswith(base + os.sep)):
            raise RuntimeError(f"Unsafe path in tar archive: {member.name}")
    tar.extractall(path)


def _download_cifar10c_tar(tar_path=CIFAR10C_TAR, urls=CIFAR10C_URLS):
    last_error = None
    for url in urls:
        try:
            print(f"Downloading CIFAR-10-C from {url}")
            urllib.request.urlretrieve(url, tar_path)
            return
        except Exception as exc:
            last_error = exc
            print(f"Download failed from {url}: {exc}")

    raise RuntimeError("Could not download CIFAR-10-C from any configured URL.") from last_error


def _extract_cifar10c_tar(tar_path=CIFAR10C_TAR):
    try:
        with tarfile.open(tar_path) as tar:
            _safe_extract_tar(tar, ".")
    except (tarfile.TarError, EOFError) as exc:
        print("Existing CIFAR-10-C tar is invalid or incomplete; re-downloading.")
        if os.path.exists(tar_path):
            os.remove(tar_path)
        _download_cifar10c_tar(tar_path)
        with tarfile.open(tar_path) as tar:
            _safe_extract_tar(tar, ".")


def load_cifar10c(severity=SEVERITY, corruptions=CORRUPTIONS, root=CIFAR10C_ROOT):
    """Download/extract CIFAR-10-C if needed, verify all files, then load one severity."""
    if not (1 <= severity <= 5):
        raise ValueError("CIFAR-10-C severity must be an integer from 1 to 5.")

    root = _find_cifar10c_root(".", corruptions)
    missing = _missing_cifar10c_files(root, corruptions)

    if missing:
        print(f"CIFAR-10-C is incomplete at '{root}'. Missing {len(missing)} file(s): {missing[:5]}")
        if not os.path.exists(CIFAR10C_TAR):
            print("CIFAR-10-C tar is not present; downloading it now (~2.9 GB).")
            _download_cifar10c_tar(CIFAR10C_TAR)
        else:
            print("CIFAR-10-C tar already exists; re-extracting it to repair the dataset.")

        _extract_cifar10c_tar(CIFAR10C_TAR)
        root = _find_cifar10c_root(".", corruptions)
        missing = _missing_cifar10c_files(root, corruptions)

    if missing:
        raise FileNotFoundError(
            "CIFAR-10-C is still incomplete after extraction. "
            f"Root checked: '{root}'. Missing files include: {missing[:10]}. "
            "Delete CIFAR-10-C and CIFAR-10-C.tar, then rerun this cell."
        )

    lo, hi = (severity - 1) * 10000, severity * 10000
    labels_full = np.load(os.path.join(root, "labels.npy"))
    labels_block = labels_full[lo:hi] if labels_full.shape[0] > 10000 else labels_full

    x_parts, y_parts = [], []
    for corr in corruptions:
        path = os.path.join(root, f"{corr}.npy")
        arr = np.load(path)[lo:hi]    # (10000, 32, 32, 3) uint8
        x_parts.append(arr)
        y_parts.append(labels_block)

    x_cifar10c = np.concatenate(x_parts, axis=0).astype("float32") / 255.0
    labels_cifar10c = np.concatenate(y_parts, axis=0).astype("int64")

    print(
        f"CIFAR-10-C set (severity {severity}, {len(corruptions)} corruptions): "
        f"{x_cifar10c.shape}, labels {labels_cifar10c.shape}"
    )
    print(f"CIFAR-10-C root: {root}")

    return x_cifar10c, labels_cifar10c


# Execute the load in this cell so Run all prepares CIFAR-10-C before prediction.
x_cifar10c, labels_cifar10c = load_cifar10c(SEVERITY, CORRUPTIONS)
# Out:
# CIFAR-10-C is incomplete at './CIFAR-10-C'. Missing 7 file(s): ['gaussian_noise.npy', 'impulse_noise.npy', 'motion_blur.npy', 'snow.npy', 'frost.npy']
# CIFAR-10-C tar is not present; downloading it now (~2.9 GB).
# Downloading CIFAR-10-C from https://zenodo.org/records/2535967/files/CIFAR-10-C.tar?download=1

# %%
# Generating predictions for the evaluation file
'''
This is the only output the downstream evaluation notebook needs from this
file. We produce softmax probabilities on:
  - the CIFAR-10 test set (in-distribution),
  - the SVHN test set (out-of-distribution),
and stash the true labels and the predicted classes alongside.

The deterministic model has a single forward pass per input, so there are no
MC samples to save - the eval file will treat probs_test as a degenerate S=1
predictive distribution.
'''

# Guard: load CIFAR-10-C here if the dedicated loading cell was skipped.
# This prevents the results file from being saved without CIFAR-10-C outputs.
if "x_cifar10c" not in globals() or "labels_cifar10c" not in globals():
    print("CIFAR-10-C was not loaded before prediction; loading it now.")
    if "load_cifar10c" not in globals():
        import os, urllib.request, tarfile
        import numpy as np

        SEVERITY = globals().get("SEVERITY", 3)
        CORRUPTIONS = globals().get("CORRUPTIONS", [
            "gaussian_noise", "shot_noise", "impulse_noise", "defocus_blur",
            "glass_blur", "motion_blur", "zoom_blur", "snow", "frost", "fog",
            "brightness", "contrast", "elastic_transform", "pixelate", "jpeg_compression",
        ])

        CIFAR10C_ROOT = "CIFAR-10-C"
        CIFAR10C_TAR = "CIFAR-10-C.tar"
        CIFAR10C_URLS = [
            "https://zenodo.org/records/2535967/files/CIFAR-10-C.tar?download=1",
            "https://zenodo.org/record/2535967/files/CIFAR-10-C.tar",
        ]


        def _required_cifar10c_files(corruptions=CORRUPTIONS):
            return ["labels.npy"] + [f"{corr}.npy" for corr in corruptions]


        def _find_cifar10c_root(start=".", corruptions=CORRUPTIONS):
            """Return the directory that best looks like the extracted CIFAR-10-C root."""
            required = set(_required_cifar10c_files(corruptions))
            candidates = []

            for root, _dirs, files in os.walk(start):
                file_set = set(files)
                if "labels.npy" in file_set:
                    score = len(required.intersection(file_set))
                    candidates.append((score, root))

            if not candidates:
                return CIFAR10C_ROOT

            candidates.sort(reverse=True)
            return candidates[0][1]


        def _missing_cifar10c_files(root, corruptions=CORRUPTIONS):
            return [
                filename
                for filename in _required_cifar10c_files(corruptions)
                if not os.path.exists(os.path.join(root, filename))
            ]


        def _safe_extract_tar(tar, path="."):
            """Protect against path traversal before extracting the downloaded tar."""
            base = os.path.abspath(path)
            for member in tar.getmembers():
                member_path = os.path.abspath(os.path.join(path, member.name))
                if not (member_path == base or member_path.startswith(base + os.sep)):
                    raise RuntimeError(f"Unsafe path in tar archive: {member.name}")
            tar.extractall(path)


        def _download_cifar10c_tar(tar_path=CIFAR10C_TAR, urls=CIFAR10C_URLS):
            last_error = None
            for url in urls:
                try:
                    print(f"Downloading CIFAR-10-C from {url}")
                    urllib.request.urlretrieve(url, tar_path)
                    return
                except Exception as exc:
                    last_error = exc
                    print(f"Download failed from {url}: {exc}")

            raise RuntimeError("Could not download CIFAR-10-C from any configured URL.") from last_error


        def _extract_cifar10c_tar(tar_path=CIFAR10C_TAR):
            try:
                with tarfile.open(tar_path) as tar:
                    _safe_extract_tar(tar, ".")
            except (tarfile.TarError, EOFError) as exc:
                print("Existing CIFAR-10-C tar is invalid or incomplete; re-downloading.")
                if os.path.exists(tar_path):
                    os.remove(tar_path)
                _download_cifar10c_tar(tar_path)
                with tarfile.open(tar_path) as tar:
                    _safe_extract_tar(tar, ".")


        def load_cifar10c(severity=SEVERITY, corruptions=CORRUPTIONS, root=CIFAR10C_ROOT):
            """Download/extract CIFAR-10-C if needed, verify all files, then load one severity."""
            if not (1 <= severity <= 5):
                raise ValueError("CIFAR-10-C severity must be an integer from 1 to 5.")

            root = _find_cifar10c_root(".", corruptions)
            missing = _missing_cifar10c_files(root, corruptions)

            if missing:
                print(f"CIFAR-10-C is incomplete at '{root}'. Missing {len(missing)} file(s): {missing[:5]}")
                if not os.path.exists(CIFAR10C_TAR):
                    print("CIFAR-10-C tar is not present; downloading it now (~2.9 GB).")
                    _download_cifar10c_tar(CIFAR10C_TAR)
                else:
                    print("CIFAR-10-C tar already exists; re-extracting it to repair the dataset.")

                _extract_cifar10c_tar(CIFAR10C_TAR)
                root = _find_cifar10c_root(".", corruptions)
                missing = _missing_cifar10c_files(root, corruptions)

            if missing:
                raise FileNotFoundError(
                    "CIFAR-10-C is still incomplete after extraction. "
                    f"Root checked: '{root}'. Missing files include: {missing[:10]}. "
                    "Delete CIFAR-10-C and CIFAR-10-C.tar, then rerun this cell."
                )

            lo, hi = (severity - 1) * 10000, severity * 10000
            labels_full = np.load(os.path.join(root, "labels.npy"))
            labels_block = labels_full[lo:hi] if labels_full.shape[0] > 10000 else labels_full

            x_parts, y_parts = [], []
            for corr in corruptions:
                path = os.path.join(root, f"{corr}.npy")
                arr = np.load(path)[lo:hi]    # (10000, 32, 32, 3) uint8
                x_parts.append(arr)
                y_parts.append(labels_block)

            x_cifar10c = np.concatenate(x_parts, axis=0).astype("float32") / 255.0
            labels_cifar10c = np.concatenate(y_parts, axis=0).astype("int64")

            print(
                f"CIFAR-10-C set (severity {severity}, {len(corruptions)} corruptions): "
                f"{x_cifar10c.shape}, labels {labels_cifar10c.shape}"
            )
            print(f"CIFAR-10-C root: {root}")

            return x_cifar10c, labels_cifar10c

    x_cifar10c, labels_cifar10c = load_cifar10c(SEVERITY, CORRUPTIONS)

## In-distribution: CIFAR-10 test set
logits_test = model.predict(test_ds)                        # (10000, 10)
probs_test  = tf.nn.softmax(logits_test, axis=-1).numpy()
preds_test  = np.argmax(probs_test, axis=1)
labels_test = np.argmax(y_test, axis=1)

print(f"Test accuracy: {(preds_test == labels_test).mean():.4f}")

## Out-of-distribution: SVHN test set
logits_svhn = model.predict(x_svhn, batch_size=128)
probs_svhn  = tf.nn.softmax(logits_svhn, axis=-1).numpy()

## In-distribution shift: CIFAR-10-C (severity 3, 15 corruptions)
logits_c10c    = model.predict(x_cifar10c, batch_size=128)
probs_cifar10c = tf.nn.softmax(logits_c10c, axis=-1).numpy()

print(f"probs_test:     {probs_test.shape}")
print(f"probs_svhn:     {probs_svhn.shape}")
print(f"probs_cifar10c: {probs_cifar10c.shape}")
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step
# Test accuracy: 0.9065
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step
# 1172/1172 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step
# probs_test:     (10000, 10)
# probs_svhn:     (26032, 10)
# probs_cifar10c: (150000, 10)

# %%
# Saving raw outputs for the evaluation file
'''
Save format (shared across all benchmarks). The evaluation notebook will
load these by filename and produce ECE, reliability diagrams, OOD AUROC,
risk-coverage and (for the BNN benchmarks) the epistemic / aleatoric
decomposition.

Keys:
  model_name     - human-readable string identifier
  probs_test     - (N_test, 10)  mean predictive distribution on CIFAR-10 test
  labels_test    - (N_test,)     true labels (integer 0-9)
  preds_test     - (N_test,)     argmax of probs_test
  probs_svhn     - (N_svhn, 10)  mean predictive distribution on SVHN OOD
  all_probs_test - (S, N_test, 10) per-sample probs (None for deterministic)
  all_probs_svhn - (S, N_svhn, 10) per-sample probs (None for deterministic)
'''
np.savez("deterministic_results.npz",
         model_name="deterministic",
         probs_test=probs_test,
         labels_test=labels_test,
         preds_test=preds_test,
         probs_svhn=probs_svhn,
         probs_cifar10c=probs_cifar10c,
         labels_cifar10c=labels_cifar10c,
         cifar10c_severity=SEVERITY,
         all_probs_test=probs_test[None, :, :],   # treat as S=1 for uniform eval API
         all_probs_svhn=probs_svhn[None, :, :],
         all_probs_cifar10c=probs_cifar10c[None, :, :])

print("Saved deterministic_results.npz")
# Out:
# Saved deterministic_results.npz
